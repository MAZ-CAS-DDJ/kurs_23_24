# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

# %%
import pandas as pd

# %%
from datetime import datetime, timedelta

# %%
import time

# %%
pd.set_option("display.max_rows", 100)

# %%
key = "((INSERT YOUR KEY))"

# %% [markdown]
# ## Top 100 Currencies

# %%
url = 'https://min-api.cryptocompare.com/data/top/mktcapfull'

parameters = {
    'limit': '100',
    'tsym': 'USD',
    'api_key': key
}
headers = {
    
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    #print(data)

except (ConnectionError, Timeout, TooManyRedirects) as e:
    data = ""
    #print(e)

# %%
data
# Out:
# {'Message': 'Success',
#  'Type': 100,
#  'MetaData': {'Count': 671},
#  'SponsoredData': [],
#  'Data': [{'CoinInfo': {'Id': '1182',
#     'Name': 'BTC',
#     'FullName': 'Bitcoin',
#     'Internal': 'BTC',
#     'ImageUrl': '/media/37746251/btc.png',
#     'Url': '/coins/btc/overview',
#     'Algorithm': 'SHA-256',
#     'ProofType': 'PoW',
#     'Rating': {'Weiss': {'Rating': 'B+',
#       'TechnologyAdoptionRating': 'A-',
#       'MarketPerformanceRating': 'D'}},
#     'NetHashesPerSecond': 411876783737888000000,
#     'BlockNumber': 807045,
#     'BlockTime': 518,
#     'BlockReward': 6.25,
#     'AssetLaunchDate': '2009-01-03',
#     'MaxSupply': 20999999.9769,
#     'Type': 1,
#     'DocumentType': 'Webpagecoinp'},
#    'RAW': {'USD': {'TYPE': '5',
#      'MARKET': 'CCCAGG',
#      'FROMSYMBOL': 'BTC',
#      'TOSYMBOL': 'USD',
#      'FLAGS': '2050',
#      'PRICE': 25766.37,
#      'LASTUPDATE': 1694360160,
#      'MEDIAN': 25770.98,
#      'LASTVOLUME': 0.36,
#      'LASTVOLUMETO': 9274.86,
#      'LASTTRADEID': '16943601600000',
#      'VOLUMEDAY': 3277.9512509801198,
#      'VOLUMEDAYTO': 84607629.40624201,
#      'VOLUME24HOUR': 4532.56337582,
#      'VOLUME24HOURTO': 117080165.28606507,
#      'OPENDAY': 25898.49,
#      'HIGHDAY': 25900.68,
#      'LOWDAY': 25716.83,
#      'OPEN24HOUR': 25890.61,
#      'HIGH24HOUR': 25938.47,
#      'LOW24HOUR': 25713.78,
#      'LASTMARKET': 'lmax',
#      'VOLUMEHOUR': 464.70469796999674,
#      'VOLUMEHOURTO': 11963857.21615816,
#      'OPENHOUR': 25767.08,
#      'HIGHHOUR': 25778.66,
#      'LOWHOUR': 25716.83,
#      'TOPTIERVOLUME24HOUR': 4532.56337582,
#      'TOPTIERVOLUME24HOURTO': 117080165.28606507,
#      'CHANGE24HOUR': -124.2400000000016,
#      'CHANGEPCT24HOUR': -0.479865093947194,
#      'CHANGEDAY': -132.12000000000262,
#      'CHANGEPCTDAY': -0.5101455721936013,
#      'CHANGEHOUR': -0.7100000000027649,
#      'CHANGEPCTHOUR': -0.0027554538581894606,
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 1694360160,
#      'SUPPLY': 19481537,
#      'MKTCAP': 501968490510.69,
#      'MKTCAPPENALTY': 0,
#      'CIRCULATINGSUPPLY': 19481537,
#      'CIRCULATINGSUPPLYMKTCAP': 501968490510.69,
#      'TOTALVOLUME24H': 26689.96158910617,
#      'TOTALVOLUME24HTO': 687995885.8869355,
#      'TOTALTOPTIERVOLUME24H': 25743.382616508563,
#      'TOTALTOPTIERVOLUME24HTO': 663605981.8447657,
#      'IMAGEURL': '/media/37746251/btc.png'}},
#    'DISPLAY': {'USD': {'FROMSYMBOL': 'Ƀ',
#      'TOSYMBOL': '$',
#      'MARKET': 'CryptoCompare Index',
#      'PRICE': '$ 25,766.4',
#      'LASTUPDATE': 'Just now',
#      'LASTVOLUME': 'Ƀ 0.3600',
#      'LASTVOLUMETO': '$ 9,274.86',
#      'LASTTRADEID': '16943601600000',
#      'VOLUMEDAY': 'Ƀ 3,277.95',
#      'VOLUMEDAYTO': '$ 84,607,629.4',
#      'VOLUME24HOUR': 'Ƀ 4,532.56',
#      'VOLUME24HOURTO': '$ 117,080,165.3',
#      'OPENDAY': '$ 25,898.5',
#      'HIGHDAY': '$ 25,900.7',
#      'LOWDAY': '$ 25,716.8',
#      'OPEN24HOUR': '$ 25,890.6',
#      'HIGH24HOUR': '$ 25,938.5',
#      'LOW24HOUR': '$ 25,713.8',
#      'LASTMARKET': 'lmax',
#      'VOLUMEHOUR': 'Ƀ 464.70',
#      'VOLUMEHOURTO': '$ 11,963,857.2',
#      'OPENHOUR': '$ 25,767.1',
#      'HIGHHOUR': '$ 25,778.7',
#      'LOWHOUR': '$ 25,716.8',
#      'TOPTIERVOLUME24HOUR': 'Ƀ 4,532.56',
#      'TOPTIERVOLUME24HOURTO': '$ 117,080,165.3',
#      'CHANGE24HOUR': '$ -124.24',
#      'CHANGEPCT24HOUR': '-0.48',
#      'CHANGEDAY': '$ -132.12',
#      'CHANGEPCTDAY': '-0.51',
#      'CHANGEHOUR': '$ -0.71',
#      'CHANGEPCTHOUR': '0.00',
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 'Just now',
#      'SUPPLY': 'Ƀ 19,481,537.0',
#      'MKTCAP': '$ 501.97 B',
#      'MKTCAPPENALTY': '0 %',
#      'CIRCULATINGSUPPLY': 'Ƀ 19,481,537.0',
#      'CIRCULATINGSUPPLYMKTCAP': '$ 501.97 B',
#      'TOTALVOLUME24H': 'Ƀ 26.69 K',
#      'TOTALVOLUME24HTO': '$ 688.00 M',
#      'TOTALTOPTIERVOLUME24H': 'Ƀ 25.74 K',
#      'TOTALTOPTIERVOLUME24HTO': '$ 663.61 M',
#      'IMAGEURL': '/media/37746251/btc.png'}}},
#   {'CoinInfo': {'Id': '7605',
#     'Name': 'ETH',
#     'FullName': 'Ethereum',
#     'Internal': 'ETH',
#     'ImageUrl': '/media/37746238/eth.png',
#     'Url': '/coins/eth/overview',
#     'Algorithm': 'Ethash',
#     'ProofType': 'PoS',
#     'Rating': {'Weiss': {'Rating': 'B-',
#       'TechnologyAdoptionRating': 'B',
#       'MarketPerformanceRating': 'D'}},
#     'NetHashesPerSecond': 0,
#     'BlockNumber': 18106823,
#     'BlockTime': 12,
#     'BlockReward': 2.044338104121828,
#     'AssetLaunchDate': '2015-07-30',
#     'MaxSupply': -1,
#     'Type': 1,
#     'DocumentType': 'Webpagecoinp'},
#    'RAW': {'USD': {'TYPE': '5',
#      'MARKET': 'CCCAGG',
#      'FROMSYMBOL': 'ETH',
#      'TOSYMBOL': 'USD',
#      'FLAGS': '2052',
#      'PRICE': 1618.46,
#      'LASTUPDATE': 1694360156,
#      'MEDIAN': 1618.56,
#      'LASTVOLUME': 0.85022788,
#      'LASTVOLUMETO': 1375.7452303492,
#      'LASTTRADEID': '468918523',
#      'VOLUMEDAY': 41401.05422012067,
#      'VOLUMEDAYTO': 67233735.06185776,
#      'VOLUME24HOUR': 49864.295637819996,
#      'VOLUME24HOURTO': 81065940.34640166,
#      'OPENDAY': 1635.28,
#      'HIGHDAY': 1635.6,
#      'LOWDAY': 1612.47,
#      'OPEN24HOUR': 1634.84,
#      'HIGH24HOUR': 1637.22,
#      'LOW24HOUR': 1611.22,
#      'LASTMARKET': 'Coinbase',
#      'VOLUMEHOUR': 7153.435266780095,
#      'VOLUMEHOURTO': 11558419.107588496,
#      'OPENHOUR': 1621.87,
#      'HIGHHOUR': 1622.1,
#      'LOWHOUR': 1612.47,
#      'TOPTIERVOLUME24HOUR': 49864.295637819996,
#      'TOPTIERVOLUME24HOURTO': 81065940.34640166,
#      'CHANGE24HOUR': -16.37999999999988,
#      'CHANGEPCT24HOUR': -1.0019329108658879,
#      'CHANGEDAY': -16.819999999999936,
#      'CHANGEPCTDAY': -1.0285700308204062,
#      'CHANGEHOUR': -3.4099999999998545,
#      'CHANGEPCTHOUR': -0.21025112986859948,
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 1694360156,
#      'SUPPLY': 120220572.27053285,
#      'MKTCAP': 194572187396.9666,
#      'MKTCAPPENALTY': 0,
#      'CIRCULATINGSUPPLY': 118779578.21796943,
#      'CIRCULATINGSUPPLYMKTCAP': 192239996162.65482,
#      'TOTALVOLUME24H': 276671.78345987195,
#      'TOTALVOLUME24HTO': 448144787.08687985,
#      'TOTALTOPTIERVOLUME24H': 267215.1923344385,
#      'TOTALTOPTIERVOLUME24HTO': 432839672.6140108,
#      'IMAGEURL': '/media/37746238/eth.png'}},
#    'DISPLAY': {'USD': {'FROMSYMBOL': 'Ξ',
#      'TOSYMBOL': '$',
#      'MARKET': 'CryptoCompare Index',
#      'PRICE': '$ 1,618.46',
#      'LASTUPDATE': 'Just now',
#      'LASTVOLUME': 'Ξ 0.8502',
#      'LASTVOLUMETO': '$ 1,375.75',
#      'LASTTRADEID': '468918523',
#      'VOLUMEDAY': 'Ξ 41,401.1',
#      'VOLUMEDAYTO': '$ 67,233,735.1',
#      'VOLUME24HOUR': 'Ξ 49,864.3',
#      'VOLUME24HOURTO': '$ 81,065,940.3',
#      'OPENDAY': '$ 1,635.28',
#      'HIGHDAY': '$ 1,635.60',
#      'LOWDAY': '$ 1,612.47',
#      'OPEN24HOUR': '$ 1,634.84',
#      'HIGH24HOUR': '$ 1,637.22',
#      'LOW24HOUR': '$ 1,611.22',
#      'LASTMARKET': 'Coinbase',
#      'VOLUMEHOUR': 'Ξ 7,153.44',
#      'VOLUMEHOURTO': '$ 11,558,419.1',
#      'OPENHOUR': '$ 1,621.87',
#      'HIGHHOUR': '$ 1,622.10',
#      'LOWHOUR': '$ 1,612.47',
#      'TOPTIERVOLUME24HOUR': 'Ξ 49,864.3',
#      'TOPTIERVOLUME24HOURTO': '$ 81,065,940.3',
#      'CHANGE24HOUR': '$ -16.38',
#      'CHANGEPCT24HOUR': '-1.00',
#      'CHANGEDAY': '$ -16.82',
#      'CHANGEPCTDAY': '-1.03',
#      'CHANGEHOUR': '$ -3.41',
#      'CHANGEPCTHOUR': '-0.21',
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 'Just now',
#      'SUPPLY': 'Ξ 120,220,572.3',
#      'MKTCAP': '$ 194.57 B',
#      'MKTCAPPENALTY': '0 %',
#      'CIRCULATINGSUPPLY': 'Ξ 118,779,578.2',
#      'CIRCULATINGSUPPLYMKTCAP': '$ 192.24 B',
#      'TOTALVOLUME24H': 'Ξ 276.67 K',
#      'TOTALVOLUME24HTO': '$ 448.14 M',
#      'TOTALTOPTIERVOLUME24H': 'Ξ 267.22 K',
#      'TOTALTOPTIERVOLUME24HTO': '$ 432.84 M',
#      'IMAGEURL': '/media/37746238/eth.png'}}},
#   {'CoinInfo': {'Id': '171986',
#     'Name': 'USDT',
#     'FullName': 'Tether',
#     'Internal': 'USDT',
#     'ImageUrl': '/media/37746338/usdt.png',
#     'Url': '/coins/usdt/overview',
#     'Algorithm': 'N/A',
#     'ProofType': 'N/A',
#     'Rating': {'Weiss': {'Rating': '',
#       'TechnologyAdoptionRating': '',
#       'MarketPerformanceRating': ''}},
#     'NetHashesPerSecond': 0,
#     'BlockNumber': 0,
#     'BlockTime': 0,
#     'BlockReward': 0,
#     'AssetLaunchDate': '2014-10-06',
#     'MaxSupply': -1,
#     'Type': 1,
#     'DocumentType': 'Webpagecoinp'},
#    'RAW': {'USD': {'TYPE': '5',
#      'MARKET': 'CCCAGG',
#      'FROMSYMBOL': 'USDT',
#      'TOSYMBOL': 'USD',
#      'FLAGS': '2052',
#      'PRICE': 0.9999,
#      'LASTUPDATE': 1694360154,
#      'MEDIAN': 0.9998,
#      'LASTVOLUME': 0.1,
#      'LASTVOLUMETO': 0.099984,
#      'LASTTRADEID': '4611686018444268070',
#      'VOLUMEDAY': 50775061.28448027,
#      'VOLUMEDAYTO': 50766721.35629445,
#      'VOLUME24HOUR': 65924219.42859069,
#      'VOLUME24HOURTO': 65912414.05808662,
#      'OPENDAY': 0.9998,
#      'HIGHDAY': 1,
#      'LOWDAY': 0.9998,
#      'OPEN24HOUR': 0.9998,
#      'HIGH24HOUR': 1,
#      'LOW24HOUR': 0.9997,
#      'LASTMARKET': 'cryptodotcom',
#      'VOLUMEHOUR': 3631769.559839164,
#      'VOLUMEHOURTO': 3631112.383906684,
#      'OPENHOUR': 0.9999,
#      'HIGHHOUR': 0.9999,
#      'LOWHOUR': 0.9999,
#      'TOPTIERVOLUME24HOUR': 65924219.42859069,
#      'TOPTIERVOLUME24HOURTO': 65912414.05808662,
#      'CHANGE24HOUR': 9.999999999998899e-05,
#      'CHANGEPCT24HOUR': 0.010002000400078915,
#      'CHANGEDAY': 9.999999999998899e-05,
#      'CHANGEPCTDAY': 0.010002000400078915,
#      'CHANGEHOUR': 0,
#      'CHANGEPCTHOUR': 0,
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 1694360154,
#      'SUPPLY': 86314722206.09319,
#      'MKTCAP': 86306090733.87257,
#      'MKTCAPPENALTY': 0,
#      'CIRCULATINGSUPPLY': 83016246102.32362,
#      'CIRCULATINGSUPPLYMKTCAP': 83007944477.7134,
#      'TOTALVOLUME24H': 167740578.96711555,
#      'TOTALVOLUME24HTO': 167718591.96065763,
#      'TOTALTOPTIERVOLUME24H': 150447698.61106354,
#      'TOTALTOPTIERVOLUME24HTO': 150427440.89264125,
#      'IMAGEURL': '/media/37746338/usdt.png'}},
#    'DISPLAY': {'USD': {'FROMSYMBOL': '₮',
#      'TOSYMBOL': '$',
#      'MARKET': 'CryptoCompare Index',
#      'PRICE': '$ 0.9999',
#      'LASTUPDATE': 'Just now',
#      'LASTVOLUME': '₮ 0.1000',
#      'LASTVOLUMETO': '$ 0.09998',
#      'LASTTRADEID': '4611686018444268070',
#      'VOLUMEDAY': '₮ 50,775,061.3',
#      'VOLUMEDAYTO': '$ 50,766,721.4',
#      'VOLUME24HOUR': '₮ 65,924,219.4',
#      'VOLUME24HOURTO': '$ 65,912,414.1',
#      'OPENDAY': '$ 0.9998',
#      'HIGHDAY': '$ 1.00',
#      'LOWDAY': '$ 0.9998',
#      'OPEN24HOUR': '$ 0.9998',
#      'HIGH24HOUR': '$ 1.00',
#      'LOW24HOUR': '$ 0.9997',
#      'LASTMARKET': 'cryptodotcom',
#      'VOLUMEHOUR': '₮ 3,631,769.6',
#      'VOLUMEHOURTO': '$ 3,631,112.4',
#      'OPENHOUR': '$ 0.9999',
#      'HIGHHOUR': '$ 0.9999',
#      'LOWHOUR': '$ 0.9999',
#      'TOPTIERVOLUME24HOUR': '₮ 65,924,219.4',
#      'TOPTIERVOLUME24HOURTO': '$ 65,912,414.1',
#      'CHANGE24HOUR': '$ 0.00010',
#      'CHANGEPCT24HOUR': '0.01',
#      'CHANGEDAY': '$ 0.00010',
#      'CHANGEPCTDAY': '0.01',
#      'CHANGEHOUR': '$ 0.0',
#      'CHANGEPCTHOUR': '0.00',
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 'Just now',
#      'SUPPLY': '₮ 86,314,722,206.1',
#      'MKTCAP': '$ 86.31 B',
#      'MKTCAPPENALTY': '0 %',
#      'CIRCULATINGSUPPLY': '₮ 83,016,246,102.3',
#      'CIRCULATINGSUPPLYMKTCAP': '$ 83.01 B',
#      'TOTALVOLUME24H': '₮ 167.74 M',
#      'TOTALVOLUME24HTO': '$ 167.72 M',
#      'TOTALTOPTIERVOLUME24H': '₮ 150.45 M',
#      'TOTALTOPTIERVOLUME24HTO': '$ 150.43 M',
#      'IMAGEURL': '/media/37746338/usdt.png'}}},
#   {'CoinInfo': {'Id': '5031',
#     'Name': 'XRP',
#     'FullName': 'XRP',
#     'Internal': 'XRP',
#     'ImageUrl': '/media/38553096/xrp.png',
#     'Url': '/coins/xrp/overview',
#     'Algorithm': 'N/A',
#     'ProofType': 'XRP LCP',
#     'Rating': {'Weiss': {'Rating': 'B-',
#       'TechnologyAdoptionRating': 'B-',
#       'MarketPerformanceRating': 'C-'}},
#     'NetHashesPerSecond': 0,
#     'BlockNumber': 82447244,
#     'BlockTime': 4,
#     'BlockReward': 0,
#     'AssetLaunchDate': '2012-09-26',
#     'MaxSupply': 100000000000,
#     'Type': 1,
#     'DocumentType': 'Webpagecoinp'},
#    'RAW': {'USD': {'TYPE': '5',
#      'MARKET': 'CCCAGG',
#      'FROMSYMBOL': 'XRP',
#      'TOSYMBOL': 'USD',
#      'FLAGS': '1026',
#      'PRICE': 0.4962,
#      'LASTUPDATE': 1694360160,
#      'MEDIAN': 0.49622,
#      'LASTVOLUME': 136.3653819,
#      'LASTVOLUMETO': 67.65086596059,
#      'LASTTRADEID': '1694360160.515254',
#      'VOLUMEDAY': 10142432.048039544,
#      'VOLUMEDAYTO': 5052927.134084627,
#      'VOLUME24HOUR': 11800738.84180766,
#      'VOLUME24HOURTO': 5887815.070712774,
#      'OPENDAY': 0.5037,
#      'HIGHDAY': 0.5037,
#      'LOWDAY': 0.4934,
#      'OPEN24HOUR': 0.5043,
#      'HIGH24HOUR': 0.5046,
#      'LOW24HOUR': 0.4928,
#      'LASTMARKET': 'Kraken',
#      'VOLUMEHOUR': 1995606.3524043607,
#      'VOLUMEHOURTO': 987590.56056737,
#      'OPENHOUR': 0.4971,
#      'HIGHHOUR': 0.4972,
#      'LOWHOUR': 0.4934,
#      'TOPTIERVOLUME24HOUR': 11800738.84180766,
#      'TOPTIERVOLUME24HOURTO': 5887815.070712774,
#      'CHANGE24HOUR': -0.008099999999999996,
#      'CHANGEPCT24HOUR': -1.606186793575252,
#      'CHANGEDAY': -0.007500000000000062,
#      'CHANGEPCTDAY': -1.488981536628958,
#      'CHANGEHOUR': -0.0009000000000000119,
#      'CHANGEPCTHOUR': -0.18105009052504767,
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 1694360160,
#      'SUPPLY': 99988432239.4507,
#      'MKTCAP': 49614260077.21543,
#      'MKTCAPPENALTY': 0,
#      'CIRCULATINGSUPPLY': 53083046512,
#      'CIRCULATINGSUPPLYMKTCAP': 26339807679.2544,
#      'TOTALVOLUME24H': 259296958.45841277,
#      'TOTALVOLUME24HTO': 128695439.24447222,
#      'TOTALTOPTIERVOLUME24H': 217029689.95612234,
#      'TOTALTOPTIERVOLUME24HTO': 107722420.61363572,
#      'IMAGEURL': '/media/38553096/xrp.png'}},
#    'DISPLAY': {'USD': {'FROMSYMBOL': 'XRP',
#      'TOSYMBOL': '$',
#      'MARKET': 'CryptoCompare Index',
#      'PRICE': '$ 0.4962',
#      'LASTUPDATE': 'Just now',
#      'LASTVOLUME': 'XRP 136.37',
#      'LASTVOLUMETO': '$ 67.65',
#      'LASTTRADEID': '1694360160.515254',
#      'VOLUMEDAY': 'XRP 10,142,432.0',
#      'VOLUMEDAYTO': '$ 5,052,927.1',
#      'VOLUME24HOUR': 'XRP 11,800,738.8',
#      'VOLUME24HOURTO': '$ 5,887,815.1',
#      'OPENDAY': '$ 0.5037',
#      'HIGHDAY': '$ 0.5037',
#      'LOWDAY': '$ 0.4934',
#      'OPEN24HOUR': '$ 0.5043',
#      'HIGH24HOUR': '$ 0.5046',
#      'LOW24HOUR': '$ 0.4928',
#      'LASTMARKET': 'Kraken',
#      'VOLUMEHOUR': 'XRP 1,995,606.4',
#      'VOLUMEHOURTO': '$ 987,590.6',
#      'OPENHOUR': '$ 0.4971',
#      'HIGHHOUR': '$ 0.4972',
#      'LOWHOUR': '$ 0.4934',
#      'TOPTIERVOLUME24HOUR': 'XRP 11,800,738.8',
#      'TOPTIERVOLUME24HOURTO': '$ 5,887,815.1',
#      'CHANGE24HOUR': '$ -0.0081',
#      'CHANGEPCT24HOUR': '-1.61',
#      'CHANGEDAY': '$ -0.0075',
#      'CHANGEPCTDAY': '-1.49',
#      'CHANGEHOUR': '$ -0.00090',
#      'CHANGEPCTHOUR': '-0.18',
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 'Just now',
#      'SUPPLY': 'XRP 99,988,432,239.5',
#      'MKTCAP': '$ 49.61 B',
#      'MKTCAPPENALTY': '0 %',
#      'CIRCULATINGSUPPLY': 'XRP 53,083,046,512.0',
#      'CIRCULATINGSUPPLYMKTCAP': '$ 26.34 B',
#      'TOTALVOLUME24H': 'XRP 259.30 M',
#      'TOTALVOLUME24HTO': '$ 128.70 M',
#      'TOTALTOPTIERVOLUME24H': 'XRP 217.03 M',
#      'TOTALTOPTIERVOLUME24HTO': '$ 107.72 M',
#      'IMAGEURL': '/media/38553096/xrp.png'}}},
#   {'CoinInfo': {'Id': '204788',
#     'Name': 'BNB',
#     'FullName': 'Binance Coin',
#     'Internal': 'BNB',
#     'ImageUrl': '/media/40485170/bnb.png',
#     'Url': '/coins/bnb/overview',
#     'Algorithm': 'BEP-2',
#     'ProofType': 'PoSA',
#     'Rating': {'Weiss': {'Rating': 'C',
#       'TechnologyAdoptionRating': 'C',
#       'MarketPerformanceRating': 'C-'}},
#     'NetHashesPerSecond': 0,
#     'BlockNumber': 338745717,
#     'BlockTime': 0,
#     'BlockReward': 0,
#     'AssetLaunchDate': '2019-04-18',
#     'MaxSupply': -1,
#     'Type': 1,
#     'DocumentType': 'Webpagecoinp'},
#    'RAW': {'USD': {'TYPE': '5',
#      'MARKET': 'CCCAGG',
#      'FROMSYMBOL': 'BNB',
#      'TOSYMBOL': 'USD',
#      'FLAGS': '2052',
#      'PRICE': 212.7,
#      'LASTUPDATE': 1694360148,
#      'MEDIAN': 212.98395869,
#      'LASTVOLUME': 0.028,
#      'LASTVOLUMETO': 5.9556,
#      'LASTTRADEID': '7222910973',
#      'VOLUMEDAY': 4075.514337999987,
#      'VOLUMEDAYTO': 870384.290243088,
#      'VOLUME24HOUR': 4164.10686206,
#      'VOLUME24HOURTO': 889280.779288714,
#      'OPENDAY': 214.13,
#      'HIGHDAY': 214.33,
#      'LOWDAY': 211.56,
#      'OPEN24HOUR': 215.2,
#      'HIGH24HOUR': 215.4,
#      'LOW24HOUR': 211.5,
#      'LASTMARKET': 'P2PB2B',
#      'VOLUMEHOUR': 176.28897560000004,
#      'VOLUMEHOURTO': 37433.700004865175,
#      'OPENHOUR': 212.4,
#      'HIGHHOUR': 212.9,
#      'LOWHOUR': 211.81,
#      'TOPTIERVOLUME24HOUR': 2.42145376,
#      'TOPTIERVOLUME24HOURTO': 516.705516917,
#      'CHANGE24HOUR': -2.5,
#      'CHANGEPCT24HOUR': -1.1617100371747213,
#      'CHANGEDAY': -1.4300000000000068,
#      'CHANGEPCTDAY': -0.6678186148601349,
#      'CHANGEHOUR': 0.29999999999998295,
#      'CHANGEPCTHOUR': 0.14124293785309933,
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 1694360148,
#      'SUPPLY': 157888831.024,
#      'MKTCAP': 33582954358.804794,
#      'MKTCAPPENALTY': 0,
#      'CIRCULATINGSUPPLY': 157888831.024,
#      'CIRCULATINGSUPPLYMKTCAP': 33582954358.804794,
#      'TOTALVOLUME24H': 267108.01039151626,
#      'TOTALVOLUME24HTO': 56817449.060004056,
#      'TOTALTOPTIERVOLUME24H': 254653.09484188972,
#      'TOTALTOPTIERVOLUME24HTO': 54164714.9351721,
#      'IMAGEURL': '/media/40485170/bnb.png'}},
#    'DISPLAY': {'USD': {'FROMSYMBOL': 'BNB',
#      'TOSYMBOL': '$',
#      'MARKET': 'CryptoCompare Index',
#      'PRICE': '$ 212.70',
#      'LASTUPDATE': 'Just now',
#      'LASTVOLUME': 'BNB 0.02800',
#      'LASTVOLUMETO': '$ 5.96',
#      'LASTTRADEID': '7222910973',
#      'VOLUMEDAY': 'BNB 4,075.51',
#      'VOLUMEDAYTO': '$ 870,384.3',
#      'VOLUME24HOUR': 'BNB 4,164.11',
#      'VOLUME24HOURTO': '$ 889,280.8',
#      'OPENDAY': '$ 214.13',
#      'HIGHDAY': '$ 214.33',
#      'LOWDAY': '$ 211.56',
#      'OPEN24HOUR': '$ 215.20',
#      'HIGH24HOUR': '$ 215.40',
#      'LOW24HOUR': '$ 211.50',
#      'LASTMARKET': 'P2PB2B',
#      'VOLUMEHOUR': 'BNB 176.29',
#      'VOLUMEHOURTO': '$ 37,433.7',
#      'OPENHOUR': '$ 212.40',
#      'HIGHHOUR': '$ 212.90',
#      'LOWHOUR': '$ 211.81',
#      'TOPTIERVOLUME24HOUR': 'BNB 2.42',
#      'TOPTIERVOLUME24HOURTO': '$ 516.71',
#      'CHANGE24HOUR': '$ -2.50',
#      'CHANGEPCT24HOUR': '-1.16',
#      'CHANGEDAY': '$ -1.43',
#      'CHANGEPCTDAY': '-0.67',
#      'CHANGEHOUR': '$ 0.30',
#      'CHANGEPCTHOUR': '0.14',
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 'Just now',
#      'SUPPLY': 'BNB 157,888,831.0',
#      'MKTCAP': '$ 33.58 B',
#      'MKTCAPPENALTY': '0 %',
#      'CIRCULATINGSUPPLY': 'BNB 157,888,831.0',
#      'CIRCULATINGSUPPLYMKTCAP': '$ 33.58 B',
#      'TOTALVOLUME24H': 'BNB 267.11 K',
#      'TOTALVOLUME24HTO': '$ 56.82 M',
#      'TOTALTOPTIERVOLUME24H': 'BNB 254.65 K',
#      'TOTALTOPTIERVOLUME24HTO': '$ 54.16 M',
#      'IMAGEURL': '/media/40485170/bnb.png'}}},
#   {'CoinInfo': {'Id': '925809',
#     'Name': 'USDC',
#     'FullName': 'USD Coin',
#     'Internal': 'USDC',
#     'ImageUrl': '/media/34835941/usdc.png',
#     'Url': '/coins/usdc/overview',
#     'Algorithm': 'N/A',
#     'ProofType': 'N/A',
#     'Rating': {'Weiss': {'Rating': '',
#       'TechnologyAdoptionRating': '',
#       'MarketPerformanceRating': ''}},
#     'NetHashesPerSecond': 0,
#     'BlockNumber': 0,
#     'BlockTime': 0,
#     'BlockReward': 0,
#     'AssetLaunchDate': '2018-09-10',
#     'MaxSupply': -1,
#     'Type': 1,
#     'DocumentType': 'Webpagecoinp'},
#    'RAW': {'USD': {'TYPE': '5',
#      'MARKET': 'CCCAGG',
#      'FROMSYMBOL': 'USDC',
#      'TOSYMBOL': 'USD',
#      'FLAGS': '2050',
#      'PRICE': 0.9999,
#      'LASTUPDATE': 1694360087,
#      'MEDIAN': 1,
#      'LASTVOLUME': 17.5322,
#      'LASTVOLUMETO': 17.53044678,
#      'LASTTRADEID': '1694360087.4414577',
#      'VOLUMEDAY': 2087013.3706750283,
#      'VOLUMEDAYTO': 2087028.3536510929,
#      'VOLUME24HOUR': 2617137.18319865,
#      'VOLUME24HOURTO': 2617170.735392511,
#      'OPENDAY': 1,
#      'HIGHDAY': 1,
#      'LOWDAY': 0.9999,
#      'OPEN24HOUR': 1,
#      'HIGH24HOUR': 1,
#      'LOW24HOUR': 0.9999,
#      'LASTMARKET': 'Kraken',
#      'VOLUMEHOUR': 734506.9237340803,
#      'VOLUMEHOURTO': 734492.1882979318,
#      'OPENHOUR': 1,
#      'HIGHHOUR': 1,
#      'LOWHOUR': 0.9999,
#      'TOPTIERVOLUME24HOUR': 2617137.18319865,
#      'TOPTIERVOLUME24HOURTO': 2617170.735392511,
#      'CHANGE24HOUR': -9.999999999998899e-05,
#      'CHANGEPCT24HOUR': -0.009999999999998899,
#      'CHANGEDAY': -9.999999999998899e-05,
#      'CHANGEPCTDAY': -0.009999999999998899,
#      'CHANGEHOUR': -9.999999999998899e-05,
#      'CHANGEPCTHOUR': -0.009999999999998899,
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 1694360087,
#      'SUPPLY': 26153521637.622272,
#      'MKTCAP': 26150906285.45851,
#      'MKTCAPPENALTY': 0,
#      'CIRCULATINGSUPPLY': 26153521637.622272,
#      'CIRCULATINGSUPPLYMKTCAP': 26150906285.45851,
#      'TOTALVOLUME24H': 118294727.81765816,
#      'TOTALVOLUME24HTO': 118283193.61078858,
#      'TOTALTOPTIERVOLUME24H': 116895147.22227055,
#      'TOTALTOPTIERVOLUME24HTO': 116883752.97346051,
#      'IMAGEURL': '/media/34835941/usdc.png'}},
#    'DISPLAY': {'USD': {'FROMSYMBOL': 'USDC',
#      'TOSYMBOL': '$',
#      'MARKET': 'CryptoCompare Index',
#      'PRICE': '$ 0.9999',
#      'LASTUPDATE': '1 min ago',
#      'LASTVOLUME': 'USDC 17.53',
#      'LASTVOLUMETO': '$ 17.53',
#      'LASTTRADEID': '1694360087.4414577',
#      'VOLUMEDAY': 'USDC 2,087,013.4',
#      'VOLUMEDAYTO': '$ 2,087,028.4',
#      'VOLUME24HOUR': 'USDC 2,617,137.2',
#      'VOLUME24HOURTO': '$ 2,617,170.7',
#      'OPENDAY': '$ 1.00',
#      'HIGHDAY': '$ 1.00',
#      'LOWDAY': '$ 0.9999',
#      'OPEN24HOUR': '$ 1.00',
#      'HIGH24HOUR': '$ 1.00',
#      'LOW24HOUR': '$ 0.9999',
#      'LASTMARKET': 'Kraken',
#      'VOLUMEHOUR': 'USDC 734,506.9',
#      'VOLUMEHOURTO': '$ 734,492.2',
#      'OPENHOUR': '$ 1.00',
#      'HIGHHOUR': '$ 1.00',
#      'LOWHOUR': '$ 0.9999',
#      'TOPTIERVOLUME24HOUR': 'USDC 2,617,137.2',
#      'TOPTIERVOLUME24HOURTO': '$ 2,617,170.7',
#      'CHANGE24HOUR': '$ -0.00010',
#      'CHANGEPCT24HOUR': '-0.01',
#      'CHANGEDAY': '$ -0.00010',
#      'CHANGEPCTDAY': '-0.01',
#      'CHANGEHOUR': '$ -0.00010',
#      'CHANGEPCTHOUR': '-0.01',
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': '1 min ago',
#      'SUPPLY': 'USDC 26,153,521,637.6',
#      'MKTCAP': '$ 26.15 B',
#      'MKTCAPPENALTY': '0 %',
#      'CIRCULATINGSUPPLY': 'USDC 26,153,521,637.6',
#      'CIRCULATINGSUPPLYMKTCAP': '$ 26.15 B',
#      'TOTALVOLUME24H': 'USDC 118.29 M',
#      'TOTALVOLUME24HTO': '$ 118.28 M',
#      'TOTALTOPTIERVOLUME24H': 'USDC 116.90 M',
#      'TOTALTOPTIERVOLUME24HTO': '$ 116.88 M',
#      'IMAGEURL': '/media/34835941/usdc.png'}}},
#   {'CoinInfo': {'Id': '938193',
#     'Name': 'STETH',
#     'FullName': 'Staked Ether',
#     'Internal': 'STETH',
#     'ImageUrl': '/media/37621928/steth.png',
#     'Url': '/coins/steth/overview',
#     'Algorithm': 'N/A',
#     'ProofType': 'N/A',
#     'Rating': {'Weiss': {'Rating': '',
#       'TechnologyAdoptionRating': '',
#       'MarketPerformanceRating': ''}},
#     'NetHashesPerSecond': 0,
#     'BlockNumber': 0,
#     'BlockTime': 0,
#     'BlockReward': 0,
#     'AssetLaunchDate': '2020-12-18',
#     'MaxSupply': -1,
#     'Type': 1,
#     'DocumentType': 'Webpagecoinp'},
#    'RAW': {'USD': {'TYPE': '5',
#      'MARKET': 'CCCAGG',
#      'FROMSYMBOL': 'STETH',
#      'TOSYMBOL': 'USD',
#      'FLAGS': '2052',
#      'PRICE': 1617.165232,
#      'LASTUPDATE': 1694360088,
#      'MEDIAN': 1616.294016,
#      'LASTVOLUME': 0.10613,
#      'LASTVOLUMETO': 171.62974607216,
#      'LASTTRADEID': '2265904664',
#      'VOLUMEDAY': 1409.7299735002252,
#      'VOLUMEDAYTO': 2279766.299652846,
#      'VOLUME24HOUR': 1535.77944964694,
#      'VOLUME24HOURTO': 2483609.129989126,
#      'OPENDAY': 1634.952944,
#      'HIGHDAY': 1635.6,
#      'LOWDAY': 1611.180024,
#      'OPEN24HOUR': 1634.513032,
#      'HIGH24HOUR': 1637.056278,
#      'LOW24HOUR': 1609.931024,
#      'LASTMARKET': 'HitBTC',
#      'VOLUMEHOUR': 441.0623442961343,
#      'VOLUMEHOURTO': 713270.688340122,
#      'OPENHOUR': 1621.383439,
#      'HIGHHOUR': 1621.61337,
#      'LOWHOUR': 1611.180024,
#      'TOPTIERVOLUME24HOUR': 0,
#      'TOPTIERVOLUME24HOURTO': 0,
#      'CHANGE24HOUR': -17.347800000000007,
#      'CHANGEPCT24HOUR': -1.0613436332638555,
#      'CHANGEDAY': -17.78771199999983,
#      'CHANGEPCTDAY': -1.0879647677492932,
#      'CHANGEHOUR': -4.218206999999893,
#      'CHANGEPCTHOUR': -0.26016097725788434,
#      'CONVERSIONTYPE': 'multiply',
#      'CONVERSIONSYMBOL': 'ETH',
#      'CONVERSIONLASTUPDATE': 1694360156,
#      'SUPPLY': 8600666.20057711,
#      'MKTCAP': 13908698351.610842,
#      'MKTCAPPENALTY': 0,
#      'CIRCULATINGSUPPLY': 8600666.20057711,
#      'CIRCULATINGSUPPLYMKTCAP': 13908698351.610842,
#      'TOTALVOLUME24H': 1573.9253396469187,
#      'TOTALVOLUME24HTO': 2545297.337040788,
#      'TOTALTOPTIERVOLUME24H': 19.943639999999995,
#      'TOTALTOPTIERVOLUME24HTO': 32252.161207524474,
#      'IMAGEURL': '/media/37621928/steth.png'}},
#    'DISPLAY': {'USD': {'FROMSYMBOL': 'STETH',
#      'TOSYMBOL': '$',
#      'MARKET': 'CryptoCompare Index',
#      'PRICE': '$ 1,617.17',
#      'LASTUPDATE': '1 min ago',
#      'LASTVOLUME': 'STETH 0.1061',
#      'LASTVOLUMETO': '$ 171.63',
#      'LASTTRADEID': '2265904664',
#      'VOLUMEDAY': 'STETH 1,409.73',
#      'VOLUMEDAYTO': '$ 2,279,766.3',
#      'VOLUME24HOUR': 'STETH 1,535.78',
#      'VOLUME24HOURTO': '$ 2,483,609.1',
#      'OPENDAY': '$ 1,634.95',
#      'HIGHDAY': '$ 1,635.60',
#      'LOWDAY': '$ 1,611.18',
#      'OPEN24HOUR': '$ 1,634.51',
#      'HIGH24HOUR': '$ 1,637.06',
#      'LOW24HOUR': '$ 1,609.93',
#      'LASTMARKET': 'HitBTC',
#      'VOLUMEHOUR': 'STETH 441.06',
#      'VOLUMEHOURTO': '$ 713,270.7',
#      'OPENHOUR': '$ 1,621.38',
#      'HIGHHOUR': '$ 1,621.61',
#      'LOWHOUR': '$ 1,611.18',
#      'TOPTIERVOLUME24HOUR': 'STETH 0',
#      'TOPTIERVOLUME24HOURTO': '$ 0',
#      'CHANGE24HOUR': '$ -17.35',
#      'CHANGEPCT24HOUR': '-1.06',
#      'CHANGEDAY': '$ -17.79',
#      'CHANGEPCTDAY': '-1.09',
#      'CHANGEHOUR': '$ -4.22',
#      'CHANGEPCTHOUR': '-0.26',
#      'CONVERSIONTYPE': 'multiply',
#      'CONVERSIONSYMBOL': 'ETH',
#      'CONVERSIONLASTUPDATE': 'Just now',
#      'SUPPLY': 'STETH 8,600,666.2',
#      'MKTCAP': '$ 13.91 B',
#      'MKTCAPPENALTY': '0 %',
#      'CIRCULATINGSUPPLY': 'STETH 8,600,666.2',
#      'CIRCULATINGSUPPLYMKTCAP': '$ 13.91 B',
#      'TOTALVOLUME24H': 'STETH 1.57 K',
#      'TOTALVOLUME24HTO': '$ 2.55 M',
#      'TOTALTOPTIERVOLUME24H': 'STETH 19.94',
#      'TOTALTOPTIERVOLUME24HTO': '$ 32.25 K',
#      'IMAGEURL': '/media/37621928/steth.png'}}},
#   {'CoinInfo': {'Id': '321992',
#     'Name': 'ADA',
#     'FullName': 'Cardano',
#     'Internal': 'ADA',
#     'ImageUrl': '/media/37746235/ada.png',
#     'Url': '/coins/ada/overview',
#     'Algorithm': 'Ouroboros',
#     'ProofType': 'PoS',
#     'Rating': {'Weiss': {'Rating': 'B-',
#       'TechnologyAdoptionRating': 'B',
#       'MarketPerformanceRating': 'D-'}},
#     'NetHashesPerSecond': 0,
#     'BlockNumber': 9272028,
#     'BlockTime': 20,
#     'BlockReward': 0,
#     'AssetLaunchDate': '2017-09-23',
#     'MaxSupply': 45000000000,
#     'Type': 1,
#     'DocumentType': 'Webpagecoinp'},
#    'RAW': {'USD': {'TYPE': '5',
#      'MARKET': 'CCCAGG',
#      'FROMSYMBOL': 'ADA',
#      'TOSYMBOL': 'USD',
#      'FLAGS': '2052',
#      'PRICE': 0.2481,
#      'LASTUPDATE': 1694360165,
#      'MEDIAN': 0.2481,
#      'LASTVOLUME': 3316.3662,
#      'LASTVOLUMETO': 822.889945206,
#      'LASTTRADEID': '298782173',
#      'VOLUMEDAY': 22119449.71154149,
#      'VOLUMEDAYTO': 5508353.381076277,
#      'VOLUME24HOUR': 26023797.4882551,
#      'VOLUME24HOURTO': 6497850.713881397,
#      'OPENDAY': 0.2532,
#      'HIGHDAY': 0.2533,
#      'LOWDAY': 0.2453,
#      'OPEN24HOUR': 0.2542,
#      'HIGH24HOUR': 0.2546,
#      'LOW24HOUR': 0.2446,
#      'LASTMARKET': 'Bitstamp',
#      'VOLUMEHOUR': 1318055.9477532986,
#      'VOLUMEHOURTO': 326330.7628288029,
#      'OPENHOUR': 0.2482,
#      'HIGHHOUR': 0.2484,
#      'LOWHOUR': 0.2465,
#      'TOPTIERVOLUME24HOUR': 26023797.4882551,
#      'TOPTIERVOLUME24HOURTO': 6497850.713881397,
#      'CHANGE24HOUR': -0.006099999999999994,
#      'CHANGEPCT24HOUR': -2.3996852871754504,
#      'CHANGEDAY': -0.005099999999999993,
#      'CHANGEPCTDAY': -2.0142180094786704,
#      'CHANGEHOUR': -0.00010000000000001674,
#      'CHANGEPCTHOUR': -0.04029008863820174,
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 1694360165,
#      'SUPPLY': 45000000000,
#      'MKTCAP': 11164500000,
#      'MKTCAPPENALTY': 0,
#      'CIRCULATINGSUPPLY': 34379580849.7657,
#      'CIRCULATINGSUPPLYMKTCAP': 8529574008.82687,
#      'TOTALVOLUME24H': 133892738.39638214,
#      'TOTALVOLUME24HTO': 33260134.95318771,
#      'TOTALTOPTIERVOLUME24H': 130884633.77165355,
#      'TOTALTOPTIERVOLUME24HTO': 32513824.19579255,
#      'IMAGEURL': '/media/37746235/ada.png'}},
#    'DISPLAY': {'USD': {'FROMSYMBOL': 'ADA',
#      'TOSYMBOL': '$',
#      'MARKET': 'CryptoCompare Index',
#      'PRICE': '$ 0.2481',
#      'LASTUPDATE': 'Just now',
#      'LASTVOLUME': 'ADA 3,316.37',
#      'LASTVOLUMETO': '$ 822.89',
#      'LASTTRADEID': '298782173',
#      'VOLUMEDAY': 'ADA 22,119,449.7',
#      'VOLUMEDAYTO': '$ 5,508,353.4',
#      'VOLUME24HOUR': 'ADA 26,023,797.5',
#      'VOLUME24HOURTO': '$ 6,497,850.7',
#      'OPENDAY': '$ 0.2532',
#      'HIGHDAY': '$ 0.2533',
#      'LOWDAY': '$ 0.2453',
#      'OPEN24HOUR': '$ 0.2542',
#      'HIGH24HOUR': '$ 0.2546',
#      'LOW24HOUR': '$ 0.2446',
#      'LASTMARKET': 'Bitstamp',
#      'VOLUMEHOUR': 'ADA 1,318,055.9',
#      'VOLUMEHOURTO': '$ 326,330.8',
#      'OPENHOUR': '$ 0.2482',
#      'HIGHHOUR': '$ 0.2484',
#      'LOWHOUR': '$ 0.2465',
#      'TOPTIERVOLUME24HOUR': 'ADA 26,023,797.5',
#      'TOPTIERVOLUME24HOURTO': '$ 6,497,850.7',
#      'CHANGE24HOUR': '$ -0.0061',
#      'CHANGEPCT24HOUR': '-2.40',
#      'CHANGEDAY': '$ -0.0051',
#      'CHANGEPCTDAY': '-2.01',
#      'CHANGEHOUR': '$ -0.00010',
#      'CHANGEPCTHOUR': '-0.04',
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 'Just now',
#      'SUPPLY': 'ADA 45,000,000,000.0',
#      'MKTCAP': '$ 11.16 B',
#      'MKTCAPPENALTY': '0 %',
#      'CIRCULATINGSUPPLY': 'ADA 34,379,580,849.8',
#      'CIRCULATINGSUPPLYMKTCAP': '$ 8.53 B',
#      'TOTALVOLUME24H': 'ADA 133.89 M',
#      'TOTALVOLUME24HTO': '$ 33.26 M',
#      'TOTALTOPTIERVOLUME24H': 'ADA 130.88 M',
#      'TOTALTOPTIERVOLUME24HTO': '$ 32.51 M',
#      'IMAGEURL': '/media/37746235/ada.png'}}},
#   {'CoinInfo': {'Id': '934443',
#     'Name': 'SOL',
#     'FullName': 'Solana',
#     'Internal': 'SOL',
#     'ImageUrl': '/media/37747734/sol.png',
#     'Url': '/coins/sol/overview',
#     'Algorithm': 'N/A',
#     'ProofType': 'PoH',
#     'Rating': {'Weiss': {'Rating': 'D+',
#       'TechnologyAdoptionRating': 'D',
#       'MarketPerformanceRating': 'C'}},
#     'NetHashesPerSecond': 0,
#     'BlockNumber': 199065692,
#     'BlockTime': 0.637,
#     'BlockReward': 0,
#     'AssetLaunchDate': '2020-03-31',
#     'MaxSupply': -1,
#     'Type': 1,
#     'DocumentType': 'Webpagecoinp'},
#    'RAW': {'USD': {'TYPE': '5',
#      'MARKET': 'CCCAGG',
#      'FROMSYMBOL': 'SOL',
#      'TOSYMBOL': 'USD',
#      'FLAGS': '2052',
#      'PRICE': 18.18,
#      'LASTUPDATE': 1694360158,
#      'MEDIAN': 18.21,
#      'LASTVOLUME': 0.43995804,
#      'LASTVOLUMETO': 7.9984371672,
#      'LASTTRADEID': '1694360158.886638',
#      'VOLUMEDAY': 1368069.9842254822,
#      'VOLUMEDAYTO': 25206051.064373165,
#      'VOLUME24HOUR': 1488783.89805586,
#      'VOLUME24HOURTO': 27555332.708767783,
#      'OPENDAY': 19.44,
#      'HIGHDAY': 19.44,
#      'LOWDAY': 17.82,
#      'OPEN24HOUR': 19.53,
#      'HIGH24HOUR': 19.57,
#      'LOW24HOUR': 17.79,
#      'LASTMARKET': 'Kraken',
#      'VOLUMEHOUR': 139510.54239369935,
#      'VOLUMEHOURTO': 2510796.070973498,
#      'OPENHOUR': 18.13,
#      'HIGHHOUR': 18.37,
#      'LOWHOUR': 17.82,
#      'TOPTIERVOLUME24HOUR': 1488783.89805586,
#      'TOPTIERVOLUME24HOURTO': 27555332.708767783,
#      'CHANGE24HOUR': -1.3500000000000014,
#      'CHANGEPCT24HOUR': -6.912442396313372,
#      'CHANGEDAY': -1.2600000000000016,
#      'CHANGEPCTDAY': -6.48148148148149,
#      'CHANGEHOUR': 0.05000000000000071,
#      'CHANGEPCTHOUR': 0.2757859900717083,
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 1694360158,
#      'SUPPLY': 557052702.5792575,
#      'MKTCAP': 10127218132.890902,
#      'MKTCAPPENALTY': 0,
#      'CIRCULATINGSUPPLY': 410610649.80558425,
#      'CIRCULATINGSUPPLYMKTCAP': 7464901613.465522,
#      'TOTALVOLUME24H': 11254902.713219542,
#      'TOTALVOLUME24HTO': 205103372.7684435,
#      'TOTALTOPTIERVOLUME24H': 11254660.794960175,
#      'TOTALTOPTIERVOLUME24HTO': 205098974.6944882,
#      'IMAGEURL': '/media/37747734/sol.png'}},
#    'DISPLAY': {'USD': {'FROMSYMBOL': 'SOL',
#      'TOSYMBOL': '$',
#      'MARKET': 'CryptoCompare Index',
#      'PRICE': '$ 18.18',
#      'LASTUPDATE': 'Just now',
#      'LASTVOLUME': 'SOL 0.4400',
#      'LASTVOLUMETO': '$ 8.00',
#      'LASTTRADEID': '1694360158.886638',
#      'VOLUMEDAY': 'SOL 1,368,070.0',
#      'VOLUMEDAYTO': '$ 25,206,051.1',
#      'VOLUME24HOUR': 'SOL 1,488,783.9',
#      'VOLUME24HOURTO': '$ 27,555,332.7',
#      'OPENDAY': '$ 19.44',
#      'HIGHDAY': '$ 19.44',
#      'LOWDAY': '$ 17.82',
#      'OPEN24HOUR': '$ 19.53',
#      'HIGH24HOUR': '$ 19.57',
#      'LOW24HOUR': '$ 17.79',
#      'LASTMARKET': 'Kraken',
#      'VOLUMEHOUR': 'SOL 139,510.5',
#      'VOLUMEHOURTO': '$ 2,510,796.1',
#      'OPENHOUR': '$ 18.13',
#      'HIGHHOUR': '$ 18.37',
#      'LOWHOUR': '$ 17.82',
#      'TOPTIERVOLUME24HOUR': 'SOL 1,488,783.9',
#      'TOPTIERVOLUME24HOURTO': '$ 27,555,332.7',
#      'CHANGE24HOUR': '$ -1.35',
#      'CHANGEPCT24HOUR': '-6.91',
#      'CHANGEDAY': '$ -1.26',
#      'CHANGEPCTDAY': '-6.48',
#      'CHANGEHOUR': '$ 0.050',
#      'CHANGEPCTHOUR': '0.28',
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 'Just now',
#      'SUPPLY': 'SOL 557,052,702.6',
#      'MKTCAP': '$ 10.13 B',
#      'MKTCAPPENALTY': '0 %',
#      'CIRCULATINGSUPPLY': 'SOL 410,610,649.8',
#      'CIRCULATINGSUPPLYMKTCAP': '$ 7.46 B',
#      'TOTALVOLUME24H': 'SOL 11.25 M',
#      'TOTALVOLUME24HTO': '$ 205.10 M',
#      'TOTALTOPTIERVOLUME24H': 'SOL 11.25 M',
#      'TOTALTOPTIERVOLUME24HTO': '$ 205.10 M',
#      'IMAGEURL': '/media/37747734/sol.png'}}},
#   {'CoinInfo': {'Id': '925144',
#     'Name': 'OKB',
#     'FullName': 'OKB',
#     'Internal': 'OKB',
#     'ImageUrl': '/media/39500812/okx.png',
#     'Url': '/coins/okb/overview',
#     'Algorithm': 'N/A',
#     'ProofType': 'N/A',
#     'Rating': {'Weiss': {'Rating': 'B-',
#       'TechnologyAdoptionRating': 'B-',
#       'MarketPerformanceRating': 'C+'}},
#     'NetHashesPerSecond': 0,
#     'BlockNumber': 0,
#     'BlockTime': 0,
#     'BlockReward': 0,
#     'AssetLaunchDate': '2019-04-26',
#     'MaxSupply': -1,
#     'Type': 1,
#     'DocumentType': 'Webpagecoinp'},
#    'RAW': {'USD': {'TYPE': '5',
#      'MARKET': 'CCCAGG',
#      'FROMSYMBOL': 'OKB',
#      'TOSYMBOL': 'USD',
#      'FLAGS': '2052',
#      'PRICE': 41.6106066,
#      'LASTUPDATE': 1694359899,
#      'MEDIAN': 41.60994048,
#      'LASTVOLUME': 1.3975,
#      'LASTVOLUMETO': 58.15082272350001,
#      'LASTTRADEID': '15832951',
#      'VOLUMEDAY': 420.7493999999998,
#      'VOLUMEDAYTO': 17507.63776058603,
#      'VOLUME24HOUR': 428.5672,
#      'VOLUME24HOURTO': 17832.94116086352,
#      'OPENDAY': 42.1248128,
#      'HIGHDAY': 42.182124,
#      'LOWDAY': 41.1341097,
#      'OPEN24HOUR': 42.21156879999999,
#      'HIGH24HOUR': 42.2730204,
#      'LOW24HOUR': 41.1022222,
#      'LASTMARKET': 'OKEX',
#      'VOLUMEHOUR': 38.1699,
#      'VOLUMEHOURTO': 1588.27269286134,
#      'OPENHOUR': 41.60096549999999,
#      'HIGHHOUR': 41.70419099999999,
#      'LOWHOUR': 41.3598555,
#      'TOPTIERVOLUME24HOUR': 428.5672,
#      'TOPTIERVOLUME24HOURTO': 17832.94116086352,
#      'CHANGE24HOUR': -0.6009621999999908,
#      'CHANGEPCT24HOUR': -1.4236907489683042,
#      'CHANGEDAY': -0.5142062000000038,
#      'CHANGEPCTDAY': -1.220672961661218,
#      'CHANGEHOUR': 0.009641100000010283,
#      'CHANGEPCTHOUR': 0.023175183277922447,
#      'CONVERSIONTYPE': 'multiply',
#      'CONVERSIONSYMBOL': 'ETH',
#      'CONVERSIONLASTUPDATE': 1694360156,
#      'SUPPLY': 235957684.8,
#      'MKTCAP': 9818342396.459599,
#      'MKTCAPPENALTY': 0,
#      'CIRCULATINGSUPPLY': 235957684.8,
#      'CIRCULATINGSUPPLYMKTCAP': 9818342396.459599,
#      'TOTALVOLUME24H': 26186.09204867732,
#      'TOTALVOLUME24HTO': 1089619.1746289,
#      'TOTALTOPTIERVOLUME24H': 24108.23321639992,
#      'TOTALTOPTIERVOLUME24HTO': 1003158.2081886696,
#      'IMAGEURL': '/media/39500812/okx.png'}},
#    'DISPLAY': {'USD': {'FROMSYMBOL': 'OKB',
#      'TOSYMBOL': '$',
#      'MARKET': 'CryptoCompare Index',
#      'PRICE': '$ 41.61',
#      'LASTUPDATE': '4 min ago',
#      'LASTVOLUME': 'OKB 1.40',
#      'LASTVOLUMETO': '$ 58.15',
#      'LASTTRADEID': '15832951',
#      'VOLUMEDAY': 'OKB 420.75',
#      'VOLUMEDAYTO': '$ 17,507.6',
#      'VOLUME24HOUR': 'OKB 428.57',
#      'VOLUME24HOURTO': '$ 17,832.9',
#      'OPENDAY': '$ 42.12',
#      'HIGHDAY': '$ 42.18',
#      'LOWDAY': '$ 41.13',
#      'OPEN24HOUR': '$ 42.21',
#      'HIGH24HOUR': '$ 42.27',
#      'LOW24HOUR': '$ 41.10',
#      'LASTMARKET': 'OKEX',
#      'VOLUMEHOUR': 'OKB 38.17',
#      'VOLUMEHOURTO': '$ 1,588.27',
#      'OPENHOUR': '$ 41.60',
#      'HIGHHOUR': '$ 41.70',
#      'LOWHOUR': '$ 41.36',
#      'TOPTIERVOLUME24HOUR': 'OKB 428.57',
#      'TOPTIERVOLUME24HOURTO': '$ 17,832.9',
#      'CHANGE24HOUR': '$ -0.60',
#      'CHANGEPCT24HOUR': '-1.42',
#      'CHANGEDAY': '$ -0.51',
#      'CHANGEPCTDAY': '-1.22',
#      'CHANGEHOUR': '$ 0.0096',
#      'CHANGEPCTHOUR': '0.02',
#      'CONVERSIONTYPE': 'multiply',
#      'CONVERSIONSYMBOL': 'ETH',
#      'CONVERSIONLASTUPDATE': 'Just now',
#      'SUPPLY': 'OKB 235,957,684.8',
#      'MKTCAP': '$ 9.82 B',
#      'MKTCAPPENALTY': '0 %',
#      'CIRCULATINGSUPPLY': 'OKB 235,957,684.8',
#      'CIRCULATINGSUPPLYMKTCAP': '$ 9.82 B',
#      'TOTALVOLUME24H': 'OKB 26.19 K',
#      'TOTALVOLUME24HTO': '$ 1.09 M',
#      'TOTALTOPTIERVOLUME24H': 'OKB 24.11 K',
#      'TOTALTOPTIERVOLUME24HTO': '$ 1.00 M',
#      'IMAGEURL': '/media/39500812/okx.png'}}},
#   {'CoinInfo': {'Id': '4432',
#     'Name': 'DOGE',
#     'FullName': 'Dogecoin',
#     'Internal': 'DOGE',
#     'ImageUrl': '/media/37746339/doge.png',
#     'Url': '/coins/doge/overview',
#     'Algorithm': 'Scrypt',
#     'ProofType': 'PoW',
#     'Rating': {'Weiss': {'Rating': 'C+',
#       'TechnologyAdoptionRating': 'B-',
#       'MarketPerformanceRating': 'E+'}},
#     'NetHashesPerSecond': 818442336390302,
#     'BlockNumber': 4877864,
#     'BlockTime': 64,
#     'BlockReward': 10000,
#     'AssetLaunchDate': '2013-12-06',
#     'MaxSupply': -1,
#     'Type': 1,
#     'DocumentType': 'Webpagecoinp'},
#    'RAW': {'USD': {'TYPE': '5',
#      'MARKET': 'CCCAGG',
#      'FROMSYMBOL': 'DOGE',
#      'TOSYMBOL': 'USD',
#      'FLAGS': '2052',
#      'PRICE': 0.06132,
#      'LASTUPDATE': 1694360139,
#      'MEDIAN': 0.06131,
#      'LASTVOLUME': 119.7,
#      'LASTVOLUMETO': 7.340004,
#      'LASTTRADEID': '59950614',
#      'VOLUMEDAY': 132284320.25883819,
#      'VOLUMEDAYTO': 8133137.291251288,
#      'VOLUME24HOUR': 147039622.945872,
#      'VOLUME24HOURTO': 9069204.13633643,
#      'OPENDAY': 0.06337,
#      'HIGHDAY': 0.0634,
#      'LOWDAY': 0.05944,
#      'OPEN24HOUR': 0.06353,
#      'HIGH24HOUR': 0.06367,
#      'LOW24HOUR': 0.05942,
#      'LASTMARKET': 'Coinbase',
#      'VOLUMEHOUR': 7867155.537896541,
#      'VOLUMEHOURTO': 480769.9665469083,
#      'OPENHOUR': 0.06138,
#      'HIGHHOUR': 0.06141,
#      'LOWHOUR': 0.06081,
#      'TOPTIERVOLUME24HOUR': 147039622.945872,
#      'TOPTIERVOLUME24HOURTO': 9069204.13633643,
#      'CHANGE24HOUR': -0.0022100000000000036,
#      'CHANGEPCT24HOUR': -3.4786714937824703,
#      'CHANGEDAY': -0.0020499999999999963,
#      'CHANGEPCTDAY': -3.2349692283414813,
#      'CHANGEHOUR': -5.9999999999997555e-05,
#      'CHANGEPCTHOUR': -0.09775171065493249,
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 1694360139,
#      'SUPPLY': 140951136383.705,
#      'MKTCAP': 8643123683.04879,
#      'MKTCAPPENALTY': 0,
#      'CIRCULATINGSUPPLY': 140951136383.705,
#      'CIRCULATINGSUPPLYMKTCAP': 8643123683.04879,
#      'TOTALVOLUME24H': 1114809102.185428,
#      'TOTALVOLUME24HTO': 68412828.603306,
#      'TOTALTOPTIERVOLUME24H': 1100207858.1639423,
#      'TOTALTOPTIERVOLUME24HTO': 67517480.3199085,
#      'IMAGEURL': '/media/37746339/doge.png'}},
#    'DISPLAY': {'USD': {'FROMSYMBOL': 'DOGE',
#      'TOSYMBOL': '$',
#      'MARKET': 'CryptoCompare Index',
#      'PRICE': '$ 0.06132',
#      'LASTUPDATE': 'Just now',
#      'LASTVOLUME': 'DOGE 119.70',
#      'LASTVOLUMETO': '$ 7.34',
#      'LASTTRADEID': '59950614',
#      'VOLUMEDAY': 'DOGE 132,284,320.3',
#      'VOLUMEDAYTO': '$ 8,133,137.3',
#      'VOLUME24HOUR': 'DOGE 147,039,622.9',
#      'VOLUME24HOURTO': '$ 9,069,204.1',
#      'OPENDAY': '$ 0.06337',
#      'HIGHDAY': '$ 0.06340',
#      'LOWDAY': '$ 0.05944',
#      'OPEN24HOUR': '$ 0.06353',
#      'HIGH24HOUR': '$ 0.06367',
#      'LOW24HOUR': '$ 0.05942',
#      'LASTMARKET': 'Coinbase',
#      'VOLUMEHOUR': 'DOGE 7,867,155.5',
#      'VOLUMEHOURTO': '$ 480,770.0',
#      'OPENHOUR': '$ 0.06138',
#      'HIGHHOUR': '$ 0.06141',
#      'LOWHOUR': '$ 0.06081',
#      'TOPTIERVOLUME24HOUR': 'DOGE 147,039,622.9',
#      'TOPTIERVOLUME24HOURTO': '$ 9,069,204.1',
#      'CHANGE24HOUR': '$ -0.0022',
#      'CHANGEPCT24HOUR': '-3.48',
#      'CHANGEDAY': '$ -0.0020',
#      'CHANGEPCTDAY': '-3.23',
#      'CHANGEHOUR': '$ -0.000060',
#      'CHANGEPCTHOUR': '-0.10',
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 'Just now',
#      'SUPPLY': 'DOGE 140,951,136,383.7',
#      'MKTCAP': '$ 8.64 B',
#      'MKTCAPPENALTY': '0 %',
#      'CIRCULATINGSUPPLY': 'DOGE 140,951,136,383.7',
#      'CIRCULATINGSUPPLYMKTCAP': '$ 8.64 B',
#      'TOTALVOLUME24H': 'DOGE 1.11 B',
#      'TOTALVOLUME24HTO': '$ 68.41 M',
#      'TOTALTOPTIERVOLUME24H': 'DOGE 1.10 B',
#      'TOTALTOPTIERVOLUME24HTO': '$ 67.52 M',
#      'IMAGEURL': '/media/37746339/doge.png'}}},
#   {'CoinInfo': {'Id': '952987',
#     'Name': 'ARB',
#     'FullName': 'Arbitrum',
#     'Internal': 'ARB',
#     'ImageUrl': '/media/44081950/arb.png',
#     'Url': '/coins/arb/overview',
#     'Algorithm': 'N/A',
#     'ProofType': 'N/A',
#     'Rating': {'Weiss': {'Rating': '',
#       'TechnologyAdoptionRating': '',
#       'MarketPerformanceRating': ''}},
#     'NetHashesPerSecond': 0,
#     'BlockNumber': 0,
#     'BlockTime': 0,
#     'BlockReward': 0,
#     'AssetLaunchDate': '2021-05-28',
#     'MaxSupply': -1,
#     'Type': 1,
#     'DocumentType': 'Webpagecoinp'},
#    'RAW': {'USD': {'TYPE': '5',
#      'MARKET': 'CCCAGG',
#      'FROMSYMBOL': 'ARB',
#      'TOSYMBOL': 'USD',
#      'FLAGS': '1026',
#      'PRICE': 0.8522,
#      'LASTUPDATE': 1694360158,
#      'MEDIAN': 0.8524,
#      'LASTVOLUME': 2,
#      'LASTVOLUMETO': 1.7042,
#      'LASTTRADEID': '2004187',
#      'VOLUMEDAY': 1843709.2485783198,
#      'VOLUMEDAYTO': 1598231.6883335588,
#      'VOLUME24HOUR': 1970286.9073542603,
#      'VOLUME24HOURTO': 1712117.3950246125,
#      'OPENDAY': 0.8978,
#      'HIGHDAY': 0.8984,
#      'LOWDAY': 0.8431,
#      'OPEN24HOUR': 0.901,
#      'HIGH24HOUR': 0.9028,
#      'LOW24HOUR': 0.8431,
#      'LASTMARKET': 'Coinbase',
#      'VOLUMEHOUR': 170858.72437839044,
#      'VOLUMEHOURTO': 145121.51003368216,
#      'OPENHOUR': 0.8517,
#      'HIGHHOUR': 0.8533,
#      'LOWHOUR': 0.8431,
#      'TOPTIERVOLUME24HOUR': 1970286.9073542603,
#      'TOPTIERVOLUME24HOURTO': 1712117.3950246125,
#      'CHANGE24HOUR': -0.048800000000000066,
#      'CHANGEPCT24HOUR': -5.4162042175360785,
#      'CHANGEDAY': -0.045600000000000085,
#      'CHANGEPCTDAY': -5.07908220093563,
#      'CHANGEHOUR': 0.0004999999999999449,
#      'CHANGEPCTHOUR': 0.05870611717740342,
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 1694360158,
#      'SUPPLY': 9999999999,
#      'MKTCAP': 8521999999.1477995,
#      'MKTCAPPENALTY': 0,
#      'CIRCULATINGSUPPLY': 1275000000,
#      'CIRCULATINGSUPPLYMKTCAP': 1086555000,
#      'TOTALVOLUME24H': 47729847.50172148,
#      'TOTALVOLUME24HTO': 40708414.93354435,
#      'TOTALTOPTIERVOLUME24H': 47729847.50172148,
#      'TOTALTOPTIERVOLUME24HTO': 40708414.93354435,
#      'IMAGEURL': '/media/44081950/arb.png'}},
#    'DISPLAY': {'USD': {'FROMSYMBOL': 'ARB',
#      'TOSYMBOL': '$',
#      'MARKET': 'CryptoCompare Index',
#      'PRICE': '$ 0.8522',
#      'LASTUPDATE': 'Just now',
#      'LASTVOLUME': 'ARB 2.00',
#      'LASTVOLUMETO': '$ 1.70',
#      'LASTTRADEID': '2004187',
#      'VOLUMEDAY': 'ARB 1,843,709.2',
#      'VOLUMEDAYTO': '$ 1,598,231.7',
#      'VOLUME24HOUR': 'ARB 1,970,286.9',
#      'VOLUME24HOURTO': '$ 1,712,117.4',
#      'OPENDAY': '$ 0.8978',
#      'HIGHDAY': '$ 0.8984',
#      'LOWDAY': '$ 0.8431',
#      'OPEN24HOUR': '$ 0.9010',
#      'HIGH24HOUR': '$ 0.9028',
#      'LOW24HOUR': '$ 0.8431',
#      'LASTMARKET': 'Coinbase',
#      'VOLUMEHOUR': 'ARB 170,858.7',
#      'VOLUMEHOURTO': '$ 145,121.5',
#      'OPENHOUR': '$ 0.8517',
#      'HIGHHOUR': '$ 0.8533',
#      'LOWHOUR': '$ 0.8431',
#      'TOPTIERVOLUME24HOUR': 'ARB 1,970,286.9',
#      'TOPTIERVOLUME24HOURTO': '$ 1,712,117.4',
#      'CHANGE24HOUR': '$ -0.049',
#      'CHANGEPCT24HOUR': '-5.42',
#      'CHANGEDAY': '$ -0.046',
#      'CHANGEPCTDAY': '-5.08',
#      'CHANGEHOUR': '$ 0.00050',
#      'CHANGEPCTHOUR': '0.06',
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 'Just now',
#      'SUPPLY': 'ARB 9,999,999,999.0',
#      'MKTCAP': '$ 8.52 B',
#      'MKTCAPPENALTY': '0 %',
#      'CIRCULATINGSUPPLY': 'ARB 1,275,000,000.0',
#      'CIRCULATINGSUPPLYMKTCAP': '$ 1.09 B',
#      'TOTALVOLUME24H': 'ARB 47.73 M',
#      'TOTALVOLUME24HTO': '$ 40.71 M',
#      'TOTALTOPTIERVOLUME24H': 'ARB 47.73 M',
#      'TOTALTOPTIERVOLUME24HTO': '$ 40.71 M',
#      'IMAGEURL': '/media/44081950/arb.png'}}},
#   {'CoinInfo': {'Id': '310829',
#     'Name': 'TRX',
#     'FullName': 'TRON',
#     'Internal': 'TRX',
#     'ImageUrl': '/media/37746879/trx.png',
#     'Url': '/coins/trx/overview',
#     'Algorithm': 'N/A',
#     'ProofType': 'DPoS',
#     'Rating': {'Weiss': {'Rating': 'C',
#       'TechnologyAdoptionRating': 'C',
#       'MarketPerformanceRating': 'D+'}},
#     'NetHashesPerSecond': 0,
#     'BlockNumber': 54576203,
#     'BlockTime': 3,
#     'BlockReward': 16,
#     'AssetLaunchDate': '2018-06-26',
#     'MaxSupply': -1,
#     'Type': 1,
#     'DocumentType': 'Webpagecoinp'},
#    'RAW': {'USD': {'TYPE': '5',
#      'MARKET': 'CCCAGG',
#      'FROMSYMBOL': 'TRX',
#      'TOSYMBOL': 'USD',
#      'FLAGS': '513',
#      'PRICE': 0.07823,
#      'LASTUPDATE': 1694360059,
#      'MEDIAN': 0.078224,
#      'LASTVOLUME': 364.0902348,
#      'LASTVOLUMETO': 28.4805945269952,
#      'LASTTRADEID': '1694360059.1946845',
#      'VOLUMEDAY': 1890269.7279192104,
#      'VOLUMEDAYTO': 147915.56940382582,
#      'VOLUME24HOUR': 2609028.29713551,
#      'VOLUME24HOURTO': 204742.31125419275,
#      'OPENDAY': 0.07917,
#      'HIGHDAY': 0.07918,
#      'LOWDAY': 0.07785,
#      'OPEN24HOUR': 0.07888,
#      'HIGH24HOUR': 0.07921,
#      'LOW24HOUR': 0.07783,
#      'LASTMARKET': 'Kraken',
#      'VOLUMEHOUR': 51620.088233359995,
#      'VOLUMEHOURTO': 4032.5918731309393,
#      'OPENHOUR': 0.07805,
#      'HIGHHOUR': 0.07823,
#      'LOWHOUR': 0.07799,
#      'TOPTIERVOLUME24HOUR': 2609028.29713551,
#      'TOPTIERVOLUME24HOURTO': 204742.31125419275,
#      'CHANGE24HOUR': -0.0006500000000000117,
#      'CHANGEPCT24HOUR': -0.8240365111562015,
#      'CHANGEDAY': -0.0009400000000000103,
#      'CHANGEPCTDAY': -1.187318428697752,
#      'CHANGEHOUR': 0.0001799999999999996,
#      'CHANGEPCTHOUR': 0.23062139654067854,
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 1694360059,
#      'SUPPLY': 89244242203.59683,
#      'MKTCAP': 6981577067.587379,
#      'MKTCAPPENALTY': 0,
#      'CIRCULATINGSUPPLY': 89244242203.59683,
#      'CIRCULATINGSUPPLYMKTCAP': 6981577067.587379,
#      'TOTALVOLUME24H': 277691914.2109427,
#      'TOTALVOLUME24HTO': 21724476.476291325,
#      'TOTALTOPTIERVOLUME24H': 248631727.43586066,
#      'TOTALTOPTIERVOLUME24HTO': 19451098.06487666,
#      'IMAGEURL': '/media/37746879/trx.png'}},
#    'DISPLAY': {'USD': {'FROMSYMBOL': 'TRX',
#      'TOSYMBOL': '$',
#      'MARKET': 'CryptoCompare Index',
#      'PRICE': '$ 0.07823',
# ...
#      'HIGHHOUR': '$ 1,915.05',
#      'LOWHOUR': '$ 1,921.24',
#      'TOPTIERVOLUME24HOUR': 'XAUT 0.1866',
#      'TOPTIERVOLUME24HOURTO': '$ 358.44',
#      'CHANGE24HOUR': '$ 1.07',
#      'CHANGEPCT24HOUR': '0.06',
#      'CHANGEDAY': '$ -0.13',
#      'CHANGEPCTDAY': '-0.01',
#      'CHANGEHOUR': '$ -0.17',
#      'CHANGEPCTHOUR': '-0.01',
#      'CONVERSIONTYPE': 'invert_divide',
#      'CONVERSIONSYMBOL': 'ETH',
#      'CONVERSIONLASTUPDATE': 'Just now',
#      'SUPPLY': 'XAUT 246,524.3',
#      'MKTCAP': '$ 473.52 M',
#      'MKTCAPPENALTY': '0 %',
#      'CIRCULATINGSUPPLY': 'XAUT 0',
#      'CIRCULATINGSUPPLYMKTCAP': '$ 0',
#      'TOTALVOLUME24H': 'XAUT 0',
#      'TOTALVOLUME24HTO': '$ 0',
#      'TOTALTOPTIERVOLUME24H': 'XAUT 0',
#      'TOTALTOPTIERVOLUME24HTO': '$ 0',
#      'IMAGEURL': '/media/37747940/xaut.png'}}},
#   {'CoinInfo': {'Id': '932177',
#     'Name': 'PAXG',
#     'FullName': 'PAX Gold',
#     'Internal': 'PAXG',
#     'ImageUrl': '/media/37747633/paxg.png',
#     'Url': '/coins/paxg/overview',
#     'Algorithm': 'N/A',
#     'ProofType': 'N/A',
#     'Rating': {'Weiss': {'Rating': '',
#       'TechnologyAdoptionRating': '',
#       'MarketPerformanceRating': ''}},
#     'NetHashesPerSecond': 0,
#     'BlockNumber': 0,
#     'BlockTime': 0,
#     'BlockReward': 0,
#     'AssetLaunchDate': '2019-08-29',
#     'MaxSupply': -1,
#     'Type': 1,
#     'DocumentType': 'Webpagecoinp'},
#    'RAW': {'USD': {'TYPE': '5',
#      'MARKET': 'CCCAGG',
#      'FROMSYMBOL': 'PAXG',
#      'TOSYMBOL': 'USD',
#      'FLAGS': '516',
#      'PRICE': 1903.30896,
#      'LASTUPDATE': 1694359567,
#      'MEDIAN': 1902.72410496,
#      'LASTVOLUME': 2.88688491,
#      'LASTVOLUMETO': 5494.633915691793,
#      'LASTTRADEID': '1694359567.5838225',
#      'VOLUMEDAY': 5.245668930000001,
#      'VOLUMEDAYTO': 9984.128675662614,
#      'VOLUME24HOUR': 5.24566893,
#      'VOLUME24HOURTO': 9984.128675662612,
#      'OPENDAY': 1898.56008,
#      'HIGHDAY': 1923.4656,
#      'LOWDAY': 1872.07767,
#      'OPEN24HOUR': 1898.04924,
#      'HIGH24HOUR': 1925.37072,
#      'LOW24HOUR': 1870.62642,
#      'LASTMARKET': 'Kraken',
#      'VOLUMEHOUR': 5.01018582,
#      'VOLUMEHOURTO': 9535.931562470947,
#      'OPENHOUR': 1897.5879,
#      'HIGHHOUR': 1907.5896,
#      'LOWHOUR': 1886.5899,
#      'TOPTIERVOLUME24HOUR': 5.24566893,
#      'TOPTIERVOLUME24HOURTO': 9984.128675662612,
#      'CHANGE24HOUR': 5.259720000000016,
#      'CHANGEPCT24HOUR': 0.2771118835673629,
#      'CHANGEDAY': 4.748880000000099,
#      'CHANGEPCTDAY': 0.25013061477623083,
#      'CHANGEHOUR': 5.7210600000000795,
#      'CHANGEPCTHOUR': 0.3014911720295054,
#      'CONVERSIONTYPE': 'multiply',
#      'CONVERSIONSYMBOL': 'ETH',
#      'CONVERSIONLASTUPDATE': 1694360156,
#      'SUPPLY': 249134.667,
#      'MKTCAP': 474180243.9477163,
#      'MKTCAPPENALTY': 0,
#      'CIRCULATINGSUPPLY': 249134.667,
#      'CIRCULATINGSUPPLYMKTCAP': 474180243.9477163,
#      'TOTALVOLUME24H': 253.04214888944125,
#      'TOTALVOLUME24HTO': 481617.38923892763,
#      'TOTALTOPTIERVOLUME24H': 239.15845499945746,
#      'TOTALTOPTIERVOLUME24HTO': 455192.4302602242,
#      'IMAGEURL': '/media/37747633/paxg.png'}},
#    'DISPLAY': {'USD': {'FROMSYMBOL': 'PAXG',
#      'TOSYMBOL': '$',
#      'MARKET': 'CryptoCompare Index',
#      'PRICE': '$ 1,903.31',
#      'LASTUPDATE': '10 min ago',
#      'LASTVOLUME': 'PAXG 2.89',
#      'LASTVOLUMETO': '$ 5,494.63',
#      'LASTTRADEID': '1694359567.5838225',
#      'VOLUMEDAY': 'PAXG 5.25',
#      'VOLUMEDAYTO': '$ 9,984.13',
#      'VOLUME24HOUR': 'PAXG 5.25',
#      'VOLUME24HOURTO': '$ 9,984.13',
#      'OPENDAY': '$ 1,898.56',
#      'HIGHDAY': '$ 1,923.47',
#      'LOWDAY': '$ 1,872.08',
#      'OPEN24HOUR': '$ 1,898.05',
#      'HIGH24HOUR': '$ 1,925.37',
#      'LOW24HOUR': '$ 1,870.63',
#      'LASTMARKET': 'Kraken',
#      'VOLUMEHOUR': 'PAXG 5.01',
#      'VOLUMEHOURTO': '$ 9,535.93',
#      'OPENHOUR': '$ 1,897.59',
#      'HIGHHOUR': '$ 1,907.59',
#      'LOWHOUR': '$ 1,886.59',
#      'TOPTIERVOLUME24HOUR': 'PAXG 5.25',
#      'TOPTIERVOLUME24HOURTO': '$ 9,984.13',
#      'CHANGE24HOUR': '$ 5.26',
#      'CHANGEPCT24HOUR': '0.28',
#      'CHANGEDAY': '$ 4.75',
#      'CHANGEPCTDAY': '0.25',
#      'CHANGEHOUR': '$ 5.72',
#      'CHANGEPCTHOUR': '0.30',
#      'CONVERSIONTYPE': 'multiply',
#      'CONVERSIONSYMBOL': 'ETH',
#      'CONVERSIONLASTUPDATE': 'Just now',
#      'SUPPLY': 'PAXG 249,134.7',
#      'MKTCAP': '$ 474.18 M',
#      'MKTCAPPENALTY': '0 %',
#      'CIRCULATINGSUPPLY': 'PAXG 249,134.7',
#      'CIRCULATINGSUPPLYMKTCAP': '$ 474.18 M',
#      'TOTALVOLUME24H': 'PAXG 253.04',
#      'TOTALVOLUME24HTO': '$ 481.62 K',
#      'TOTALTOPTIERVOLUME24H': 'PAXG 239.16',
#      'TOTALTOPTIERVOLUME24HTO': '$ 455.19 K',
#      'IMAGEURL': '/media/37747633/paxg.png'}}},
#   {'CoinInfo': {'Id': '948819',
#     'Name': 'LUNA',
#     'FullName': 'Terra',
#     'Internal': 'LUNA',
#     'ImageUrl': '/media/40219253/luna.png',
#     'Url': '/coins/luna/overview',
#     'Algorithm': 'N/A',
#     'ProofType': 'DPoS',
#     'Rating': {'Weiss': {'Rating': 'E+',
#       'TechnologyAdoptionRating': 'E',
#       'MarketPerformanceRating': 'D+'}},
#     'NetHashesPerSecond': 0,
#     'BlockNumber': 0,
#     'BlockTime': 6,
#     'BlockReward': 0,
#     'AssetLaunchDate': '2022-05-28',
#     'MaxSupply': -1,
#     'Type': 1,
#     'DocumentType': 'Webpagecoinp'},
#    'RAW': {'USD': {'TYPE': '5',
#      'MARKET': 'CCCAGG',
#      'FROMSYMBOL': 'LUNA',
#      'TOSYMBOL': 'USD',
#      'FLAGS': '2050',
#      'PRICE': 0.4048,
#      'LASTUPDATE': 1694360122,
#      'MEDIAN': 0.4046,
#      'LASTVOLUME': 0.1,
#      'LASTVOLUMETO': 0.04051,
#      'LASTTRADEID': '4611686018428817397',
#      'VOLUMEDAY': 94965.20313947607,
#      'VOLUMEDAYTO': 39302.13395471209,
#      'VOLUME24HOUR': 160230.35055763,
#      'VOLUME24HOURTO': 67449.96756958238,
#      'OPENDAY': 0.4303,
#      'HIGHDAY': 0.4374,
#      'LOWDAY': 0.3903,
#      'OPEN24HOUR': 0.4225,
#      'HIGH24HOUR': 0.4376,
#      'LOW24HOUR': 0.3902,
#      'LASTMARKET': 'cryptodotcom',
#      'VOLUMEHOUR': 2377.3091265099974,
#      'VOLUMEHOURTO': 962.1520334428951,
#      'OPENHOUR': 0.4062,
#      'HIGHHOUR': 0.4066,
#      'LOWHOUR': 0.4016,
#      'TOPTIERVOLUME24HOUR': 160230.35055763,
#      'TOPTIERVOLUME24HOURTO': 67449.96756958238,
#      'CHANGE24HOUR': -0.017699999999999994,
#      'CHANGEPCT24HOUR': -4.189349112426035,
#      'CHANGEDAY': -0.025500000000000023,
#      'CHANGEPCTDAY': -5.926098071113182,
#      'CHANGEHOUR': -0.0014000000000000123,
#      'CHANGEPCTHOUR': -0.344657804037423,
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 1694360122,
#      'SUPPLY': 1114822861.99839,
#      'MKTCAP': 451280294.53694826,
#      'MKTCAPPENALTY': 0,
#      'CIRCULATINGSUPPLY': 370814467.230636,
#      'CIRCULATINGSUPPLYMKTCAP': 150105696.33496144,
#      'TOTALVOLUME24H': 26337756.644964844,
#      'TOTALVOLUME24HTO': 10664112.611545622,
#      'TOTALTOPTIERVOLUME24H': 26305453.465395845,
#      'TOTALTOPTIERVOLUME24HTO': 10651036.284456093,
#      'IMAGEURL': '/media/40219253/luna.png'}},
#    'DISPLAY': {'USD': {'FROMSYMBOL': 'LUNA',
#      'TOSYMBOL': '$',
#      'MARKET': 'CryptoCompare Index',
#      'PRICE': '$ 0.4048',
#      'LASTUPDATE': 'Just now',
#      'LASTVOLUME': 'LUNA 0.1000',
#      'LASTVOLUMETO': '$ 0.04051',
#      'LASTTRADEID': '4611686018428817397',
#      'VOLUMEDAY': 'LUNA 94,965.2',
#      'VOLUMEDAYTO': '$ 39,302.1',
#      'VOLUME24HOUR': 'LUNA 160,230.4',
#      'VOLUME24HOURTO': '$ 67,450.0',
#      'OPENDAY': '$ 0.4303',
#      'HIGHDAY': '$ 0.4374',
#      'LOWDAY': '$ 0.3903',
#      'OPEN24HOUR': '$ 0.4225',
#      'HIGH24HOUR': '$ 0.4376',
#      'LOW24HOUR': '$ 0.3902',
#      'LASTMARKET': 'cryptodotcom',
#      'VOLUMEHOUR': 'LUNA 2,377.31',
#      'VOLUMEHOURTO': '$ 962.15',
#      'OPENHOUR': '$ 0.4062',
#      'HIGHHOUR': '$ 0.4066',
#      'LOWHOUR': '$ 0.4016',
#      'TOPTIERVOLUME24HOUR': 'LUNA 160,230.4',
#      'TOPTIERVOLUME24HOURTO': '$ 67,450.0',
#      'CHANGE24HOUR': '$ -0.018',
#      'CHANGEPCT24HOUR': '-4.19',
#      'CHANGEDAY': '$ -0.026',
#      'CHANGEPCTDAY': '-5.93',
#      'CHANGEHOUR': '$ -0.0014',
#      'CHANGEPCTHOUR': '-0.34',
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 'Just now',
#      'SUPPLY': 'LUNA 1,114,822,862.0',
#      'MKTCAP': '$ 451.28 M',
#      'MKTCAPPENALTY': '0 %',
#      'CIRCULATINGSUPPLY': 'LUNA 370,814,467.2',
#      'CIRCULATINGSUPPLYMKTCAP': '$ 150.11 M',
#      'TOTALVOLUME24H': 'LUNA 26.34 M',
#      'TOTALVOLUME24HTO': '$ 10.66 M',
#      'TOTALTOPTIERVOLUME24H': 'LUNA 26.31 M',
#      'TOTALTOPTIERVOLUME24HTO': '$ 10.65 M',
#      'IMAGEURL': '/media/40219253/luna.png'}}},
#   {'CoinInfo': {'Id': '922003',
#     'Name': 'RPL',
#     'FullName': 'RocketPool',
#     'Internal': 'RPL',
#     'ImageUrl': '/media/43961461/rpl.png',
#     'Url': '/coins/rpl/overview',
#     'Algorithm': 'N/A',
#     'ProofType': 'N/A',
#     'Rating': {'Weiss': {'Rating': '',
#       'TechnologyAdoptionRating': '',
#       'MarketPerformanceRating': ''}},
#     'NetHashesPerSecond': 0,
#     'BlockNumber': 0,
#     'BlockTime': 0,
#     'BlockReward': 0,
#     'AssetLaunchDate': '2021-09-30',
#     'MaxSupply': -1,
#     'Type': 1,
#     'DocumentType': 'Webpagecoinp'},
#    'RAW': {'USD': {'TYPE': '5',
#      'MARKET': 'CCCAGG',
#      'FROMSYMBOL': 'RPL',
#      'TOSYMBOL': 'USD',
#      'FLAGS': '513',
#      'PRICE': 23.46767,
#      'LASTUPDATE': 1694360052,
#      'MEDIAN': 23.47397568,
#      'LASTVOLUME': 11.83,
#      'LASTVOLUMETO': 277.6225361,
#      'LASTTRADEID': '16943600520001',
#      'VOLUMEDAY': 3089.970000000001,
#      'VOLUMEDAYTO': 72514.39626990003,
#      'VOLUME24HOUR': 4413.57,
#      'VOLUME24HOURTO': 103576.2042819,
#      'OPENDAY': 24.12038,
#      'HIGHDAY': 24.37044,
#      'LOWDAY': 21.5909733,
#      'OPEN24HOUR': 24.1302384,
#      'HIGH24HOUR': 24.5583,
#      'LOW24HOUR': 21.5742358,
#      'LASTMARKET': 'bilaxy',
#      'VOLUMEHOUR': 76.36000000000001,
#      'VOLUMEHOURTO': 1791.9912812,
#      'OPENHOUR': 23.7766142,
#      'HIGHHOUR': 23.861091,
#      'LOWHOUR': 23.3485656,
#      'TOPTIERVOLUME24HOUR': 0,
#      'TOPTIERVOLUME24HOURTO': 0,
#      'CHANGE24HOUR': -0.6625684000000014,
#      'CHANGEPCT24HOUR': -2.7458013013249025,
#      'CHANGEDAY': -0.6527100000000026,
#      'CHANGEPCTDAY': -2.7060518947048204,
#      'CHANGEHOUR': -0.30894420000000267,
#      'CHANGEPCTHOUR': -1.2993616223120728,
#      'CONVERSIONTYPE': 'multiply',
#      'CONVERSIONSYMBOL': 'ETH',
#      'CONVERSIONLASTUPDATE': 1694360156,
#      'SUPPLY': 19694369.8469077,
#      'MKTCAP': 462180972.42518044,
#      'MKTCAPPENALTY': 0,
#      'CIRCULATINGSUPPLY': 19694369.8469077,
#      'CIRCULATINGSUPPLYMKTCAP': 462180972.42518044,
#      'TOTALVOLUME24H': 21105.991290415546,
#      'TOTALVOLUME24HTO': 495308.4386263462,
#      'TOTALTOPTIERVOLUME24H': 14750.439503949767,
#      'TOTALTOPTIERVOLUME24HTO': 346158.4466336568,
#      'IMAGEURL': '/media/43961461/rpl.png'}},
#    'DISPLAY': {'USD': {'FROMSYMBOL': 'RPL',
#      'TOSYMBOL': '$',
#      'MARKET': 'CryptoCompare Index',
#      'PRICE': '$ 23.47',
#      'LASTUPDATE': '1 min ago',
#      'LASTVOLUME': 'RPL 11.83',
#      'LASTVOLUMETO': '$ 277.62',
#      'LASTTRADEID': '16943600520001',
#      'VOLUMEDAY': 'RPL 3,089.97',
#      'VOLUMEDAYTO': '$ 72,514.4',
#      'VOLUME24HOUR': 'RPL 4,413.57',
#      'VOLUME24HOURTO': '$ 103,576.2',
#      'OPENDAY': '$ 24.12',
#      'HIGHDAY': '$ 24.37',
#      'LOWDAY': '$ 21.59',
#      'OPEN24HOUR': '$ 24.13',
#      'HIGH24HOUR': '$ 24.56',
#      'LOW24HOUR': '$ 21.57',
#      'LASTMARKET': 'bilaxy',
#      'VOLUMEHOUR': 'RPL 76.36',
#      'VOLUMEHOURTO': '$ 1,791.99',
#      'OPENHOUR': '$ 23.78',
#      'HIGHHOUR': '$ 23.86',
#      'LOWHOUR': '$ 23.35',
#      'TOPTIERVOLUME24HOUR': 'RPL 0',
#      'TOPTIERVOLUME24HOURTO': '$ 0',
#      'CHANGE24HOUR': '$ -0.66',
#      'CHANGEPCT24HOUR': '-2.75',
#      'CHANGEDAY': '$ -0.65',
#      'CHANGEPCTDAY': '-2.71',
#      'CHANGEHOUR': '$ -0.31',
#      'CHANGEPCTHOUR': '-1.30',
#      'CONVERSIONTYPE': 'multiply',
#      'CONVERSIONSYMBOL': 'ETH',
#      'CONVERSIONLASTUPDATE': 'Just now',
#      'SUPPLY': 'RPL 19,694,369.8',
#      'MKTCAP': '$ 462.18 M',
#      'MKTCAPPENALTY': '0 %',
#      'CIRCULATINGSUPPLY': 'RPL 19,694,369.8',
#      'CIRCULATINGSUPPLYMKTCAP': '$ 462.18 M',
#      'TOTALVOLUME24H': 'RPL 21.11 K',
#      'TOTALVOLUME24HTO': '$ 495.31 K',
#      'TOTALTOPTIERVOLUME24H': 'RPL 14.75 K',
#      'TOTALTOPTIERVOLUME24HTO': '$ 346.16 K',
#      'IMAGEURL': '/media/43961461/rpl.png'}}},
#   {'CoinInfo': {'Id': '886955',
#     'Name': 'VRA',
#     'FullName': 'Verasity',
#     'Internal': 'VRA',
#     'ImageUrl': '/media/38553416/vra.png',
#     'Url': '/coins/vra/overview',
#     'Algorithm': 'N/A',
#     'ProofType': 'PoW',
#     'Rating': {'Weiss': {'Rating': 'C-',
#       'TechnologyAdoptionRating': 'C',
#       'MarketPerformanceRating': 'D+'}},
#     'NetHashesPerSecond': 0,
#     'BlockNumber': 0,
#     'BlockTime': 0,
#     'BlockReward': 0,
#     'AssetLaunchDate': '2018-05-18',
#     'MaxSupply': -1,
#     'Type': 1,
#     'DocumentType': 'Webpagecoinp'},
#    'RAW': {'USD': {'TYPE': '5',
#      'MARKET': 'CCCAGG',
#      'FROMSYMBOL': 'VRA',
#      'TOSYMBOL': 'USD',
#      'FLAGS': '2052',
#      'PRICE': 0.004085,
#      'LASTUPDATE': 1694360154,
#      'MEDIAN': 0.00409,
#      'LASTVOLUME': 100,
#      'LASTVOLUMETO': 0.40854,
#      'LASTTRADEID': '4611686018428571483',
#      'VOLUMEDAY': 3622146.65999805,
#      'VOLUMEDAYTO': 14804.383877251303,
#      'VOLUME24HOUR': 4550429.76550157,
#      'VOLUME24HOURTO': 18625.009888186145,
#      'OPENDAY': 0.004117,
#      'HIGHDAY': 0.00414,
#      'LOWDAY': 0.00405,
#      'OPEN24HOUR': 0.00412,
#      'HIGH24HOUR': 0.004141,
#      'LOW24HOUR': 0.00405,
#      'LASTMARKET': 'cryptodotcom',
#      'VOLUMEHOUR': 23231.92865648,
#      'VOLUMEHOURTO': 94.92666869109173,
#      'OPENHOUR': 0.004088,
#      'HIGHHOUR': 0.0041,
#      'LOWHOUR': 0.004069,
#      'TOPTIERVOLUME24HOUR': 4550429.76550157,
#      'TOPTIERVOLUME24HOURTO': 18625.009888186145,
#      'CHANGE24HOUR': -3.500000000000031e-05,
#      'CHANGEPCT24HOUR': -0.8495145631068035,
#      'CHANGEDAY': -3.199999999999991e-05,
#      'CHANGEPCTDAY': -0.7772649987855212,
#      'CHANGEHOUR': -2.999999999999531e-06,
#      'CHANGEPCTHOUR': -0.07338551859098656,
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 1694360154,
#      'SUPPLY': 110305680354,
#      'MKTCAP': 450598704.24609,
#      'MKTCAPPENALTY': 0,
#      'CIRCULATINGSUPPLY': 10305680354,
#      'CIRCULATINGSUPPLYMKTCAP': 42098704.24609,
#      'TOTALVOLUME24H': 84807799.10042092,
#      'TOTALVOLUME24HTO': 346476.3636213317,
#      'TOTALTOPTIERVOLUME24H': 76677528.70733652,
#      'TOTALTOPTIERVOLUME24HTO': 313264.20906558185,
#      'IMAGEURL': '/media/38553416/vra.png'}},
#    'DISPLAY': {'USD': {'FROMSYMBOL': 'VRA',
#      'TOSYMBOL': '$',
#      'MARKET': 'CryptoCompare Index',
#      'PRICE': '$ 0.004085',
#      'LASTUPDATE': 'Just now',
#      'LASTVOLUME': 'VRA 100.00',
#      'LASTVOLUMETO': '$ 0.4085',
#      'LASTTRADEID': '4611686018428571483',
#      'VOLUMEDAY': 'VRA 3,622,146.7',
#      'VOLUMEDAYTO': '$ 14,804.4',
#      'VOLUME24HOUR': 'VRA 4,550,429.8',
#      'VOLUME24HOURTO': '$ 18,625.0',
#      'OPENDAY': '$ 0.004117',
#      'HIGHDAY': '$ 0.004140',
#      'LOWDAY': '$ 0.004050',
#      'OPEN24HOUR': '$ 0.004120',
#      'HIGH24HOUR': '$ 0.004141',
#      'LOW24HOUR': '$ 0.004050',
#      'LASTMARKET': 'cryptodotcom',
#      'VOLUMEHOUR': 'VRA 23,231.9',
#      'VOLUMEHOURTO': '$ 94.93',
#      'OPENHOUR': '$ 0.004088',
#      'HIGHHOUR': '$ 0.004100',
#      'LOWHOUR': '$ 0.004069',
#      'TOPTIERVOLUME24HOUR': 'VRA 4,550,429.8',
#      'TOPTIERVOLUME24HOURTO': '$ 18,625.0',
#      'CHANGE24HOUR': '$ -0.000035',
#      'CHANGEPCT24HOUR': '-0.85',
#      'CHANGEDAY': '$ -0.000032',
#      'CHANGEPCTDAY': '-0.78',
#      'CHANGEHOUR': '$ -0.0000030',
#      'CHANGEPCTHOUR': '-0.07',
#      'CONVERSIONTYPE': 'direct',
#      'CONVERSIONSYMBOL': '',
#      'CONVERSIONLASTUPDATE': 'Just now',
#      'SUPPLY': 'VRA 110,305,680,354.0',
#      'MKTCAP': '$ 450.60 M',
#      'MKTCAPPENALTY': '0 %',
#      'CIRCULATINGSUPPLY': 'VRA 10,305,680,354.0',
#      'CIRCULATINGSUPPLYMKTCAP': '$ 42.10 M',
#      'TOTALVOLUME24H': 'VRA 84.81 M',
#      'TOTALVOLUME24HTO': '$ 346.48 K',
#      'TOTALTOPTIERVOLUME24H': 'VRA 76.68 M',
#      'TOTALTOPTIERVOLUME24HTO': '$ 313.26 K',
#      'IMAGEURL': '/media/38553416/vra.png'}}}],
#  'RateLimit': {},
#  'HasWarning': False}

# %%
len(data['Data'])
# Out:
# 100

# %%
currencies = []

# %%
i = 0

# %%
for d in data['Data']:
    print(i, d['CoinInfo']['Name'])
    currency = {}
    currency['id'] = d['CoinInfo']['Id']
    currency['name'] = d['CoinInfo']['Name']
    currency['fullname'] = d['CoinInfo']['FullName']
    currency['internal'] = d['CoinInfo']['Internal']
    try: 
        currency['marketcap'] = d['RAW']['USD']['MKTCAP']
    except:
        currency['marketcap'] = 0
    currencies.append(currency)
    i = i + 1
# Out:
# 0 BTC
# 1 ETH
# 2 USDT
# 3 XRP
# 4 BNB
# 5 USDC
# 6 STETH
# 7 ADA
# 8 SOL
# 9 OKB
# 10 DOGE
# 11 ARB
# 12 TRX
# 13 XLM
# 14 LINK
# 15 APT
# 16 OP
# 17 MATIC
# 18 DOT
# 19 LTC
# 20 SHIB
# 21 UNI
# 22 WBTC
# 23 AVAX
# 24 DAI
# 25 BCH
# 26 LEO
# 27 TUSD
# 28 XMR
# 29 BUSD
# 30 MANTLE
# 31 ATOM
# 32 HBAR
# 33 ETC
# 34 CBETH
# 35 XDC
# 36 DYDX
# 37 CRO
# 38 ICP
# 39 LDO
# 40 QNT
# 41 FIL
# 42 NEAR
# 43 VET
# 44 FLR
# 45 APE
# 46 SEI
# 47 AXS
# 48 MKR
# 49 MX
# 50 FTN
# 51 IMX
# 52 ALGO
# 53 GRT
# 54 SAND
# 55 AAVE
# 56 CRV
# 57 GMT
# 58 XCH
# 59 KAS
# 60 RNDR
# 61 TWT
# 62 KLAY
# 63 RUNE
# 64 ENS
# 65 XRD
# 66 NEO
# 67 SNX
# 68 INJ
# 69 XTZ
# 70 EOS
# 71 CFX
# 72 STX
# 73 IOST
# 74 MANA
# 75 EGLD
# 76 LYXE
# 77 FLOW
# 78 FTM
# 79 THETA
# 80 KCS
# 81 NEXO
# 82 BSV
# 83 BLUR
# 84 GT
# 85 STG
# 86 USDP
# 87 FXS
# 88 CHZ
# 89 WEMIX
# 90 KAVA
# 91 CAKE
# 92 ASTR
# 93 HT
# 94 MIOTA
# 95 XAUT
# 96 PAXG
# 97 LUNA
# 98 RPL
# 99 VRA

# %%
df_currencies = pd.DataFrame(currencies)

# %%
df_currencies
# Out:
#         id    name                     fullname internal     marketcap
# 0     1182     BTC                      Bitcoin      BTC  5.019685e+11
# 1     7605     ETH                     Ethereum      ETH  1.945722e+11
# 2   171986    USDT                       Tether     USDT  8.630609e+10
# 3     5031     XRP                          XRP      XRP  4.961426e+10
# 4   204788     BNB                 Binance Coin      BNB  3.358295e+10
# 5   925809    USDC                     USD Coin     USDC  2.615091e+10
# 6   938193   STETH                 Staked Ether    STETH  1.390870e+10
# 7   321992     ADA                      Cardano      ADA  1.116450e+10
# 8   934443     SOL                       Solana      SOL  1.012722e+10
# 9   925144     OKB                          OKB      OKB  9.818342e+09
# 10    4432    DOGE                     Dogecoin     DOGE  8.643124e+09
# 11  952987     ARB                     Arbitrum      ARB  8.522000e+09
# 12  310829     TRX                         TRON      TRX  6.981577e+09
# 13    4614     XLM                      Stellar      XLM  6.505233e+09
# 14  309621    LINK                    Chainlink     LINK  6.013000e+09
# 15  951233     APT                        Aptos      APT  5.478917e+09
# 16  948958      OP                     Optimism       OP  5.415954e+09
# 17  930246   MATIC                      Polygon    MATIC  5.200388e+09
# 18  935731     DOT                     Polkadot      DOT  5.096221e+09
# 19    3808     LTC                     Litecoin      LTC  4.481653e+09
# 20  940776    SHIB                    Shiba Inu     SHIB  4.333618e+09
# 21  936630     UNI       Uniswap Protocol Token      UNI  4.204000e+09
# 22  928761    WBTC              Wrapped Bitcoin     WBTC  4.196694e+09
# 23  935805    AVAX                    Avalanche     AVAX  4.116936e+09
# 24  932637     DAI                          Dai      DAI  3.824696e+09
# 25  202330     BCH                 Bitcoin Cash      BCH  3.678148e+09
# 26  930571     LEO                    LEO Token      LEO  3.599423e+09
# 27  844139    TUSD                     True USD     TUSD  3.033758e+09
# 28    5038     XMR                       Monero      XMR  2.618404e+09
# 29  932135    BUSD                  Binance USD     BUSD  2.583266e+09
# 30  953741  MANTLE                       Mantle   MANTLE  2.552770e+09
# 31  199107    ATOM                       Cosmos     ATOM  2.422913e+09
# 32  932121    HBAR             Hedera Hashgraph     HBAR  2.379000e+09
# 33    5324     ETC             Ethereum Classic      ETC  2.144057e+09
# 34  950787   CBETH  Coinbase Wrapped Staked ETH    CBETH  2.140574e+09
# 35  933001     XDC               Xinfin Network      XDC  2.035062e+09
# 36  943395    DYDX                         dYdX     DYDX  1.942527e+09
# 37  929418     CRO                       Cronos      CRO  1.576400e+09
# 38  941276     ICP            Internet Computer      ICP  1.558339e+09
# 39  938419     LDO                     Lido DAO      LDO  1.475000e+09
# 40  928790     QNT                        Quant      QNT  1.450998e+09
# 41  213663     FIL                     FileCoin      FIL  1.388145e+09
# 42  937105    NEAR                         Near     NEAR  1.309793e+09
# 43  236131     VET                      VeChain      VET  1.307158e+09
# 44  938073     FLR                        Flare      FLR  1.260864e+09
# 45  947197     APE                      ApeCoin      APE  1.253000e+09
# 46  953255     SEI                          Sei      SEI  1.199000e+09
# 47  937569     AXS         Axie Infinity Shards      AXS  1.188000e+09
# 48   41192     MKR                        Maker      MKR  1.095529e+09
# 49  932263      MX                     MX Token       MX  1.047546e+09
# 50  952545     FTN                    Fasttoken      FTN  0.000000e+00
# 51  944525     IMX                  Immutable X      IMX  1.024800e+09
# 52  930992    ALGO                     Algorand     ALGO  9.085000e+08
# 53  938098     GRT                    The Graph      GRT  9.005279e+08
# 54  936179    SAND                  The Sandbox     SAND  8.814000e+08
# 55  936952    AAVE                         Aave     AAVE  8.700800e+08
# 56  936137     CRV              Curve DAO Token      CRV  8.586179e+08
# 57  947549     GMT                        STEPN      GMT  8.201195e+08
# 58  941178     XCH                         Chia      XCH  8.195486e+08
# 59  952198     KAS                        Kaspa      KAS  0.000000e+00
# 60  348131    RNDR                 Render Token     RNDR  7.843228e+08
# 61  934995     TWT           Trust Wallet Token      TWT  7.680280e+08
# 62  932843    KLAY                       Klaytn     KLAY  7.565966e+08
# 63  932760    RUNE                    Thorchain     RUNE  7.444158e+08
# 64  944364     ENS        Ethereum Name Service      ENS  7.391000e+08
# 65  943104     XRD                        Radix      XRD  7.391593e+08
# 66   27368     NEO                          NEO      NEO  7.101802e+08
# 67  816635     SNX                    Synthetix      SNX  6.955914e+08
# 68  937043     INJ                    Injective      INJ  6.618000e+08
# 69  166390     XTZ                        Tezos      XTZ  6.583808e+08
# 70  166503     EOS                          EOS      EOS  6.569720e+08
# 71  937778     CFX              Conflux Network      CFX  6.522840e+08
# 72  932603     STX                       Stacks      STX  6.320276e+08
# 73  716522    IOST                    IOS token     IOST  6.205176e+08
# 74  199148    MANA                 Decentraland     MANA  6.189152e+08
# 75  936373    EGLD                        eGold     EGLD  6.126469e+08
# 76  934997    LYXE                        LUKSO     LYXE  6.119397e+08
# 77  938812    FLOW                         Flow     FLOW  6.100926e+08
# 78  928158     FTM                       Fantom      FTM  6.086475e+08
# 79  714811   THETA                Theta Network    THETA  6.076000e+08
# 80  348628     KCS                 KuCoin Token      KCS  5.912917e+08
# 81  877073    NEXO                         NEXO     NEXO  5.689214e+08
# 82  926591     BSV                   Bitcoin SV      BSV  5.659449e+08
# 83  952688    BLUR                         Blur     BLUR  5.328000e+08
# 84  931795      GT              Gatechain Token       GT  5.284419e+08
# 85  947592     STG             Stargate Finance      STG  5.250284e+08
# 86  925939    USDP                   Pax Dollar     USDP  5.202659e+08
# 87  938354     FXS                   Frax Share      FXS  5.156123e+08
# 88  931799     CHZ                       Chiliz      CHZ  5.093333e+08
# 89  937519   WEMIX                        WEMIX    WEMIX  4.893744e+08
# 90  932609    KAVA                         Kava     KAVA  4.864760e+08
# 91  936880    CAKE                  PancakeSwap     CAKE  4.841063e+08
# 92  946030    ASTR                        Astar     ASTR  4.813969e+08
# 93  771595      HT                  Huobi Token       HT  4.829043e+08
# 94  127356   MIOTA                         IOTA    MIOTA  4.766894e+08
# 95  934021    XAUT                  Tether Gold     XAUT  4.735222e+08
# 96  932177    PAXG                     PAX Gold     PAXG  4.741802e+08
# 97  948819    LUNA                        Terra     LUNA  4.512803e+08
# 98  922003     RPL                   RocketPool      RPL  4.621810e+08
# 99  886955     VRA                     Verasity      VRA  4.505987e+08

# %%
df_currencies.to_csv("100_currencies_new.csv", index=False)

# %% [markdown]
# ## Price data for all currencies

# %%
df = pd.read_csv("100_currencies_new.csv")

# %%
df.head(5)
# Out:
#        id  name      fullname internal     marketcap
# 0    1182   BTC       Bitcoin      BTC  5.019685e+11
# 1    7605   ETH      Ethereum      ETH  1.945722e+11
# 2  171986  USDT        Tether     USDT  8.630609e+10
# 3    5031   XRP           XRP      XRP  4.961426e+10
# 4  204788   BNB  Binance Coin      BNB  3.358295e+10

# %%
name_fullname = dict(zip(df['name'], df['fullname']))

# %% [markdown]
# #### Test with one currency

# %%
date1 = pd.to_datetime("2017-09-05")
date2 = pd.to_datetime("2022-09-05")
date2 - date1
# Out:
# Timedelta('1826 days 00:00:00')

# %%
currency = 'BTC'

# %%
url = "https://min-api.cryptocompare.com/data/v2/histoday"
    
parameters = {
    'fsym': currency,
    'tsym': 'USD',    
    'limit': '1826',
    'api_key': key
}
headers = {
    #'Accepts': 'application/json',
    #'X-CMC_PRO_API_KEY': 'b54bcf4d-1bca-4e8e-9a24-22ff2c3d462c',
    #'X-CMC_PRO_API_KEY': 'f2245cf9-126f-4e79-aa3f-5c3d88769399',
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    
    if data['Response'] != "Error":
        print("Success")

except (ConnectionError, Timeout, TooManyRedirects) as e:
    data = ""
    #print(e)
# Out:
# Success

# %%
data
# Out:
# {'Response': 'Success',
#  'Message': '',
#  'HasWarning': False,
#  'Type': 100,
#  'RateLimit': {},
#  'Data': {'Aggregated': False,
#   'TimeFrom': 1536537600,
#   'TimeTo': 1694304000,
#   'Data': [{'time': 1536537600,
#     'high': 6371.42,
#     'low': 6247.64,
#     'open': 6249.07,
#     'volumefrom': 50695.88,
#     'volumeto': 320435279.61,
#     'close': 6324.43,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1536624000,
#     'high': 6415.51,
#     'low': 6199.19,
#     'open': 6324.43,
#     'volumefrom': 51401.22,
#     'volumeto': 324512939.85,
#     'close': 6295.54,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1536710400,
#     'high': 6357.89,
#     'low': 6208.28,
#     'open': 6295.54,
#     'volumefrom': 52814.83,
#     'volumeto': 332537236.17,
#     'close': 6337.11,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1536796800,
#     'high': 6534.89,
#     'low': 6337.08,
#     'open': 6337.08,
#     'volumefrom': 65684.53,
#     'volumeto': 425090869.76,
#     'close': 6492,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1536883200,
#     'high': 6591.59,
#     'low': 6393.84,
#     'open': 6492.17,
#     'volumefrom': 58029.07,
#     'volumeto': 377989402.01,
#     'close': 6486.01,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1536969600,
#     'high': 6573.19,
#     'low': 6473.47,
#     'open': 6485.39,
#     'volumefrom': 31894.67,
#     'volumeto': 208349557,
#     'close': 6522.08,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1537056000,
#     'high': 6525.05,
#     'low': 6404.31,
#     'open': 6522.68,
#     'volumefrom': 30897.54,
#     'volumeto': 200545603.1,
#     'close': 6502.44,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1537142400,
#     'high': 6538.82,
#     'low': 6216.83,
#     'open': 6502.44,
#     'volumefrom': 62738.57,
#     'volumeto': 399675966.34,
#     'close': 6261.48,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1537228800,
#     'high': 6393.39,
#     'low': 6238.25,
#     'open': 6261.33,
#     'volumefrom': 55076.95,
#     'volumeto': 348485895.37,
#     'close': 6346.44,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1537315200,
#     'high': 6522.9,
#     'low': 6131.02,
#     'open': 6346.44,
#     'volumefrom': 71293.01,
#     'volumeto': 452379323.08,
#     'close': 6398.8,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1537401600,
#     'high': 6551.93,
#     'low': 6361.33,
#     'open': 6398.83,
#     'volumefrom': 46802.06,
#     'volumeto': 301619960.91,
#     'close': 6505.9,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1537488000,
#     'high': 6785.22,
#     'low': 6501.01,
#     'open': 6505.97,
#     'volumefrom': 85295.46,
#     'volumeto': 569642976.25,
#     'close': 6762.06,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1537574400,
#     'high': 6834.49,
#     'low': 6633.01,
#     'open': 6762.07,
#     'volumefrom': 38829.87,
#     'volumeto': 261159308.22,
#     'close': 6716.6,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1537660800,
#     'high': 6768.56,
#     'low': 6663.9,
#     'open': 6716.6,
#     'volumefrom': 25143.83,
#     'volumeto': 169080003.37,
#     'close': 6702.7,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1537747200,
#     'high': 6717.6,
#     'low': 6557.82,
#     'open': 6702.73,
#     'volumefrom': 48934.13,
#     'volumeto': 324660682.66,
#     'close': 6583.53,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1537833600,
#     'high': 6583.54,
#     'low': 6333.21,
#     'open': 6583.53,
#     'volumefrom': 65381.85,
#     'volumeto': 420279170.44,
#     'close': 6437.74,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1537920000,
#     'high': 6543.92,
#     'low': 6383.16,
#     'open': 6437.74,
#     'volumefrom': 40752.6,
#     'volumeto': 264402806.65,
#     'close': 6462.6,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1538006400,
#     'high': 6733.94,
#     'low': 6434.76,
#     'open': 6462.6,
#     'volumefrom': 52542,
#     'volumeto': 345096700.08,
#     'close': 6686.13,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1538092800,
#     'high': 6806.1,
#     'low': 6545.41,
#     'open': 6686.13,
#     'volumefrom': 74353.41,
#     'volumeto': 497340510.07,
#     'close': 6635.38,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1538179200,
#     'high': 6635.42,
#     'low': 6474.23,
#     'open': 6635.4,
#     'volumefrom': 37296.34,
#     'volumeto': 245055396.51,
#     'close': 6603.75,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1538265600,
#     'high': 6741.96,
#     'low': 6543.68,
#     'open': 6603.75,
#     'volumefrom': 26335.14,
#     'volumeto': 174302164.09,
#     'close': 6623.71,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1538352000,
#     'high': 6662.6,
#     'low': 6510.54,
#     'open': 6623.82,
#     'volumefrom': 38926.98,
#     'volumeto': 256959931.63,
#     'close': 6594.98,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1538438400,
#     'high': 6618.95,
#     'low': 6478.04,
#     'open': 6594.98,
#     'volumefrom': 40624.2,
#     'volumeto': 267166277.79,
#     'close': 6525.47,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1538524800,
#     'high': 6537.07,
#     'low': 6428.98,
#     'open': 6525.46,
#     'volumefrom': 47186,
#     'volumeto': 306385346.59,
#     'close': 6492.26,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1538611200,
#     'high': 6622.32,
#     'low': 6486.86,
#     'open': 6492.61,
#     'volumefrom': 42142.96,
#     'volumeto': 277614018.45,
#     'close': 6579.79,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1538697600,
#     'high': 6683.55,
#     'low': 6546.98,
#     'open': 6580,
#     'volumefrom': 39731.28,
#     'volumeto': 262562344.98,
#     'close': 6632.87,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1538784000,
#     'high': 6637.08,
#     'low': 6563.25,
#     'open': 6632.88,
#     'volumefrom': 24787.61,
#     'volumeto': 162722103.98,
#     'close': 6589.94,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1538870400,
#     'high': 6622.49,
#     'low': 6535.02,
#     'open': 6589.94,
#     'volumefrom': 27272.67,
#     'volumeto': 179378859.39,
#     'close': 6601.15,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1538956800,
#     'high': 6698.31,
#     'low': 6565.01,
#     'open': 6601.46,
#     'volumefrom': 47216.82,
#     'volumeto': 313507433.75,
#     'close': 6650.07,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1539043200,
#     'high': 6657,
#     'low': 6589.39,
#     'open': 6650.07,
#     'volumefrom': 32204.25,
#     'volumeto': 213976678.23,
#     'close': 6631.79,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1539129600,
#     'high': 6633.22,
#     'low': 6487.86,
#     'open': 6631.79,
#     'volumefrom': 49264.39,
#     'volumeto': 323664963.18,
#     'close': 6581.07,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1539216000,
#     'high': 6581.59,
#     'low': 6171.95,
#     'open': 6581.07,
#     'volumefrom': 104258.49,
#     'volumeto': 654924117.8,
#     'close': 6209.47,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1539302400,
#     'high': 6296.56,
#     'low': 6173.86,
#     'open': 6209.47,
#     'volumefrom': 46195.91,
#     'volumeto': 289840137.45,
#     'close': 6250.85,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1539388800,
#     'high': 6280.73,
#     'low': 6238.92,
#     'open': 6252.1,
#     'volumefrom': 21914.85,
#     'volumeto': 137705035.59,
#     'close': 6267.27,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1539475200,
#     'high': 6346.56,
#     'low': 6247.17,
#     'open': 6267.27,
#     'volumefrom': 34130.1,
#     'volumeto': 215422888.18,
#     'close': 6277.73,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1539561600,
#     'high': 7234.83,
#     'low': 6244.77,
#     'open': 6277.73,
#     'volumefrom': 177320.05,
#     'volumeto': 1190524168.21,
#     'close': 6612.36,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1539648000,
#     'high': 6724.91,
#     'low': 6545.54,
#     'open': 6612.69,
#     'volumefrom': 49191.34,
#     'volumeto': 324232509.78,
#     'close': 6583.05,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1539734400,
#     'high': 6589.2,
#     'low': 6511.6,
#     'open': 6583.05,
#     'volumefrom': 33538.55,
#     'volumeto': 220418636.64,
#     'close': 6574.52,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1539820800,
#     'high': 6616.27,
#     'low': 6445.05,
#     'open': 6576.4,
#     'volumefrom': 50725.31,
#     'volumeto': 331761115.45,
#     'close': 6488.72,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1539907200,
#     'high': 6503.09,
#     'low': 6449.36,
#     'open': 6489.37,
#     'volumefrom': 36599.64,
#     'volumeto': 237855085.41,
#     'close': 6469.28,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1539993600,
#     'high': 6645.2,
#     'low': 6395.45,
#     'open': 6469.28,
#     'volumefrom': 19543.75,
#     'volumeto': 127185847.78,
#     'close': 6490.56,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1540080000,
#     'high': 6557.39,
#     'low': 6474.47,
#     'open': 6490.6,
#     'volumefrom': 16019.49,
#     'volumeto': 105283929.06,
#     'close': 6509.87,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1540166400,
#     'high': 6531.23,
#     'low': 6460.38,
#     'open': 6509.87,
#     'volumefrom': 31239.03,
#     'volumeto': 202766914.4,
#     'close': 6483.23,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1540252800,
#     'high': 6496.2,
#     'low': 6438.99,
#     'open': 6484.32,
#     'volumefrom': 34071.62,
#     'volumeto': 220913293.6,
#     'close': 6470.22,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1540339200,
#     'high': 6538.35,
#     'low': 6465.73,
#     'open': 6470.63,
#     'volumefrom': 34111.66,
#     'volumeto': 222068131.83,
#     'close': 6476.25,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1540425600,
#     'high': 6497.9,
#     'low': 6432.3,
#     'open': 6476.52,
#     'volumefrom': 35706.92,
#     'volumeto': 231214963.95,
#     'close': 6462.77,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1540512000,
#     'high': 6514,
#     'low': 6441.81,
#     'open': 6462.77,
#     'volumefrom': 33284.54,
#     'volumeto': 215447656.36,
#     'close': 6457.21,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1540598400,
#     'high': 6479,
#     'low': 6445.95,
#     'open': 6457.21,
#     'volumefrom': 19092.86,
#     'volumeto': 124066466.34,
#     'close': 6470.17,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1540684800,
#     'high': 6483.24,
#     'low': 6444.74,
#     'open': 6470.17,
#     'volumefrom': 16806.73,
#     'volumeto': 109118160.99,
#     'close': 6470.74,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1540771200,
#     'high': 6483.39,
#     'low': 6282.58,
#     'open': 6470.74,
#     'volumefrom': 53760.53,
#     'volumeto': 342463526.52,
#     'close': 6313.91,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1540857600,
#     'high': 6340.68,
#     'low': 6286.3,
#     'open': 6314.38,
#     'volumefrom': 42701.22,
#     'volumeto': 269592154.08,
#     'close': 6309.11,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1540944000,
#     'high': 6391.25,
#     'low': 6241.49,
#     'open': 6309.11,
#     'volumefrom': 38823.41,
#     'volumeto': 245357244.49,
#     'close': 6342.61,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1541030400,
#     'high': 6402.59,
#     'low': 6322.6,
#     'open': 6342.81,
#     'volumefrom': 31397.71,
#     'volumeto': 199861220.45,
#     'close': 6381.3,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1541116800,
#     'high': 6420.93,
#     'low': 6371.57,
#     'open': 6381.3,
#     'volumefrom': 27987.6,
#     'volumeto': 179385606.7,
#     'close': 6394.66,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1541203200,
#     'high': 6398.09,
#     'low': 6336.96,
#     'open': 6394.65,
#     'volumefrom': 28808.38,
#     'volumeto': 183565304.27,
#     'close': 6376.32,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1541289600,
#     'high': 6498.16,
#     'low': 6351.92,
#     'open': 6376.55,
#     'volumefrom': 27317.02,
#     'volumeto': 175805188.92,
#     'close': 6467.05,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1541376000,
#     'high': 6475.8,
#     'low': 6406.69,
#     'open': 6467.05,
#     'volumefrom': 24142,
#     'volumeto': 155758902.3,
#     'close': 6433.74,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1541462400,
#     'high': 6482.81,
#     'low': 6412.56,
#     'open': 6433.53,
#     'volumefrom': 37162.36,
#     'volumeto': 239808254.25,
#     'close': 6479.72,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1541548800,
#     'high': 6562.79,
#     'low': 6476.59,
#     'open': 6479.72,
#     'volumefrom': 55100.44,
#     'volumeto': 360052788.55,
#     'close': 6529.68,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1541635200,
#     'high': 6542.42,
#     'low': 6438.27,
#     'open': 6530.94,
#     'volumefrom': 42073.45,
#     'volumeto': 273205386.68,
#     'close': 6446.06,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1541721600,
#     'high': 6457.97,
#     'low': 6352.45,
#     'open': 6446.06,
#     'volumefrom': 37086.04,
#     'volumeto': 237893036.71,
#     'close': 6377.99,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1541808000,
#     'high': 6419.92,
#     'low': 6376.17,
#     'open': 6377.99,
#     'volumefrom': 14658.42,
#     'volumeto': 94313328.59,
#     'close': 6396.37,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1541894400,
#     'high': 6414.18,
#     'low': 6326.38,
#     'open': 6396.39,
#     'volumefrom': 20337.03,
#     'volumeto': 130156001.58,
#     'close': 6408.18,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1541980800,
#     'high': 6435.41,
#     'low': 6350.87,
#     'open': 6408.18,
#     'volumefrom': 28338.62,
#     'volumeto': 181575610.86,
#     'close': 6375.08,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1542067200,
#     'high': 6389.43,
#     'low': 6315.58,
#     'open': 6375.08,
#     'volumefrom': 35761.27,
#     'volumeto': 227689745.72,
#     'close': 6339.17,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1542153600,
#     'high': 6375.7,
#     'low': 5469.93,
#     'open': 6339.17,
#     'volumefrom': 178422.8,
#     'volumeto': 1045469380.16,
#     'close': 5741.47,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1542240000,
#     'high': 5767.06,
#     'low': 5300.75,
#     'open': 5740.51,
#     'volumefrom': 147895.07,
#     'volumeto': 820864013.96,
#     'close': 5647.5,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1542326400,
#     'high': 5676.54,
#     'low': 5487.87,
#     'open': 5647.5,
#     'volumefrom': 71050.83,
#     'volumeto': 397196182.83,
#     'close': 5586.27,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1542412800,
#     'high': 5602.01,
#     'low': 5524.7,
#     'open': 5586.97,
#     'volumefrom': 29517.8,
#     'volumeto': 164182152.19,
#     'close': 5568.94,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1542499200,
#     'high': 5701.35,
#     'low': 5567.95,
#     'open': 5567.95,
#     'volumefrom': 41702.04,
#     'volumeto': 233409182.46,
#     'close': 5615.26,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1542585600,
#     'high': 5615.98,
#     'low': 4757.01,
#     'open': 5615.26,
#     'volumefrom': 207964.38,
#     'volumeto': 1072037780.45,
#     'close': 4809.62,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1542672000,
#     'high': 4953.56,
#     'low': 4168.25,
#     'open': 4809.62,
#     'volumefrom': 315023.21,
#     'volumeto': 1433400842.16,
#     'close': 4441.81,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1542758400,
#     'high': 4689.55,
#     'low': 4315.58,
#     'open': 4441.81,
#     'volumefrom': 152286.19,
#     'volumeto': 686284917.84,
#     'close': 4593.04,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1542844800,
#     'high': 4640.72,
#     'low': 4297.21,
#     'open': 4593.04,
#     'volumefrom': 83715.43,
#     'volumeto': 376852837.57,
#     'close': 4320.68,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1542931200,
#     'high': 4419.48,
#     'low': 4157.19,
#     'open': 4320.68,
#     'volumefrom': 121719.16,
#     'volumeto': 521825987.75,
#     'close': 4343.42,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1543017600,
#     'high': 4432,
#     'low': 3741.2,
#     'open': 4343.42,
#     'volumefrom': 123090.79,
#     'volumeto': 503028289.39,
#     'close': 3854.11,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1543104000,
#     'high': 4165.93,
#     'low': 3550.04,
#     'open': 3854.11,
#     'volumefrom': 213926.98,
#     'volumeto': 819869496.19,
#     'close': 4004.15,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1543190400,
#     'high': 4124.7,
#     'low': 3598.81,
#     'open': 4004.46,
#     'volumefrom': 185985.76,
#     'volumeto': 715341714.72,
#     'close': 3784.59,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1543276800,
#     'high': 3878.9,
#     'low': 3613.11,
#     'open': 3784.77,
#     'volumefrom': 147999.31,
#     'volumeto': 555212127.53,
#     'close': 3822.99,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1543363200,
#     'high': 4398.57,
#     'low': 3822.94,
#     'open': 3822.99,
#     'volumefrom': 175435.76,
#     'volumeto': 726808596.57,
#     'close': 4263.55,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1543449600,
#     'high': 4444.39,
#     'low': 4130.68,
#     'open': 4263.52,
#     'volumefrom': 112103.36,
#     'volumeto': 479575430.64,
#     'close': 4286.69,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1543536000,
#     'high': 4331.07,
#     'low': 3916.3,
#     'open': 4286.85,
#     'volumefrom': 121993.57,
#     'volumeto': 497762735.43,
#     'close': 4009.67,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1543622400,
#     'high': 4309.65,
#     'low': 3942.62,
#     'open': 4009.67,
#     'volumefrom': 67774.58,
#     'volumeto': 280927570.31,
#     'close': 4197.46,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1543708800,
#     'high': 4318.79,
#     'low': 4077.67,
#     'open': 4197.7,
#     'volumefrom': 62748.83,
#     'volumeto': 262154694.41,
#     'close': 4143.86,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1543795200,
#     'high': 4159.01,
#     'low': 3795.18,
#     'open': 4143.86,
#     'volumefrom': 107400.61,
#     'volumeto': 423985399.83,
#     'close': 3871.41,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1543881600,
#     'high': 4082.68,
#     'low': 3770.92,
#     'open': 3871.41,
#     'volumefrom': 94655.27,
#     'volumeto': 373361232.89,
#     'close': 3948.44,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1543968000,
#     'high': 3961.8,
#     'low': 3719.19,
#     'open': 3948.44,
#     'volumefrom': 83811.55,
#     'volumeto': 320944415.67,
#     'close': 3737.53,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1544054400,
#     'high': 3883.43,
#     'low': 3467.92,
#     'open': 3737.53,
#     'volumefrom': 159523.77,
#     'volumeto': 590923562.42,
#     'close': 3485.18,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1544140800,
#     'high': 3576.11,
#     'low': 3248,
#     'open': 3485.18,
#     'volumefrom': 206088.47,
#     'volumeto': 699930576.16,
#     'close': 3420.57,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1544227200,
#     'high': 3602.49,
#     'low': 3295.21,
#     'open': 3420.57,
#     'volumefrom': 104091.14,
#     'volumeto': 357548590.53,
#     'close': 3461.07,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1544313600,
#     'high': 3718.58,
#     'low': 3436.5,
#     'open': 3461.07,
#     'volumefrom': 83347.79,
#     'volumeto': 295321498.63,
#     'close': 3592.84,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1544400000,
#     'high': 3645.49,
#     'low': 3416.77,
#     'open': 3592.84,
#     'volumefrom': 81855.33,
#     'volumeto': 287119758.11,
#     'close': 3467.16,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1544486400,
#     'high': 3483.58,
#     'low': 3348.98,
#     'open': 3467.16,
#     'volumefrom': 67519.71,
#     'volumeto': 230671778.42,
#     'close': 3401.02,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1544572800,
#     'high': 3545.37,
#     'low': 3380.48,
#     'open': 3401.02,
#     'volumefrom': 74415.95,
#     'volumeto': 257293632.74,
#     'close': 3485.59,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1544659200,
#     'high': 3493.76,
#     'low': 3272.81,
#     'open': 3485.59,
#     'volumefrom': 84592.04,
#     'volumeto': 286236674.73,
#     'close': 3305.11,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1544745600,
#     'high': 3333.24,
#     'low': 3180.97,
#     'open': 3305.11,
#     'volumefrom': 89133.43,
#     'volumeto': 290985461.02,
#     'close': 3235.48,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1544832000,
#     'high': 3271.76,
#     'low': 3169.53,
#     'open': 3235.48,
#     'volumefrom': 51317.37,
#     'volumeto': 165378769.6,
#     'close': 3232.51,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1544918400,
#     'high': 3319.83,
#     'low': 3227.4,
#     'open': 3232.51,
#     'volumefrom': 45102.51,
#     'volumeto': 148182655.41,
#     'close': 3255.37,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1545004800,
#     'high': 3639.65,
#     'low': 3239.06,
#     'open': 3255.37,
#     'volumefrom': 119831.24,
#     'volumeto': 412454521.38,
#     'close': 3548.19,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1545091200,
#     'high': 3727.99,
#     'low': 3481.46,
#     'open': 3548.19,
#     'volumefrom': 91609.53,
#     'volumeto': 327807644.75,
#     'close': 3715.85,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1545177600,
#     'high': 3969.7,
#     'low': 3693.57,
#     'open': 3715.85,
#     'volumefrom': 163016.15,
#     'volumeto': 620695447.39,
#     'close': 3736.54,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1545264000,
#     'high': 4225.52,
#     'low': 3712.82,
#     'open': 3736.54,
#     'volumefrom': 180025.9,
#     'volumeto': 724855205.51,
#     'close': 4137.66,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1545350400,
#     'high': 4247.71,
#     'low': 3831.2,
#     'open': 4137.66,
#     'volumefrom': 128508.13,
#     'volumeto': 516656937.13,
#     'close': 3898.81,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1545436800,
#     'high': 4060.34,
#     'low': 3849.23,
#     'open': 3898.81,
#     'volumefrom': 63672.55,
#     'volumeto': 250085915.72,
#     'close': 4045.24,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1545523200,
#     'high': 4117.65,
#     'low': 3972.39,
#     'open': 4045.24,
#     'volumefrom': 58294.45,
#     'volumeto': 235997621.23,
#     'close': 4007.63,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1545609600,
#     'high': 4303.37,
#     'low': 4006.6,
#     'open': 4007.63,
#     'volumefrom': 109869.44,
#     'volumeto': 459290147.24,
#     'close': 4081.95,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1545696000,
#     'high': 4094.61,
#     'low': 3734.85,
#     'open': 4081.95,
#     'volumefrom': 95683.55,
#     'volumeto': 367200910.64,
#     'close': 3834.73,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1545782400,
#     'high': 3923.93,
#     'low': 3746.86,
#     'open': 3834.73,
#     'volumefrom': 68965.06,
#     'volumeto': 263439573.84,
#     'close': 3848.78,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1545868800,
#     'high': 3888.92,
#     'low': 3622.39,
#     'open': 3848.78,
#     'volumefrom': 81652.77,
#     'volumeto': 305729129.14,
#     'close': 3646.09,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1545955200,
#     'high': 4007.71,
#     'low': 3628.43,
#     'open': 3646.09,
#     'volumefrom': 92882.41,
#     'volumeto': 353705007.17,
#     'close': 3947.86,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1546041600,
#     'high': 4004.14,
#     'low': 3774.38,
#     'open': 3947.86,
#     'volumefrom': 54702.16,
#     'volumeto': 214891355.42,
#     'close': 3797.06,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1546128000,
#     'high': 3925.18,
#     'low': 3760.8,
#     'open': 3797.06,
#     'volumefrom': 49797.04,
#     'volumeto': 191958416.81,
#     'close': 3896.21,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1546214400,
#     'high': 3904.28,
#     'low': 3701.48,
#     'open': 3896.21,
#     'volumefrom': 54221.49,
#     'volumeto': 206190463.74,
#     'close': 3747.39,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1546300800,
#     'high': 3938.75,
#     'low': 3696.94,
#     'open': 3747.39,
#     'volumefrom': 45104.29,
#     'volumeto': 170598307.96,
#     'close': 3880.15,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1546387200,
#     'high': 3989.59,
#     'low': 3826.29,
#     'open': 3880.15,
#     'volumefrom': 54034.73,
#     'volumeto': 210854603.84,
#     'close': 3961.01,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1546473600,
#     'high': 3965.52,
#     'low': 3778.76,
#     'open': 3961.01,
#     'volumefrom': 45585.19,
#     'volumeto': 176488072.06,
#     'close': 3835.86,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1546560000,
#     'high': 3901.65,
#     'low': 3783.88,
#     'open': 3835.86,
#     'volumefrom': 44398.9,
#     'volumeto': 170507611.15,
#     'close': 3874.06,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1546646400,
#     'high': 3926.92,
#     'low': 3841.13,
#     'open': 3874.06,
#     'volumefrom': 35766.65,
#     'volumeto': 139438510.18,
#     'close': 3855.39,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1546732800,
#     'high': 4145.16,
#     'low': 3829.09,
#     'open': 3855.39,
#     'volumefrom': 58878.99,
#     'volumeto': 236298043.75,
#     'close': 4102.85,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1546819200,
#     'high': 4132.62,
#     'low': 4001.35,
#     'open': 4102.85,
#     'volumefrom': 51541.23,
#     'volumeto': 209289368.14,
#     'close': 4050.4,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1546905600,
#     'high': 4156.16,
#     'low': 3990.34,
#     'open': 4050.4,
#     'volumefrom': 65973.5,
#     'volumeto': 268091045.44,
#     'close': 4040.75,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1546992000,
#     'high': 4092.91,
#     'low': 4013,
#     'open': 4040.75,
#     'volumefrom': 55130.13,
#     'volumeto': 223639028.92,
#     'close': 4048.34,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1547078400,
#     'high': 4085.09,
#     'low': 3631.07,
#     'open': 4048.34,
#     'volumefrom': 108277.01,
#     'volumeto': 412522198.13,
#     'close': 3668.15,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1547164800,
#     'high': 3729.69,
#     'low': 3616.41,
#     'open': 3668.15,
#     'volumefrom': 63070.18,
#     'volumeto': 231465488.1,
#     'close': 3669.2,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1547251200,
#     'high': 3692.12,
#     'low': 3611.2,
#     'open': 3669.2,
#     'volumefrom': 28343.28,
#     'volumeto': 103912541.38,
#     'close': 3664.38,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1547337600,
#     'high': 3675.2,
#     'low': 3528.24,
#     'open': 3664.38,
#     'volumefrom': 45682.73,
#     'volumeto': 164125048.97,
#     'close': 3551.24,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1547424000,
#     'high': 3748.88,
#     'low': 3544.53,
#     'open': 3551.24,
#     'volumefrom': 56099.99,
#     'volumeto': 204793029.92,
#     'close': 3703.9,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1547510400,
#     'high': 3724.3,
#     'low': 3590.49,
#     'open': 3703.9,
#     'volumefrom': 54154.65,
#     'volumeto': 198582447.53,
#     'close': 3621.24,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1547596800,
#     'high': 3704.37,
#     'low': 3611.38,
#     'open': 3621.24,
#     'volumefrom': 53843.55,
#     'volumeto': 196211595.54,
#     'close': 3643.99,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1547683200,
#     'high': 3695.28,
#     'low': 3586.92,
#     'open': 3643.99,
#     'volumefrom': 46181.32,
#     'volumeto': 168287506.1,
#     'close': 3685.3,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1547769600,
#     'high': 3685.39,
#     'low': 3620.44,
#     'open': 3685.3,
#     'volumefrom': 32418.99,
#     'volumeto': 118317804.97,
#     'close': 3648.05,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1547856000,
#     'high': 3799.62,
#     'low': 3643.01,
#     'open': 3648.05,
#     'volumefrom': 38341.35,
#     'volumeto': 143238228.4,
#     'close': 3729.78,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1547942400,
#     'high': 3754.65,
#     'low': 3529.25,
#     'open': 3729.78,
#     'volumefrom': 49198.37,
#     'volumeto': 177628515.93,
#     'close': 3567.73,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1548028800,
#     'high': 3599.83,
#     'low': 3535.19,
#     'open': 3567.73,
#     'volumefrom': 36101.4,
#     'volumeto': 129000924.6,
#     'close': 3571.92,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1548115200,
#     'high': 3635.69,
#     'low': 3473.77,
#     'open': 3571.92,
#     'volumefrom': 53586.91,
#     'volumeto': 191355241.84,
#     'close': 3602.04,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1548201600,
#     'high': 3631.15,
#     'low': 3543.96,
#     'open': 3602.04,
#     'volumefrom': 37910.4,
#     'volumeto': 135864247.56,
#     'close': 3572.05,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1548288000,
#     'high': 3616.33,
#     'low': 3546.5,
#     'open': 3572.05,
#     'volumefrom': 31630.57,
#     'volumeto': 113155246.95,
#     'close': 3598.52,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1548374400,
#     'high': 3607.43,
#     'low': 3539.41,
#     'open': 3598.52,
#     'volumefrom': 32679.69,
#     'volumeto': 116674680.78,
#     'close': 3582.89,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1548460800,
#     'high': 3676.4,
#     'low': 3578.62,
#     'open': 3582.89,
#     'volumefrom': 29201.1,
#     'volumeto': 105927045.55,
#     'close': 3596.5,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1548547200,
#     'high': 3605.99,
#     'low': 3511.29,
#     'open': 3596.5,
#     'volumefrom': 26261.48,
#     'volumeto': 93766117.67,
#     'close': 3565.08,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1548633600,
#     'high': 3567.56,
#     'low': 3402.56,
#     'open': 3565.08,
#     'volumefrom': 59700.11,
#     'volumeto': 206309738.62,
#     'close': 3453.42,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1548720000,
#     'high': 3463.2,
#     'low': 3369.19,
#     'open': 3453.42,
#     'volumefrom': 46304.1,
#     'volumeto': 158106687,
#     'close': 3418.25,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1548806400,
#     'high': 3488.91,
#     'low': 3395.94,
#     'open': 3418.25,
#     'volumefrom': 42399.63,
#     'volumeto': 146422486.1,
#     'close': 3467.21,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1548892800,
#     'high': 3499.78,
#     'low': 3422.83,
#     'open': 3467.21,
#     'volumefrom': 37365.7,
#     'volumeto': 128773893.15,
#     'close': 3434.13,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1548979200,
#     'high': 3478.55,
#     'low': 3398.96,
#     'open': 3434.13,
#     'volumefrom': 41976.43,
#     'volumeto': 144476056.44,
#     'close': 3461.63,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1549065600,
#     'high': 3519.14,
#     'low': 3441.21,
#     'open': 3461.63,
#     'volumefrom': 27103.48,
#     'volumeto': 94144187.11,
#     'close': 3508.68,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1549152000,
#     'high': 3514.43,
#     'low': 3424.42,
#     'open': 3508.68,
#     'volumefrom': 23044.88,
#     'volumeto': 79591219.11,
#     'close': 3449.62,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1549238400,
#     'high': 3470.8,
#     'low': 3429.21,
#     'open': 3449.62,
#     'volumefrom': 23959.61,
#     'volumeto': 82280894.52,
#     'close': 3431.24,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1549324800,
#     'high': 3447.88,
#     'low': 3415.67,
#     'open': 3431.24,
#     'volumefrom': 24459.49,
#     'volumeto': 84042727.18,
#     'close': 3447.66,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1549411200,
#     'high': 3459.33,
#     'low': 3362.24,
#     'open': 3447.66,
#     'volumefrom': 44281.79,
#     'volumeto': 150408587.85,
#     'close': 3394.89,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1549497600,
#     'high': 3406.54,
#     'low': 3369.1,
#     'open': 3394.89,
#     'volumefrom': 28811.35,
#     'volumeto': 97390901.92,
#     'close': 3375.33,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1549584000,
#     'high': 3735.1,
#     'low': 3363.32,
#     'open': 3375.33,
#     'volumefrom': 89444.22,
#     'volumeto': 317023029.42,
#     'close': 3660.03,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1549670400,
#     'high': 3673.71,
#     'low': 3616.11,
#     'open': 3660.03,
#     'volumefrom': 25880.75,
#     'volumeto': 94200588.34,
#     'close': 3652.26,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1549756800,
#     'high': 3689.32,
#     'low': 3611.46,
#     'open': 3652.26,
#     'volumefrom': 30046.26,
#     'volumeto': 109365095.98,
#     'close': 3685.14,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1549843200,
#     'high': 3688.59,
#     'low': 3608.18,
#     'open': 3685.14,
#     'volumefrom': 40461.58,
#     'volumeto': 146354074.39,
#     'close': 3611.34,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1549929600,
#     'high': 3648.67,
#     'low': 3574.22,
#     'open': 3611.34,
#     'volumefrom': 45717.05,
#     'volumeto': 164816438.53,
#     'close': 3617.41,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1550016000,
#     'high': 3655.89,
#     'low': 3590.01,
#     'open': 3617.41,
#     'volumefrom': 40664.15,
#     'volumeto': 146822348.57,
#     'close': 3605.87,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1550102400,
#     'high': 3619.7,
#     'low': 3567.39,
#     'open': 3605.87,
#     'volumefrom': 32779.35,
#     'volumeto': 117804856.32,
#     'close': 3588.72,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1550188800,
#     'high': 3640.65,
#     'low': 3575.95,
#     'open': 3588.72,
#     'volumefrom': 36251.38,
#     'volumeto': 130398989.33,
#     'close': 3593.49,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1550275200,
#     'high': 3639.75,
#     'low': 3592.04,
#     'open': 3593.49,
#     'volumefrom': 24003.59,
#     'volumeto': 86973822.79,
#     'close': 3617.24,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1550361600,
#     'high': 3706.17,
#     'low': 3608.18,
#     'open': 3617.24,
#     'volumefrom': 36849.32,
#     'volumeto': 134218331.16,
#     'close': 3670.92,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1550448000,
#     'high': 3952.44,
#     'low': 3661.42,
#     'open': 3670.92,
#     'volumefrom': 98728.99,
#     'volumeto': 376203280.43,
#     'close': 3912.57,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1550534400,
#     'high': 4010.91,
#     'low': 3882.52,
#     'open': 3912.57,
#     'volumefrom': 74127.62,
#     'volumeto': 292137057.43,
#     'close': 3924.24,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1550620800,
#     'high': 3992.31,
#     'low': 3898.91,
#     'open': 3924.24,
#     'volumefrom': 53048.95,
#     'volumeto': 209282292.49,
#     'close': 3974.05,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1550707200,
#     'high': 4026.54,
#     'low': 3900.28,
#     'open': 3974.05,
#     'volumefrom': 47433.87,
#     'volumeto': 187314178.85,
#     'close': 3937.04,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1550793600,
#     'high': 3996.15,
#     'low': 3917.66,
#     'open': 3937.04,
#     'volumefrom': 43006.55,
#     'volumeto': 170405341.81,
#     'close': 3983.53,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1550880000,
#     'high': 4192.39,
#     'low': 3948.48,
#     'open': 3983.53,
#     'volumefrom': 57002.5,
#     'volumeto': 231174632.28,
#     'close': 4149.09,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1550966400,
#     'high': 4221.62,
#     'low': 3755.38,
#     'open': 4149.09,
#     'volumefrom': 80391.72,
#     'volumeto': 319071544.94,
#     'close': 3771.62,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1551052800,
#     'high': 3885.06,
#     'low': 3771.53,
#     'open': 3771.62,
#     'volumefrom': 48406.42,
#     'volumeto': 185036583.31,
#     'close': 3845.51,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1551139200,
#     'high': 3852.66,
#     'low': 3791.9,
#     'open': 3845.51,
#     'volumefrom': 33253.08,
#     'volumeto': 126868886.89,
#     'close': 3817.88,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1551225600,
#     'high': 3851.84,
#     'low': 3699.53,
#     'open': 3817.88,
#     'volumefrom': 46011.1,
#     'volumeto': 175069054.72,
#     'close': 3830.72,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1551312000,
#     'high': 3909.86,
#     'low': 3798,
#     'open': 3830.72,
#     'volumefrom': 44353.45,
#     'volumeto': 170646670.66,
#     'close': 3823.37,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1551398400,
#     'high': 3866.12,
#     'low': 3822.67,
#     'open': 3823.37,
#     'volumefrom': 26522.34,
#     'volumeto': 101774924.71,
#     'close': 3831.48,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1551484800,
#     'high': 3846.38,
#     'low': 3790.74,
#     'open': 3831.48,
#     'volumefrom': 19283.71,
#     'volumeto': 73894412.97,
#     'close': 3842.94,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1551571200,
#     'high': 3853.28,
#     'low': 3788.04,
#     'open': 3842.94,
#     'volumefrom': 16769.86,
#     'volumeto': 64065044.79,
#     'close': 3812.31,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1551657600,
#     'high': 3831.01,
#     'low': 3705.14,
#     'open': 3812.31,
#     'volumefrom': 39278.22,
#     'volumeto': 147245676.28,
#     'close': 3731.28,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1551744000,
#     'high': 3893.52,
#     'low': 3720.49,
#     'open': 3731.28,
#     'volumefrom': 43262.3,
#     'volumeto': 165062256.27,
#     'close': 3874.18,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1551830400,
#     'high': 3916.29,
#     'low': 3839.39,
#     'open': 3874.18,
#     'volumefrom': 33536.95,
#     'volumeto': 129520549.49,
#     'close': 3874.98,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1551916800,
#     'high': 3911.76,
#     'low': 3853.2,
#     'open': 3874.98,
#     'volumefrom': 37619.38,
#     'volumeto': 146201726.67,
#     'close': 3882.61,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1552003200,
#     'high': 3932.02,
#     'low': 3804.98,
#     'open': 3882.61,
#     'volumefrom': 39428.25,
#     'volumeto': 153405087.61,
#     'close': 3868.02,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1552089600,
#     'high': 3975.25,
#     'low': 3860.66,
#     'open': 3868.02,
#     'volumefrom': 27600.01,
#     'volumeto': 108370246.04,
#     'close': 3947.74,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1552176000,
#     'high': 3948.21,
#     'low': 3897.82,
#     'open': 3947.74,
#     'volumefrom': 17404.16,
#     'volumeto': 68252920.53,
#     'close': 3929.84,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1552262400,
#     'high': 3941.99,
#     'low': 3849.45,
#     'open': 3929.84,
#     'volumefrom': 32708.55,
#     'volumeto': 126998648.6,
#     'close': 3874.89,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1552348800,
#     'high': 3904.7,
#     'low': 3827.23,
#     'open': 3874.89,
#     'volumefrom': 33655.37,
#     'volumeto': 130291591.54,
#     'close': 3888.57,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1552435200,
#     'high': 3898.25,
#     'low': 3853.06,
#     'open': 3888.57,
#     'volumefrom': 27922.69,
#     'volumeto': 108286926.77,
#     'close': 3878.44,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1552521600,
#     'high': 3922.21,
#     'low': 3825.03,
#     'open': 3878.44,
#     'volumefrom': 34554.38,
#     'volumeto': 133931876.12,
#     'close': 3881.44,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1552608000,
#     'high': 3935.1,
#     'low': 3876.17,
#     'open': 3881.44,
#     'volumefrom': 32133.02,
#     'volumeto': 125588541.02,
#     'close': 3927.08,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1552694400,
#     'high': 4069.11,
#     'low': 3924.98,
#     'open': 3927.08,
#     'volumefrom': 41319.81,
#     'volumeto': 166216280.52,
#     'close': 4027.01,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1552780800,
#     'high': 4030.38,
#     'low': 3970.97,
#     'open': 4027.01,
#     'volumefrom': 17033.6,
#     'volumeto': 68146133.16,
#     'close': 3998,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1552867200,
#     'high': 4038.99,
#     'low': 3964.31,
#     'open': 3998,
#     'volumefrom': 27416.92,
#     'volumeto': 109428478.54,
#     'close': 3988.85,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1552953600,
#     'high': 4032.04,
#     'low': 3972.47,
#     'open': 3988.85,
#     'volumefrom': 29686.2,
#     'volumeto': 118919147.36,
#     'close': 4024.14,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1553040000,
#     'high': 4064.95,
#     'low': 3995.49,
#     'open': 4024.14,
#     'volumefrom': 36862.09,
#     'volumeto': 148490744.9,
#     'close': 4056.75,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1553126400,
#     'high': 4082.29,
#     'low': 3953.53,
#     'open': 4056.75,
#     'volumefrom': 44251.52,
#     'volumeto': 178077036.22,
#     'close': 3996.93,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1553212800,
#     'high': 4018.21,
#     'low': 3984,
#     'open': 3996.93,
#     'volumefrom': 22671.75,
#     'volumeto': 90726555.79,
#     'close': 4000.84,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1553299200,
#     'high': 4019.36,
#     'low': 3982.47,
#     'open': 4000.84,
#     'volumefrom': 18486.22,
#     'volumeto': 74094017.72,
#     'close': 4007.21,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1553385600,
#     'high': 4010.3,
#     'low': 3970.35,
#     'open': 4007.21,
#     'volumefrom': 16111.98,
#     'volumeto': 64375076.75,
#     'close': 3994.11,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1553472000,
#     'high': 4005.29,
#     'low': 3887.68,
#     'open': 3994.11,
#     'volumefrom': 34191.84,
#     'volumeto': 136398998.18,
#     'close': 3924.55,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1553558400,
#     'high': 3943.2,
#     'low': 3902.52,
#     'open': 3924.55,
#     'volumefrom': 23873.14,
#     'volumeto': 93805733.55,
#     'close': 3942.22,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1553644800,
#     'high': 4054.32,
#     'low': 3932.79,
#     'open': 3942.22,
#     'volumefrom': 37132.4,
#     'volumeto': 149005782.26,
#     'close': 4045.98,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1553731200,
#     'high': 4046.44,
#     'low': 4014.69,
#     'open': 4045.98,
#     'volumefrom': 25343.13,
#     'volumeto': 102296341.19,
#     'close': 4036.45,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1553817600,
#     'high': 4122.89,
#     'low': 4031.22,
#     'open': 4036.45,
#     'volumefrom': 41843.31,
#     'volumeto': 170915132.77,
#     'close': 4111.38,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1553904000,
#     'high': 4146.88,
#     'low': 4066.87,
#     'open': 4111.38,
#     'volumefrom': 24906.26,
#     'volumeto': 102400533.82,
#     'close': 4118.13,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1553990400,
#     'high': 4129.43,
#     'low': 4098.79,
#     'open': 4118.13,
#     'volumefrom': 13792.73,
#     'volumeto': 56727425.19,
#     'close': 4112.69,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1554076800,
#     'high': 4164.33,
#     'low': 4082.2,
#     'open': 4112.69,
#     'volumefrom': 36921.55,
#     'volumeto': 152826759.02,
#     'close': 4151.32,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1554163200,
#     'high': 5104.42,
#     'low': 4147.7,
#     'open': 4151.32,
#     'volumefrom': 172473.31,
#     'volumeto': 814748125.73,
#     'close': 4906.93,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1554249600,
#     'high': 5335.7,
#     'low': 4831.59,
#     'open': 4906.93,
#     'volumefrom': 159843.43,
#     'volumeto': 809158339.99,
#     'close': 4976.59,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1554336000,
#     'high': 5071.98,
#     'low': 4799.77,
#     'open': 4976.59,
#     'volumefrom': 74544.88,
#     'volumeto': 370109007.61,
#     'close': 4913.36,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1554422400,
#     'high': 5074.13,
#     'low': 4897.61,
#     'open': 4913.36,
#     'volumefrom': 56130.82,
#     'volumeto': 280722247.3,
#     'close': 5047.23,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1554508800,
#     'high': 5240.19,
#     'low': 4938,
#     'open': 5047.23,
#     'volumefrom': 54180.91,
#     'volumeto': 275839573.8,
#     'close': 5057.25,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1554595200,
#     'high': 5266.04,
#     'low': 5044.28,
#     'open': 5057.25,
#     'volumefrom': 47200.43,
#     'volumeto': 243329883.48,
#     'close': 5201.16,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1554681600,
#     'high': 5347.88,
#     'low': 5141.23,
#     'open': 5201.16,
#     'volumefrom': 69803.56,
#     'volumeto': 366577921.18,
#     'close': 5294.09,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1554768000,
#     'high': 5294.09,
#     'low': 5159.13,
# ...
#    {'time': 1616976000,
#     'high': 58413.9,
#     'low': 54910.57,
#     'open': 55781.01,
#     'volumefrom': 51547.9,
#     'volumeto': 2950020309.68,
#     'close': 57626.1,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1617062400,
#     'high': 59402.27,
#     'low': 57055.21,
#     'open': 57626.1,
#     'volumefrom': 35315.45,
#     'volumeto': 2064647135.86,
#     'close': 58781.54,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1617148800,
#     'high': 59818.5,
#     'low': 56918.81,
#     'open': 58781.54,
#     'volumefrom': 46494.48,
#     'volumeto': 2727194335.71,
#     'close': 58793.8,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1617235200,
#     'high': 59469.45,
#     'low': 57949.11,
#     'open': 58793.8,
#     'volumefrom': 28027.66,
#     'volumeto': 1648724834.05,
#     'close': 58730.82,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1617321600,
#     'high': 60061.51,
#     'low': 58458.46,
#     'open': 58730.82,
#     'volumefrom': 29748.03,
#     'volumeto': 1765524921.41,
#     'close': 58987.8,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1617408000,
#     'high': 59770.87,
#     'low': 56958.04,
#     'open': 58987.8,
#     'volumefrom': 25104.9,
#     'volumeto': 1470430519.81,
#     'close': 57074.97,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1617494400,
#     'high': 58493.73,
#     'low': 56493.38,
#     'open': 57074.97,
#     'volumefrom': 19002.99,
#     'volumeto': 1093079652.2,
#     'close': 58219.43,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1617580800,
#     'high': 59235.68,
#     'low': 56833.44,
#     'open': 58219.43,
#     'volumefrom': 24696.26,
#     'volumeto': 1439529332.47,
#     'close': 59119.56,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1617667200,
#     'high': 59464.31,
#     'low': 57369.44,
#     'open': 59119.56,
#     'volumefrom': 26304.15,
#     'volumeto': 1535666142.46,
#     'close': 58010.35,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1617753600,
#     'high': 58628.19,
#     'low': 55467.58,
#     'open': 58010.35,
#     'volumefrom': 50347.59,
#     'volumeto': 2855410824.81,
#     'close': 55951.98,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1617840000,
#     'high': 58150.23,
#     'low': 55711.07,
#     'open': 55951.98,
#     'volumefrom': 25461.84,
#     'volumeto': 1458096433.7,
#     'close': 58084.46,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1617926400,
#     'high': 58881.94,
#     'low': 57694.22,
#     'open': 58084.46,
#     'volumefrom': 21314.29,
#     'volumeto': 1241735091.75,
#     'close': 58106.85,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1618012800,
#     'high': 61193.5,
#     'low': 57885.43,
#     'open': 58106.85,
#     'volumefrom': 38726.18,
#     'volumeto': 2322058695.22,
#     'close': 59784.8,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1618099200,
#     'high': 60673.37,
#     'low': 59218.25,
#     'open': 59784.8,
#     'volumefrom': 20365.62,
#     'volumeto': 1218894531.01,
#     'close': 59980.45,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1618185600,
#     'high': 61233.29,
#     'low': 59421.37,
#     'open': 59980.45,
#     'volumefrom': 31804.9,
#     'volumeto': 1913098388.79,
#     'close': 59845.76,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1618272000,
#     'high': 63682.32,
#     'low': 59811.31,
#     'open': 59845.76,
#     'volumefrom': 52964.84,
#     'volumeto': 3299086696.94,
#     'close': 63558.48,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1618358400,
#     'high': 64859.81,
#     'low': 61312.98,
#     'open': 63558.48,
#     'volumefrom': 64272.96,
#     'volumeto': 4066819695.96,
#     'close': 62964.27,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1618444800,
#     'high': 63826.89,
#     'low': 62038.33,
#     'open': 62964.27,
#     'volumefrom': 34089.46,
#     'volumeto': 2146219571.03,
#     'close': 63233.03,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1618531200,
#     'high': 63567.11,
#     'low': 60048.13,
#     'open': 63233.03,
#     'volumefrom': 57540.3,
#     'volumeto': 3544777400.64,
#     'close': 61416.41,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1618617600,
#     'high': 62541.21,
#     'low': 59712.92,
#     'open': 61416.41,
#     'volumefrom': 34261.66,
#     'volumeto': 2093039585.66,
#     'close': 60056.07,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1618704000,
#     'high': 60393.33,
#     'low': 52785.1,
#     'open': 60056.07,
#     'volumefrom': 112545.94,
#     'volumeto': 6264051811.58,
#     'close': 56246.82,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1618790400,
#     'high': 57590.64,
#     'low': 54291.08,
#     'open': 56246.82,
#     'volumefrom': 48650.49,
#     'volumeto': 2732647682.18,
#     'close': 55680.11,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1618876800,
#     'high': 57101.05,
#     'low': 53429.73,
#     'open': 55680.11,
#     'volumefrom': 55866.75,
#     'volumeto': 3091319805.6,
#     'close': 56496.06,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1618963200,
#     'high': 56801.94,
#     'low': 53640.81,
#     'open': 56496.06,
#     'volumefrom': 41813.35,
#     'volumeto': 2312255459.33,
#     'close': 53803.25,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1619049600,
#     'high': 55458.61,
#     'low': 50519.78,
#     'open': 53803.25,
#     'volumefrom': 84222.11,
#     'volumeto': 4488994737.96,
#     'close': 51717.61,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1619136000,
#     'high': 52112.75,
#     'low': 47495.24,
#     'open': 51717.61,
#     'volumefrom': 105510.21,
#     'volumeto': 5241192198.03,
#     'close': 51178.03,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1619222400,
#     'high': 51223.86,
#     'low': 48769.48,
#     'open': 51178.03,
#     'volumefrom': 33894.94,
#     'volumeto': 1695108976.06,
#     'close': 50115.99,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1619308800,
#     'high': 50576.4,
#     'low': 47073.07,
#     'open': 50115.99,
#     'volumefrom': 44241.37,
#     'volumeto': 2176241676.28,
#     'close': 49120.97,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1619395200,
#     'high': 54389.71,
#     'low': 48843.41,
#     'open': 49120.97,
#     'volumefrom': 61603.5,
#     'volumeto': 3254396664.97,
#     'close': 54062.29,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1619481600,
#     'high': 55490.94,
#     'low': 53357.59,
#     'open': 54062.29,
#     'volumefrom': 40602.56,
#     'volumeto': 2220077233.11,
#     'close': 55073.48,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1619568000,
#     'high': 56461.55,
#     'low': 53886.63,
#     'open': 55073.48,
#     'volumefrom': 42647.15,
#     'volumeto': 2339383717.48,
#     'close': 54877.94,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1619654400,
#     'high': 55217.24,
#     'low': 52399.42,
#     'open': 54877.94,
#     'volumefrom': 43948.76,
#     'volumeto': 2359198137.55,
#     'close': 53581.58,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1619740800,
#     'high': 57984.34,
#     'low': 53089.93,
#     'open': 53581.58,
#     'volumefrom': 48771,
#     'volumeto': 2719315702.2,
#     'close': 57757.97,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1619827200,
#     'high': 58498.65,
#     'low': 57057.4,
#     'open': 57757.97,
#     'volumefrom': 26146.3,
#     'volumeto': 1511783659.93,
#     'close': 57843.16,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1619913600,
#     'high': 57934.82,
#     'low': 56092.72,
#     'open': 57843.16,
#     'volumefrom': 21671.56,
#     'volumeto': 1230710822.31,
#     'close': 56623.51,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1620000000,
#     'high': 58963.84,
#     'low': 56531.6,
#     'open': 56623.51,
#     'volumefrom': 41015.04,
#     'volumeto': 2371465902.34,
#     'close': 57195.07,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1620086400,
#     'high': 57226.81,
#     'low': 53108.04,
#     'open': 57195.07,
#     'volumefrom': 64556.47,
#     'volumeto': 3556756117.3,
#     'close': 53244.07,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1620172800,
#     'high': 57944.11,
#     'low': 52978.89,
#     'open': 53244.07,
#     'volumefrom': 56998.25,
#     'volumeto': 3200062630.96,
#     'close': 57506.88,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1620259200,
#     'high': 58392.76,
#     'low': 55299.4,
#     'open': 57506.88,
#     'volumefrom': 50632.92,
#     'volumeto': 2878647496.02,
#     'close': 56441.94,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1620345600,
#     'high': 58695.29,
#     'low': 55311.16,
#     'open': 56441.94,
#     'volumefrom': 42812.69,
#     'volumeto': 2439662460.45,
#     'close': 57374.33,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1620432000,
#     'high': 59521.69,
#     'low': 56985.44,
#     'open': 57374.33,
#     'volumefrom': 37728.82,
#     'volumeto': 2211507566.18,
#     'close': 58943.13,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1620518400,
#     'high': 59276.99,
#     'low': 56350.98,
#     'open': 58943.13,
#     'volumefrom': 45716.87,
#     'volumeto': 2645394205.33,
#     'close': 58294.18,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1620604800,
#     'high': 59587.03,
#     'low': 54239.16,
#     'open': 58294.18,
#     'volumefrom': 71168.05,
#     'volumeto': 4067497161.41,
#     'close': 55870.01,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1620691200,
#     'high': 56928.37,
#     'low': 54490.38,
#     'open': 55870.01,
#     'volumefrom': 42949.94,
#     'volumeto': 2395231325.24,
#     'close': 56747.52,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1620777600,
#     'high': 58005.44,
#     'low': 49182.89,
#     'open': 56747.52,
#     'volumefrom': 74345.74,
#     'volumeto': 4035173480.67,
#     'close': 49504.08,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1620864000,
#     'high': 51377.99,
#     'low': 47029.73,
#     'open': 49504.08,
#     'volumefrom': 119769.29,
#     'volumeto': 5919941739.84,
#     'close': 49700.6,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1620950400,
#     'high': 51554.66,
#     'low': 48910.06,
#     'open': 49700.6,
#     'volumefrom': 42891.66,
#     'volumeto': 2156016499.66,
#     'close': 49887.96,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1621036800,
#     'high': 50710.05,
#     'low': 46606.18,
#     'open': 49887.96,
#     'volumefrom': 53332.47,
#     'volumeto': 2591003797.63,
#     'close': 46775.29,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1621123200,
#     'high': 49808.83,
#     'low': 43918.69,
#     'open': 46775.29,
#     'volumefrom': 79337.9,
#     'volumeto': 3693969204.75,
#     'close': 46490.71,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1621209600,
#     'high': 46665.19,
#     'low': 42130.83,
#     'open': 46490.71,
#     'volumefrom': 134127.17,
#     'volumeto': 5896147491.21,
#     'close': 43552.14,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1621296000,
#     'high': 45819.36,
#     'low': 42309.39,
#     'open': 43552.14,
#     'volumefrom': 71930.7,
#     'volumeto': 3159184422.64,
#     'close': 42886.02,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1621382400,
#     'high': 43564.34,
#     'low': 29925.2,
#     'open': 42886.02,
#     'volumefrom': 290986.06,
#     'volumeto': 11120220854.77,
#     'close': 36771.87,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1621468800,
#     'high': 42520.03,
#     'low': 35009.25,
#     'open': 36771.87,
#     'volumefrom': 139648.53,
#     'volumeto': 5531454912.79,
#     'close': 40597.4,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1621555200,
#     'high': 42252.07,
#     'low': 33552.8,
#     'open': 40597.4,
#     'volumefrom': 120589.87,
#     'volumeto': 4573692788.95,
#     'close': 37350.39,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1621641600,
#     'high': 38841.92,
#     'low': 35287.71,
#     'open': 37350.39,
#     'volumefrom': 74964.98,
#     'volumeto': 2808008188.27,
#     'close': 37491.5,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1621728000,
#     'high': 38304.55,
#     'low': 31157.18,
#     'open': 37491.5,
#     'volumefrom': 131584.71,
#     'volumeto': 4494413873.1,
#     'close': 34716.84,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1621814400,
#     'high': 39945.35,
#     'low': 34467.32,
#     'open': 34716.84,
#     'volumefrom': 106765.14,
#     'volumeto': 3981461441.04,
#     'close': 38837.76,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1621900800,
#     'high': 39842.9,
#     'low': 36509.09,
#     'open': 38837.76,
#     'volumefrom': 66530.67,
#     'volumeto': 2529569055.97,
#     'close': 38387.36,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1621987200,
#     'high': 40854.81,
#     'low': 37855.81,
#     'open': 38387.36,
#     'volumefrom': 66483.59,
#     'volumeto': 2607759779.42,
#     'close': 39295.08,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1622073600,
#     'high': 40408.95,
#     'low': 37211.84,
#     'open': 39295.08,
#     'volumefrom': 46474.62,
#     'volumeto': 1804036815.09,
#     'close': 38538.84,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1622160000,
#     'high': 38879.6,
#     'low': 34733.76,
#     'open': 38538.84,
#     'volumefrom': 85345.66,
#     'volumeto': 3104364367.82,
#     'close': 35680.92,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1622246400,
#     'high': 37307.1,
#     'low': 33666.06,
#     'open': 35680.92,
#     'volumefrom': 60616.25,
#     'volumeto': 2127790128.94,
#     'close': 34611.58,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1622332800,
#     'high': 36481.62,
#     'low': 33400.65,
#     'open': 34611.58,
#     'volumefrom': 37522.16,
#     'volumeto': 1325408340.1,
#     'close': 35662.59,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1622419200,
#     'high': 37512.8,
#     'low': 34202.86,
#     'open': 35662.59,
#     'volumefrom': 50306.62,
#     'volumeto': 1821662523.97,
#     'close': 37290.83,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1622505600,
#     'high': 37910.19,
#     'low': 35733.52,
#     'open': 37290.83,
#     'volumefrom': 44444.78,
#     'volumeto': 1626268789.21,
#     'close': 36683.51,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1622592000,
#     'high': 38225.18,
#     'low': 35935.34,
#     'open': 36683.51,
#     'volumefrom': 39948.44,
#     'volumeto': 1494571249.19,
#     'close': 37576.98,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1622678400,
#     'high': 39482.46,
#     'low': 37199.92,
#     'open': 37576.98,
#     'volumefrom': 41098.93,
#     'volumeto': 1586641442.02,
#     'close': 39229.66,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1622764800,
#     'high': 39273.49,
#     'low': 35617.03,
#     'open': 39229.66,
#     'volumefrom': 49661.48,
#     'volumeto': 1837944242.33,
#     'close': 36861.5,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    {'time': 1622851200,
#     'high': 37911.76,
#     'low': 34846.16,
#     'open': 36861.5,
#     'volumefrom': 39864.17,
#     'volumeto': 1444088532.56,
#     'close': 35538.4,
#     'conversionType': 'direct',
#     'conversionSymbol': ''},
#    ...]}}

# %%
df_price = pd.DataFrame(data['Data']['Data'])

# %%
df_price['date'] = pd.to_datetime(df_price['time'], unit="s")

# %%
df_price['currency'] = name_fullname[currency]

# %%
df_price
# Out:
#             time      high       low      open  volumefrom      volumeto  \
# 0     1536537600   6371.42   6247.64   6249.07    50695.88  3.204353e+08
# 1     1536624000   6415.51   6199.19   6324.43    51401.22  3.245129e+08
# 2     1536710400   6357.89   6208.28   6295.54    52814.83  3.325372e+08
# 3     1536796800   6534.89   6337.08   6337.08    65684.53  4.250909e+08
# 4     1536883200   6591.59   6393.84   6492.17    58029.07  3.779894e+08
# ...          ...       ...       ...       ...         ...           ...
# 1822  1693958400  26013.02  25384.17  25784.45    15182.39  3.899956e+08
# 1823  1694044800  26423.48  25602.65  25751.58    18951.68  4.918186e+08
# 1824  1694131200  26444.48  25649.39  26266.45    18554.85  4.823584e+08
# 1825  1694217600  25937.07  25797.25  25907.13     4094.13  1.059249e+08
# 1826  1694304000  25900.68  25716.83  25898.41     3279.13  8.463795e+07
#
#          close conversionType conversionSymbol       date currency
# 0      6324.43         direct                  2018-09-10  Bitcoin
# 1      6295.54         direct                  2018-09-11  Bitcoin
# 2      6337.11         direct                  2018-09-12  Bitcoin
# 3      6492.00         direct                  2018-09-13  Bitcoin
# 4      6486.01         direct                  2018-09-14  Bitcoin
# ...        ...            ...              ...        ...      ...
# 1822  25751.58         direct                  2023-09-06  Bitcoin
# 1823  26266.45         direct                  2023-09-07  Bitcoin
# 1824  25907.13         direct                  2023-09-08  Bitcoin
# 1825  25898.41         direct                  2023-09-09  Bitcoin
# 1826  25766.94         direct                  2023-09-10  Bitcoin
#
# [1827 rows x 11 columns]

# %%
df_price = df_price[['currency', 'date', 'open', 'high', 'low', 'close', 'volumeto']]

# %%
df_price = df_price.rename(columns={'volumeto': 'volume'})

# %%
df_price.to_csv("test.csv", index=False)

# %% [markdown]
# #### Execute with all currencies

# %% [markdown]
# Note: We only use 30!

# %%
for currency in df['name'][0:30]:
    url = "https://min-api.cryptocompare.com/data/v2/histoday"
    
    parameters = {
        'fsym': currency,
        'tsym': 'USD',    
        'limit': '1826',
        'api_key': key
    }
    
    headers = {
    }

    session = Session()
    session.headers.update(headers)
    
    print(currency)

    try:
        response = session.get(url, params=parameters)
        data = json.loads(response.text)
        
        if data['Response'] != "Error":
            df_price = pd.DataFrame(data['Data']['Data'])
            df_price['date'] = pd.to_datetime(df_price['time'], unit="s")
            df_price = df_price[['date', 'open', 'high', 'low', 'close', 'volumeto']]
            df_price = df_price.rename(columns={'volumeto': 'volume'})
            df_price['currency'] = name_fullname[currency]
            df_price.to_csv("data/" + currency + ".csv", index=False)
        
            print(" - OK")
            
        else:
            print (" - Error")

    except (ConnectionError, Timeout, TooManyRedirects) as e:
        data = ""
        print(" - Error") 
        
    time.sleep(2)
# Out:
# BTC
#  - OK
# ETH
#  - OK
# USDT
#  - OK
# XRP
#  - OK
# BNB
#  - OK
# USDC
#  - OK
# STETH
#  - OK
# ADA
#  - OK
# SOL
#  - OK
# OKB
#  - OK
# DOGE
#  - OK
# ARB
#  - OK
# TRX
#  - OK
# XLM
#  - OK
# LINK
#  - OK
# APT
#  - OK
# OP
#  - OK
# MATIC
#  - OK
# DOT
#  - OK
# LTC
#  - OK
# SHIB
#  - OK
# UNI
#  - OK
# WBTC
#  - OK
# AVAX
#  - OK
# DAI
#  - OK
# BCH
#  - OK
# LEO
#  - OK
# TUSD
#  - OK
# XMR
#  - OK
# BUSD
#  - OK
