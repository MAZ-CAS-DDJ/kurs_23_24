# %% [markdown]
# # Datensets explorieren

# %% [markdown]
# **Inhalt:** Erste Schritte mit Pandas
#
# **Nötige Skills:** Keine
#
# **Lernziele:**
# - Datensets herunterladen, Datensets öffnen
# - Umfang der Daten, Felder und groben Inhalt erkennen
# - Einfache deskriptive Statistiken
# - Plotting Level 0

# %% [markdown]
# # Das Beispiel
#
# Eine Datenbank zu den verhängten Todesstrafen und Exekutionen in den USA seit 1991
#
# Quelle/Beschreibung: http://endofitsrope.com/data-and-documents/
#
# Daten: http://endofitsrope.com/wp-content/uploads/2018/03/1991_2017_individualFIPS.csv-1991_2017_individualFIPS.csv
#
# **Das Datenfile ist leicht editiert und hier abgelegt:** `dataprojects/death-sentences/`)

# %% [markdown]
# ## Vorbereitung

# %% [markdown]
# Um die pandas library zu benutzen, müssen wir sie immer zuerst importieren

# %%
import pandas as pd

# %% [markdown]
# ## Datenfile laden

# %% [markdown]
# Zuerst mal: Wo ist überhaupt die Datendatei, die wir gerade heruntergeladen haben?
#
# **TIPP:** Tabulator-Taste während dem Tippen benutzen, um den Pfad auszulesen

# %%
path = "dataprojects/death-sentences/new.csv"

# %% [markdown]
# Wir haben jetzt den Pfad zur Datei in der Variable `path` gespeichert

# %% [markdown]
# Jetzt wollen wir in die Datei hineinschauen. Was ein csv-File ist, wissen wir bereits: Eine Art Tabelle, bei der die einzelnen Spalten durch Kommas und die Zeilen durch Zeilenumbrüche getrennt sind. Schauen wir uns das nochmals kurz an:

# %%
with open(path) as f:
    dateiinhalt = f.read()

# %%
print(dateiinhalt)
# Out:
# defendant,year,sent_date,offns_date,fips_st,fips,state,county,prev_sent,def_race,def_gender,Executed,DateofExecution
# "Petersen, Ryan",2017,,,1,69,AL,Houston,,W,M,,
# "Jackson, Jamal",2017,,,1,97,AL,Mobile,,B,M,,
# "Hunter Smith, Brad",2017,,,5,25,AR,Cleveland,,W,M,,
# "Allen, Samantha",2017,,,4,13,AZ,Maricopa,,W,F,,
# "Allen, John",2017,,,4,13,AZ,Maricopa,,W,M,,
# "Champagne, Alan",2017,,,4,13,AZ,Maricopa,,O,M,,
# "Strong, Preston",2017,,,4,27,AZ,Yuma,,B,M,,
# "Washington, Darnell",2017,,,6,13,CA,Contra Costa,,B,M,,
# "Meza, Heraclio",2017,,,6,37,CA,Los Angeles,,L,M,,
# "Gordon, Steven",2017,,,6,59,CA,Orange,,W,M,,
# "Rhoades, Cherie",2017,,,6,61,CA,bernan,,O,F,,
# "Lopez, Elias",2017,,,6,65,CA,Riverside,,L,M,,
# "Lopez, Johnny",2017,,,6,65,CA,Riverside,,L,M,,
# "Contreras, David",2017,,,6,65,CA,Riverside,,L,M,,
# "Hunter, Lorraine Allison",2017,,,6,65,CA,Riverside,,B,F,,
# "Ellis, James",2017,,,6,71,CA,San Bernardino,,B,M,,
# "Cheary, Christopher",2017,,,6,107,CA,Tulare,,W,M,,
# "Roof, Dylann",2017,,,99,1,Federal,,,W,M,,
# "Demas, Mesac",2017,,,12,21,FL,Collier,,B,M,,
# "Rogers, Shawn",2017,,,12,113,FL,Santa Rosa,,B,M,,
# "Bush, Sean",2017,,,12,109,FL,St. Johns,,B,M,,
# "Renfro, Jonathan",2017,,,16,55,ID,Kootenai,,W,M,,
# "Rice, Marvin",2017,,,29,183,MO,St. Charles,,W,M,,
# "Garcia, Alberto",2017,,,28,47,MS,Harrison,,L,M,,
# "Jenkins, Nikko",2017,,,31,55,NE,Douglas,,B,M,,
# "Righetti, Javier",2017,,,32,3,NV,Clark,,L,M,,
# "Belcher, Norman",2017,,,32,3,NV,Clark,,B,M,,
# "Randolph, Thomas",2017,,,32,3,NV,Clark,,W,M,,
# "Sitton, Will",2017,,,32,3,NV,Clark,,W,M,,
# "Froman, Terry",2017,,,39,165,OH,Warren,,B,M,,
# "Nolen, Alton",2017,,,40,27,OK,Cleveland,,B,M,,
# "Fuston, Ronnie",2017,,,40,27,OK,Cleveland,,B,M,,
# "Thomas, Leeton",2017,,,42,71,PA,Lancaster,,B,M,,
# "Frein, Eric",2017,,,42,103,PA,Pike,,W,M,,
# "Falk, John Ray",2017,,,48,5,TX,Angelina,,W,M,,
# "Colone, Jr., Joseph",2017,,,48,245,TX,Jefferson,,B,M,,
# "Hudson, Wiiliam",2017,,,48,1,TX,Anderson,,W,M,,
# "Tracy, Billy",2017,,,48,37,TX,Bowie,,W,M,,
# "Barrera, Raymond",2017,,,6,65,CA,Riverside,,L,M,,
# "Gaddy, Richard",1991,,,1,73,Alabama,Jefferson,,W,M,,
# "Beard, David",1991,,,1,95,Alabama,Marshall,,W,M,,
# "Bush, William",1991,,,1,101,Alabama,Montgomery,,B,M,,
# "McNair, Willie",1991,,,1,101,Alabama,Montgomery,,B,M,Executed,5/14/09
# "Giles, Arthur Lee",1991,,,1,103,Alabama,Morgan,Resentenced,B,M,,
# "Jenkins, Mark Allen",1991,,,1,115,Alabama,St. Clair,,L,M,,
# "Carroll, Robert",1991,,,1,119,Alabama,Sumter,,W,M,,
# "Milke, Debra Jean",1991,2/4/91,,4,13,Arizona,Maricopa,,W,F,,
# "Gallegos, Michael",1991,5/24/91,3/16/90,4,13,Arizona,Maricopa,,L,M,,
# "Cornell, Joe",1991,,,4,13,Arizona,Maricopa,,W,M,,
# "King, Eric John",1991,,,4,13,Arizona,Maricopa,,B,M,Executed,3/29/11
# "Scott, Roger Mark",1991,4/30/91,,4,13,Arizona,Maricopa,,W,M,,
# "Ross, Arthur",1991,,,4,19,Arizona,Pima,,W,M,Executed,4/29/98
# "Detrick, David",1991,,,4,19,Arizona,Pima,,,M,,
# "Medina, Oscar Gonzalez",1991,,,4,19,Arizona,Pima,,L,M,,
# "Eastlack, John Patrick",1991,,,4,19,Arizona,Pima,,B,M,,
# "Wood, Joseph",1991,,,4,19,Arizona,Pima,,W,M,Executed,7/22/14
# "Grannis, David Wayne",1991,,,4,19,Arizona,Pima,,W,M,,
# "Webster, Daniel Ethan",1991,,,4,19,Arizona,Pima,,W,M,,
# "Brenk, Herbert",1991,,,5,5,Arkansas,Baxter,,,M,,
# "Sanders, Raymond",1991,,,5,59,Arkansas,Hot Spring,,B,M,,
# "Johnson, Mark",1991,,,17,31,Illinois,Cook,,B,M,,
# "Geist, Joseph",1991,,,17,31,Illinois,Cook,,W,M,,
# "Page, Patrick",1991,8/1/90,,17,31,Illinois,Cook,,W,M,,
# "Banks, Randy",1991,,,17,31,Illinois,Cook,,B,M,,
# "Howery, Bernon",1991,,,17,91,Illinois,Kankakee,,B,M,,
# "Enis, Anthony",1991,,,17,97,Illinois,Lake,Resentenced - prior sentence in 1988,B,M,,
# "Johnson, Lenard",1991,,,17,135,Illinois,Montgomery,,B,M,,
# "Edgeston, Ondrea",1991,,,17,201,Illinois,Winnebago,,B,M,,
# "James, Vincent",1991,,,18,91,Indiana,La Porte,,B,M,Executed,
# "Roche, Charles",1991,,,18,89,Indiana,Lake,,W,M,,
# "Miller, Perry",1991,,,18,127,Indiana,Porter,,W,M,,
# "Bussell, Charles Wayne",1991,,,21,47,Kentucky,Christian,,B,M,,
# "Hunter, James",1991,,,21,49,Kentucky,Clark,,W,M,,
# "Sanborn, Parramore",1991,5/14/91,,21,103,Kentucky,Henry,Resentenced - prior sentence in 1984,W,M,,
# "Code, Nathaniel Robert",1991,,,22,17,Louisiana,Caddo,,B,M,,
# "Robertson, Allen",1991,,,22,33,Louisiana,East Baton Rouge,,B,M,,
# "Tart, Willie Lee",1991,,,22,67,Louisiana,Morehouse,,B,M,,
# "Brooks, John",1991,,,22,71,Louisiana,Orleans,,B,M,,
# "Divers, James",1991,,,22,73,Louisiana,Ouachita,,B,M,,
# "Bourque, Scott",1991,,,22,99,Louisiana,St. Martin,,W,M,,
# "Oken, Steve",1991,,,24,5,Maryland,Baltimore,,W,M,Executed,6/17/04
# "Bruce, Kirk",1991,,,24,33,Maryland,Prince Georges,,B,M,,
# "Mack, Jimmy",1991,6/29/91,,28,11,Mississippi,Bolivar,,B,M,,
# "Walker, Allen",1991,,9/8/90,28,47,Mississippi,Harrison,,W,M,,
# "Davis, Kenneth",1991,3/15/91,,28,49,Mississippi,Hinds,,W,M,,
# "Foster, Ron",1991,,,28,75,Mississippi,Lauderdale,,B,M,,
# "Jackson, Henry",1991,9/14/91,11/1/90,28,83,Mississippi,Leflore,,B,M,Executed,6/4/12
# "Dupalantis, David",1991,12/4/91,,28,101,Mississippi,Newton,,W,M,,
# "Butler, James",1991,5/7/91,5/5/90,29,47,Missouri,Clay,,W,M,,
# "Dexter, Clarence",1991,10/7/91,11/18/90,29,47,Missouri,Clay,,W,M,,
# "Roy, Roberts",1991,3/14/91,11/21/98,29,95,Missouri,Jackson,,B,M,Executed,3/10/99
# "Taylor, Michael",1991,,3/1/89,29,95,Missouri,Jackson,,B,M,Executed,2/25/14
# "Nunley, Roderick",1991,,3/1/89,29,95,Missouri,Jackson,,B,M,Executed,9/1/15
# "Copeland, Ray",1991,5/1/91,,29,117,Missouri,Livingston,,W,M,,
# "Copeland, Faye",1991,,,29,117,Missouri,Livingston,,W,F,,
# "Wise, Jessie Lee",1991,,,29,189,Missouri,St Louis,,B,M,Executed,5/25/99
# "Johnston, Timothy",1991,,,29,189,Missouri,St Louis,,W,M,Executed,8/31/05
# "Storey, Walter",1991,10/26/01,2/2/90,29,183,Missouri,St. Charles,,W,M,,
# "Isa, Maria",1991,12/20/91,,29,189,Missouri,St. Louis,,O,F,,
# "Isa, Zein",1991,12/20/91,,29,189,Missouri,St. Louis,,O,M,,
# "Drinkwater, Randy",1991,3/1/91,11/1/89,31,31,Nebraska,Cherry,,,M,,
# "Powell, Kitrich",1991,6/10/91,,32,3,Nevada,Clark,,W,M,,
# "Parker, Steven",1991,4/2/91,,32,3,Nevada,Clark,,B,M,,
# "Echavarria, Jose",1991,3/15/91,6/25/90,32,3,Nevada,Clark,,L,M,,
# "Guy, Curtis",1991,4/8/91,4/7/90,32,3,Nevada,Clark,,B,M,,
# "Moore, Blanche Taylor",1991,1/18/91,,37,1,North Carolina,Alamance,,W,F,,
# "Gibbs, Renwick",1991,11/14/91,,37,13,North Carolina,Beaufort,,B,M,,
# "Gay, Yvette",1991,8/10/91,,37,13,North Carolina,Beaufort,,B,F,,
# "McCollum, Henry",1991,11/22/91,,37,51,North Carolina,Cumberland,Resentenced - prior sentence in 1984,B,M,,
# "Sanderson, Ricky Lee",1991,6/3/91,,37,57,North Carolina,Davidson,Resentenced - prior sentence in 1986,W,M,Executed,1/30/98
# "Keel, Joseph Timothy",1991,8/12/91,,37,65,North Carolina,Edgecombe,,,M,Executed,11/7/03
# "Connor, Jerry W.",1991,4/30/91,,37,73,North Carolina,Gates,,W,M,,
# "Howell, Franklin Dwayne",1991,11/27/91,,37,101,North Carolina,Johnston,,W,M,,
# "Cunningham, Calvin C.",1991,5/5/91,,37,119,North Carolina,Mecklenburg,,B,M,,
# "Syriani, Elias H.",1991,6/13/91,,37,119,North Carolina,Mecklenburg,,O,M,Executed,11/18/05
# "Coffey, Fred Howard Jr.",1991,5/22/91,,37,119,North Carolina,Mecklenburg,Resentenced - prior sentence in 1987,W,M,,
# "Camacho, Frederick",1991,12/17/91,,37,119,North Carolina,Mecklenburg,,O,M,,
# "Bacon, Robert",1991,2/19/91,,37,133,North Carolina,Onslow,,B,M,,
# "Quick, Harold",1991,,,37,153,North Carolina,Richmond,Resentenced - prior sentence in 1988,,M,,
# "Rose, Clinton R.",1991,12/19/91,,37,157,North Carolina,Rockingham,,W,M,,
# "McHone, Steven V.",1991,3/7/91,,37,171,North Carolina,Surry,,W,M,Executed,11/11/05
# "Jones, William Quentin",1991,7/1/91,,37,183,North Carolina,Wake,Resentenced - prior sentence in 1987,B,M,Executed,8/21/03
# "Sexton, Michael Earl",1991,9/25/91,,37,183,North Carolina,Wake,,B,M,Executed,11/8/00
# "Carter, Ernest Marvin",1991,,,40,109,OKlahoma,Oklahoma,,B,M,Executed,12/17/02
# "Joseph, Richard",1991,,,39,3,Ohio,Allen,,W,M,,
# "Williams, Clifford",1991,2/8/91,,39,17,Ohio,Butler,,B,M,,
# "Loza, Jose Trinidad",1991,11/12/91,,39,17,Ohio,Butler,,L,M,,
# "Kinley, Juan",1991,3/19/91,1/10/89,39,23,Ohio,Clark,,B,M,,
# "Wilkerson, Ponchai",1991,7/26/91,,48,201,Texas,Harris,,B,M,Executed,3/14/00
# "Nelson, Billy Ray",1991,48,,48,227,Texas,Howard,,,M,,
# "Clark, Jack",1991,2/21/91,,48,303,Texas,Lubbock,,W,M,Executed,1/9/01
# "Casey, Gerald",1991,11/15/91,,48,339,Texas,Montgomery,,W,M,Executed,4/18/02
# "Powell, James Rexford",1991,6/6/91,,48,351,Texas,Newton,,W,M,Executed,10/1/02
# "Brewer, Brent",1991,6/4/91,,48,381,Texas,Randall,,W,M,,
# "Heiselbetz, Earl Carl Jr.",1991,11/1/91,,48,403,Texas,Sabine,,W,M,Executed,1/12/00
# "Chambers, Tony",1991,9/6/91,,48,423,Texas,Smith,,B,M,Executed,11/15/00
# "Sigler, Dale",1991,2/26/91,,48,439,Texas,Tarrant,,W,M,,
# "Goff, David Lee",1991,11/25/91,,48,439,Texas,Tarrant,,B,M,Executed,4/25/01
# "Clark, Kenneth R",1991,,5/10/91,48,439,Texas,Tarrant,,B,M,,
# "Barraza, Mauro",1991,4/30/91,,48,439,Texas,Tarrant,,L,M,,
# "Staley, Steven",1991,8/2/91,,48,439,Texas,Tarrant,,W,M,,
# "Bigby, James Eugene",1991,3/12/91,,48,439,Texas,Tarrant,,W,M,,
# "Cantu, Andrew",1991,,,48,441,Texas,Taylor,,L,M,Executed,2/16/99
# "Powell, David",1991,11/12/91,,48,453,Texas,Travis,,W,M,Executed,6/15/10
# "Barnes, Odell",1991,5/14/91,,48,485,Texas,Wichita,,B,M,Executed,3/1/00
# "Holland, James",1991,,,49,43,Utah,Summit,,W,M,,
# "Taylor, Vaughn",1991,,,49,43,Utah,Summit,,W,M,,
# "Satcher, Michael C.",1991,,,51,13,Virginia,Arlington County,,B,M,Executed,12/9/97
# "Mueller, Everett L.",1991,,,51,41,Virginia,Chesterfield County,,W,M,Executed,9/16/99
# "Thomas, Douglas C.",1991,,,51,119,Virginia,Middlesex County,,W,M,Executed,1/10/00
# "George, Michael C.",1991,,,51,153,Virginia,Prince William,,W,M,Executed,2/6/97
# "King, Danny L.",1991,,,51,161,Virginia,Roanoke County,,W,M,Executed,7/23/98
# "Davidson, Mickey W.",1991,,,51,173,Virginia,Smyth County,,W,M,Executed,10/19/95
# "Jenkins, Arthur R. III",1991,,,51,187,Virginia,Warren County,,W,M,Executed,4/20/99
# "Gentry, Jonathan",1991,,,53,35,Washington,Kitsap,,B,M,,
# "Dobyne, Willie",1992,1/12/91,,1,7,Alabama,Bibb,,W,M,,
# "Giles, Arthur Lee",1992,6/14/05,11/10/78,1,9,Alabama,Blount,Resentenced - prior sentence in1979,B,M,,
# "McGahee, Earl",1992,,,1,47,Alabama,Dallas,,B,M,,
# "Smith, Willie B",1992,,1991,1,73,Alabama,Jefferson,,B,M,,
# "Carr, Patrick",1992,,,1,73,Alabama,Jefferson,,B,M,,
# "Smith, James Wyman",1992,6/24/92,,1,81,Alabama,Lee,,W,M,,
# "Fletcher, Marcus",1992,,,1,83,Alabama,Limestone,,B,M,,
# "Rieber, Jeffrey D",1992,,1990,1,89,Alabama,Madison,,W,M,,
# "Brownlow, Charles",2016,5/23/16,,48,257,Texas,Kaufman,,B,M,,
# "Wells, Amos",2016,11/18/16,,48,439,Texas,Tarrant,,B,M,,
# "Bluntson, Demond",2016,5/10/16,,48,479,Texas,Webb,,B,M,,

# %% [markdown]
# Um mit diesen Daten arbeiten zu können, brauchen wir sie in nützlicher Form. Genau dafür ist pandas da.

# %% [markdown]
# Wir lesen das Datenfile also nochmals - diesmal mit der pandas Funktion `read_csv()`.
#
# Pandas stellt das csv-File nun als Tabelle dar, mit Spaltentieln und einem Zeilen-Index.
#
# Die oberste Zeile im csv-File wird standardmässig verwendet, um die Spaltentitel zu bilden.

# %%
pd.read_csv(path)
# Out:
#                defendant  year sent_date offns_date  fips_st  fips  \
# 0         Petersen, Ryan  2017       NaN        NaN        1    69
# 1         Jackson, Jamal  2017       NaN        NaN        1    97
# 2     Hunter Smith, Brad  2017       NaN        NaN        5    25
# 3        Allen, Samantha  2017       NaN        NaN        4    13
# 4            Allen, John  2017       NaN        NaN        4    13
# ...                  ...   ...       ...        ...      ...   ...
# 4914        Tam Minh, Le  2016   12/9/16        NaN       42   101
# 4915      Gonzalez, Mark  2016   1/28/16        NaN       48    29
# 4916   Brownlow, Charles  2016   5/23/16        NaN       48   257
# 4917         Wells, Amos  2016  11/18/16        NaN       48   439
# 4918    Bluntson, Demond  2016   5/10/16        NaN       48   479
#
#              state        county prev_sent def_race def_gender Executed  \
# 0               AL       Houston       NaN        W          M      NaN
# 1               AL        Mobile       NaN        B          M      NaN
# 2               AR     Cleveland       NaN        W          M      NaN
# 3               AZ      Maricopa       NaN        W          F      NaN
# 4               AZ      Maricopa       NaN        W          M      NaN
# ...            ...           ...       ...      ...        ...      ...
# 4914  Pennsylvania  Philadelphia       NaN        A          M      NaN
# 4915         Texas         Bexar       NaN        L          M      NaN
# 4916         Texas       Kaufman       NaN        B          M      NaN
# 4917         Texas       Tarrant       NaN        B          M      NaN
# 4918         Texas          Webb       NaN        B          M      NaN
#
#      DateofExecution
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 4914             NaN
# 4915             NaN
# 4916             NaN
# 4917             NaN
# 4918             NaN
#
# [4919 rows x 13 columns]

# %% [markdown]
# Was wir hier sehen, nennt sich in pandas-Sprache ***dataframe***. Dataframes sind die python-Version von Exceltabellen.
#
# (Um es genau zu nehmen: wir sehen hier nicht das dataframe selbst, sondern eine Repräsentation davon)

# %% [markdown]
# Wir wollen das dataframe allerdings nicht nur sehen, sondern auch damit arbeiten.
#
# Dazu müssen wir es in einer Variable speichern - der meistbenutzte Name dafür ist `df`.
#
# (Man könnte aber auch irgendeinen anderen Variablennamen nehmen, zB `meinLiebstesDataframe`).

# %%
df = pd.read_csv(path)

# %% [markdown]
# ## Datenstruktur überblicken

# %% [markdown]
# Der logische erste Schritt nach dem Einlesen eines Datenfile ist gewöhnlich, dass man sich einen Überblick über die Datenstruktur verschafft:
# - Zeilenzahl
# - Spaltenzahl
# - Spaltennamen
# - Datentypen
# - etc.

# %% [markdown]
# Die allereinfachste Art, das zu tun, ist, sich das Datenfile einfach visuell darstellen zu lassen, indem man den Variablennamen eintippt und den Codeblock ausführt.
#
# **Check:** Was sieht man in der Darstellung? Was sieht man nicht?

# %%
df
# Out:
#                defendant  year sent_date offns_date  fips_st  fips  \
# 0         Petersen, Ryan  2017       NaN        NaN        1    69
# 1         Jackson, Jamal  2017       NaN        NaN        1    97
# 2     Hunter Smith, Brad  2017       NaN        NaN        5    25
# 3        Allen, Samantha  2017       NaN        NaN        4    13
# 4            Allen, John  2017       NaN        NaN        4    13
# ...                  ...   ...       ...        ...      ...   ...
# 4914        Tam Minh, Le  2016   12/9/16        NaN       42   101
# 4915      Gonzalez, Mark  2016   1/28/16        NaN       48    29
# 4916   Brownlow, Charles  2016   5/23/16        NaN       48   257
# 4917         Wells, Amos  2016  11/18/16        NaN       48   439
# 4918    Bluntson, Demond  2016   5/10/16        NaN       48   479
#
#              state        county prev_sent def_race def_gender Executed  \
# 0               AL       Houston       NaN        W          M      NaN
# 1               AL        Mobile       NaN        B          M      NaN
# 2               AR     Cleveland       NaN        W          M      NaN
# 3               AZ      Maricopa       NaN        W          F      NaN
# 4               AZ      Maricopa       NaN        W          M      NaN
# ...            ...           ...       ...      ...        ...      ...
# 4914  Pennsylvania  Philadelphia       NaN        A          M      NaN
# 4915         Texas         Bexar       NaN        L          M      NaN
# 4916         Texas       Kaufman       NaN        B          M      NaN
# 4917         Texas       Tarrant       NaN        B          M      NaN
# 4918         Texas          Webb       NaN        B          M      NaN
#
#      DateofExecution
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 4914             NaN
# 4915             NaN
# 4916             NaN
# 4917             NaN
# 4918             NaN
#
# [4919 rows x 13 columns]

# %% [markdown]
# ### Anfang und Schluss anzeigen

# %% [markdown]
# Manchmal möchte man in einem Notebook platzsparend arbeiten - das viele scrollen nervt.
#
# Um Platz zu sparen: zeigen wir doch einfach nur die ersten drei Einträge an. Wir verwenden dazu die Funktion `head()`.
#
# Jedes dataframe hat diese Funktion "eingebaut", wie auch noch viele weitere Funktionen, die wir in den nächsten Tagen kennenlernen werden.

# %%
df.head(3)
# Out:
#             defendant  year sent_date offns_date  fips_st  fips state  \
# 0      Petersen, Ryan  2017       NaN        NaN        1    69    AL
# 1      Jackson, Jamal  2017       NaN        NaN        1    97    AL
# 2  Hunter Smith, Brad  2017       NaN        NaN        5    25    AR
#
#       county prev_sent def_race def_gender Executed DateofExecution
# 0    Houston       NaN        W          M      NaN             NaN
# 1     Mobile       NaN        B          M      NaN             NaN
# 2  Cleveland       NaN        W          M      NaN             NaN

# %% [markdown]
# Analog: die letzten drei Einträge. Mit `tail()`

# %%
df.tail(3)
# Out:
#               defendant  year sent_date offns_date  fips_st  fips  state  \
# 4916  Brownlow, Charles  2016   5/23/16        NaN       48   257  Texas
# 4917        Wells, Amos  2016  11/18/16        NaN       48   439  Texas
# 4918   Bluntson, Demond  2016   5/10/16        NaN       48   479  Texas
#
#        county prev_sent def_race def_gender Executed DateofExecution
# 4916  Kaufman       NaN        B          M      NaN             NaN
# 4917  Tarrant       NaN        B          M      NaN             NaN
# 4918     Webb       NaN        B          M      NaN             NaN

# %%
#head() funktioniert auch ohne Angabe der Zeilenzahl...

# %% [markdown]
# **Tipp:** Wenn ihr nicht wisst, wie eine Funktion benutzen: Einfach ein Fragezeichen tippen: `?`

# %%
df.head?

# %% [markdown]
# **Frage:** Was ist das für eine Art von Output, den wir hier erhalten haben?

# %% [markdown]
# Wir können den Output separat speichern, um damit weiter zu arbeiten.

# %%
erste_drei = df.head(3)

# %%
erste_drei
# Out:
#             defendant  year sent_date offns_date  fips_st  fips state  \
# 0      Petersen, Ryan  2017       NaN        NaN        1    69    AL
# 1      Jackson, Jamal  2017       NaN        NaN        1    97    AL
# 2  Hunter Smith, Brad  2017       NaN        NaN        5    25    AR
#
#       county prev_sent def_race def_gender Executed DateofExecution
# 0    Houston       NaN        W          M      NaN             NaN
# 1     Mobile       NaN        B          M      NaN             NaN
# 2  Cleveland       NaN        W          M      NaN             NaN

# %% [markdown]
# **Quiz:** Erstellen Sie ein Dataframe, das ausschliesslich den dritt- und den zweitletzten Eintrag im dataframe `df` beinhaltet!

# %%
#Antwort: 
letzte_drei = df.tail(3)

# %%
zweit_und_drittletze = letzte_drei.head(2)

# %%
zweit_und_drittletze
# Out:
#               defendant  year sent_date offns_date  fips_st  fips  state  \
# 4916  Brownlow, Charles  2016   5/23/16        NaN       48   257  Texas
# 4917        Wells, Amos  2016  11/18/16        NaN       48   439  Texas
#
#        county prev_sent def_race def_gender Executed DateofExecution
# 4916  Kaufman       NaN        B          M      NaN             NaN
# 4917  Tarrant       NaN        B          M      NaN             NaN

# %% [markdown]
# ### Chained notation

# %% [markdown]
# Aktion ausführen, Output abspeichern, Aktion mit dem Output ausführen, Output erneut abspeichern ...
#
# ... um diesen Prozess etwas abzukürzen, gibt es vielen Programmiersprachen die sog. "chained notation".
#
# So auch in Pandas. Wir können mehrere Aktionen in einer einzigen Kommandozeile ausführen, sie "verketten".

# %%
#das obige Beispiel funktioniert dann so:
df.tail(3).head(2)
# Out:
#               defendant  year sent_date offns_date  fips_st  fips  state  \
# 4916  Brownlow, Charles  2016   5/23/16        NaN       48   257  Texas
# 4917        Wells, Amos  2016  11/18/16        NaN       48   439  Texas
#
#        county prev_sent def_race def_gender Executed DateofExecution
# 4916  Kaufman       NaN        B          M      NaN             NaN
# 4917  Tarrant       NaN        B          M      NaN             NaN

# %% [markdown]
# Mit der chained notation kann man beliebig viele pandas-Befehle aneinanderreihen – so lange der Output eines befehls ein Objekt ist (dataframe, series), das wiederum standardmässig mit einer Reihe von Funktionen "ausgerüstet" ist.

# %% [markdown]
# **Frage:** Warum funktioniert der folgende Befehl nicht?

# %%
#print(df).head(3)

# %% [markdown]
# ### Ein paar Übersichtsfunktionen und -properties

# %% [markdown]
# An dieser Stelle wollen wir die Grösse und Struktur der Tabelle erforschen, ohne die Tabelle selbst anzuzeigen.
#
# Pandas stellt dazu ein paar Befehle zur Verfügung.

# %% [markdown]
# - `shape` zeigt die Zeilen- und Spaltenzahl des dataframes als tuple an

# %%
df.shape
# Out:
# (4919, 13)

# %% [markdown]
# - `len()`: Falls wir nur an der Zeilenzahl interessiert sind, geht das auch über einen normalen Python-Befehl

# %%
len(df)
# Out:
# 4919

# %% [markdown]
# - `columns` spuckt eine Liste der Spalten aus

# %%
df.columns
# Out:
# Index(['defendant', 'year', 'sent_date', 'offns_date', 'fips_st', 'fips',
#        'state', 'county', 'prev_sent', 'def_race', 'def_gender', 'Executed',
#        'DateofExecution'],
#       dtype='object')

# %% [markdown]
# - `dtypes` spuckt eine Liste der Spalten samt dem Datentyp aus

# %%
df.dtypes
# Out:
# defendant          object
# year                int64
# sent_date          object
# offns_date         object
# fips_st             int64
# fips                int64
# state              object
# county             object
# prev_sent          object
# def_race           object
# def_gender         object
# Executed           object
# DateofExecution    object
# dtype: object

# %% [markdown]
# Die Übersicht der `dtypes` zeigt uns rasch einiger wertvolle Informationen an:
# - welche Spalten beinhalten Zahlenwerte (`int64` oder auch `float64`)
# - welche Spalten beinhalten einen Text, der nicht als Zahl erkannt werden kann (`object`)
#
# `dtypes` verrät auch schnell, falls es irgendwo Probleme und Unsauberkeiten in den Daten geben könnte. Das kann später wichtig werden.
#
# Falls zB die Spalte "year" nicht als Zahl erkannt wird, stehen vermutlich irgendwo Buchstaben drin. Gewisse Funktionen über diese Spalte könnten deshalb fehlerhaft ausgeführt werden, weil der Datentyp nicht richtig erkannt wurde.

# %% [markdown]
# ### Einfache deskriptive Statistiken - Teil 1

# %% [markdown]
# - `describe()` spuckt ein paar deskriptive Statistiken zu allen numerischen Spalten aus

# %%
df.describe()
# Out:
#               year      fips_st         fips
# count  4919.000000  4919.000000  4919.000000
# mean   1999.973572    26.026428    94.189266
# std       6.755333    18.647075    99.697414
# min    1991.000000     1.000000     1.000000
# 25%    1994.000000     6.000000    31.000000
# 50%    1998.000000    24.000000    71.000000
# 75%    2005.000000    42.000000   113.000000
# max    2017.000000    99.000000   840.000000

# %% [markdown]
# Schauen wir uns diesen Output einen Moment an.
#
# **year** scheint klar. Aber was zur Hölle sind **"fips_st"** und **"fips"** für Datenfelder? Weil die Dokumentation oben fehlt, wissen wir das für den Moment leider nicht.
#
# Googeln führt uns:
# - hierhin https://www.google.com/search?q=fips+code&ie=utf-8&oe=utf-8&client=firefox-b-ab
# - und hierhin https://en.wikipedia.org/wiki/FIPS_county_code
#
# Es handelt sich also um County Codes. Einen Durchschnitt darüber auszurechnen wäre offensichtlich ziemlich sinnlos. Etwa so sinnlos, wie zu berechnen: Was ist die durchschnittliche Postleitzahl eines Mörders in der Schweiz?

# %% [markdown]
# Bleiben wir also mal bei den Jahren. Das "durchschnittliche Jahr, in dem eine Exekution stattfand" auzurechnen, ist zwar auch nicht viel sinnvoller, aber immerhin: pandas hat eine separate Funktion dafür.

# %% [markdown]
# - `mean()` berechnet den Durchschnitt einer Datenreihe

# %%
df['year'].mean()
# Out:
# 1999.9735718642

# %% [markdown]
# - `sum()` berechnet die Summe

# %%
df['year'].sum()
# Out:
# 9837870

# %% [markdown]
# Etwas sinnvoller sind das Minimum und das Maximum - zeigen Beginn und Ende der Datensammlung an:

# %% [markdown]
# - `max()` und `min()` zeigen die Extremwerte an

# %%
df['year'].min()
# Out:
# 1991

# %%
df['year'].max()
# Out:
# 2017

# %% [markdown]
# Die totale Anzahl der Jahres-Einträge ist in diesem Fall gleichbedeutend mit der Anzahl Einträge im ganzen dataframe, weil jeder Eintrag vollständig ist.

# %% [markdown]
# - `count()` gibt die Anzahl der Einträge an

# %%
df['year'].count()
# Out:
# 4919

# %% [markdown]
# Dann gibt's noch Dinge wie den Median und die Standardabweichung, obwohl das in diesem Fall wie gesagt ziemlich sinnlose Zahlen sind:

# %% [markdown]
# - `median()`und `std()`

# %%
df['year'].median()
# Out:
# 1998.0

# %%
df['year'].std()
# Out:
# 6.755332632797353

# %% [markdown]
# ### Einzelne Spalten anschauen

# %% [markdown]
# Moment mal, was war denn das soeben für eine Syntax mit den eckigen Klammern?
#
# Einzelne Spalten werden bei pandas als ***series*** bezeichnet.
#
# Es gibt verschiedene Arten, solche series bzw Spalten anzusprechen.

# %%
# Mit einer eckigen Klammer
df['year']
# Out:
# 0       2017
# 1       2017
# 2       2017
# 3       2017
# 4       2017
#         ...
# 4914    2016
# 4915    2016
# 4916    2016
# 4917    2016
# 4918    2016
# Name: year, Length: 4919, dtype: int64

# %%
# Einfach so nach dem Punkt
df.year
# Out:
# 0       2017
# 1       2017
# 2       2017
# 3       2017
# 4       2017
#         ...
# 4914    2016
# 4915    2016
# 4916    2016
# 4917    2016
# 4918    2016
# Name: year, Length: 4919, dtype: int64

# %% [markdown]
# Welche Syntax wählen? Darauf gibt es mehrere Antworten:
# - Kommt drauf an, was man genau tun will und wie schreibfaul man ist
# - Um auf Nummer sicher zu gehen, die eckigen Klammern verwenden

# %% [markdown]
# Um die Notation mit den eckigen Klammern noch besser zu verstehen, schaut euch mal diese zwei Zeilen Code an:

# %%
spalte = 'year'

# %%
df[spalte]
# Out:
# 0       2017
# 1       2017
# 2       2017
# 3       2017
# 4       2017
#         ...
# 4914    2016
# 4915    2016
# 4916    2016
# 4917    2016
# 4918    2016
# Name: year, Length: 4919, dtype: int64

# %% [markdown]
# Übrigens, manche Befehle wie `head()` funktionieren auch mit Serien. Am besten einfach ausprobieren - falls ein Befehl mit dataframes funktioniert aber mit series nicht, gibt es dann halt eine Fehlermeldung.

# %%
df['year'].head(3)
# Out:
# 0    2017
# 1    2017
# 2    2017
# Name: year, dtype: int64

# %% [markdown]
# ### Einfache desktiptive Statistiken - Teil 2

# %% [markdown]
# Viele journalistische Fragestellungen ergeben sich, indem man einfach einmal zählt, wie oft gewisse Dinge in einem Datenset vorkommen: gewisse Namen, Geschlechter, Länder, whatever! Es ist (verlgichen mit Regressionsanalysen und sonstigen Methoden, die man an der Uni gelernt hat) etwa die simpelste und stupideste Auswertungsmethode.
#
# Aber: Sie ist extrem gut vermittelbar, jeder Leser begreift sie, und sie fördert verblüffend oft Ansätze für Geschichten zutage.
#
# Merkt euch dazu diese Funktion: `value_counts()`! Die Funktion spuckt aus, welches Element wie oft in einer Serie vorkommt.
#
# (Wie gesagt - sieht trivial aus. Den Nutzen dieser Funktion hab ich am meisten unterschätzt, als ich sie zum ersten Mal gesehen habe.)

# %% [markdown]
# **Beispiel**: Anzahl der Todesurteile nach Jahren.
#
# Man sieht auf den ersten Blick, dass die Anzahl der Todesurteile über die Jahre hinweg abgenommen hat.

# %%
df['year'].value_counts()
# Out:
# year
# 1994    344
# 1995    344
# 1996    321
# 1993    308
# 1998    300
# 1991    295
# 1992    290
# 1999    287
# 1997    283
# 2000    230
# 2001    174
# 2002    168
# 2003    153
# 2005    148
# 2004    147
# 2007    144
# 2006    132
# 2008    130
# 2010    127
# 2009    126
# 2012     89
# 2011     87
# 2013     86
# 2014     79
# 2015     56
# 2017     39
# 2016     32
# Name: count, dtype: int64

# %% [markdown]
# **Quiz:** Um welchen Datentyp handelt es sich bei diesem Output?

# %%
#Antwort: 
type(df['year'].value_counts())
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Quiz:** Welche zehn US-Bundesstaaten haben am meisten Personen zu Tode verurteilt?

# %%
#Antwort:
df['state'].value_counts().head(10)
# Out:
# state
# California        657
# Texas             646
# Florida           622
# North Carolina    307
# Alabama           296
# Pennsylvania      251
# Ohio              244
# Arizona           197
# Oklahoma          186
# Illinois          141
# Name: count, dtype: int64

# %% [markdown]
# **Quiz:** Und welche zehn US-Bundesstaaten haben am wenigsten Personen zu Tode verurteilt?

# %%
#Antwort
df['state'].value_counts().tail(10)
# Out:
# state
# OK               2
# OKlahoma         1
# AR               1
# OH               1
# NE               1
# MS               1
# MO               1
# Wyoming          1
# ID               1
# New Hampshire    1
# Name: count, dtype: int64

# %% [markdown]
# ... oops. Was für ein Staat ist "OKlahoma"? Und was ist "ID"?
#
# Sieht aus, als wurden diese Daten nicht richtig geputzt!!
#
# (ein häufiges Problem, das wir später noch genau anschaun werden).
#
# Für den Moment, einfach mal diesen Code hier ausführen:

# %%
states = {
    'CA': 'California',
    'AR': 'Arkansas',
    'NV': 'Nevada',
    'TX': 'Texas',
    'AZ': 'Arizona',
    'FL': 'Florida',
    'OK': 'Oklahoma',
    'AL': 'Alabama',
    'PA': 'Pennsylvania',
    'OH': 'Ohio',
    'MS': 'Missouri',
    'MO': 'Montana',
    'ID': 'Idaho',
    'NE': 'Nebraska',
    'OKlahoma': 'Oklahoma'
}
df['state'].replace(states, inplace=True)

# %% [markdown]
# ... und nochmals probieren:

# %%
df['state'].value_counts().tail(10)
# Out:
# state
# Nebraska         15
# Colorado          9
# South Dakota      9
# New Mexico        7
# New York          7
# Utah              6
# Montana           4
# U.S. Military     4
# Wyoming           1
# New Hampshire     1
# Name: count, dtype: int64

# %% [markdown]
# Aaaaah, viel besser!

# %% [markdown]
# **Quiz:** Basierend auf dieser Liste: Wie viele Todesurteile haben die Staaten im Durchschnitt ausgesprochen

# %%
#Antwort
df['state'].value_counts().mean()
# Out:
# 122.975

# %% [markdown]
# **Quiz:** Wie viele der 50 US-Bundesstaaten haben überhaupt Todesurteile ausgesprochen?

# %%
#Antwort
df['state'].value_counts().count()
# Out:
# 40

# %% [markdown]
# **Quiz**: Wie heissen die drei Personen, die am öftesten zum Tode verurteilt wurden?

# %%
#Antwort
df['defendant'].value_counts().head(3)
# Out:
# defendant
# Wuornos, Aileen        5
# McFadden , Vincent     4
# Bolin, Oscar           4
# Name: count, dtype: int64

# %% [markdown]
# ### Minimal komplexere deskriptive Statistiken

# %% [markdown]
# Bis jetzt ging es immer darum, einzelne Spalten auszuwerten. Nun machen wir uns daran, zwei Spalten in Kombination auszuwerten. Auch dafür hält pandas einige Funktionen bereit.
#
# Die wichtigste: `groupby()` - ziemlich praktisch anzuwenden, wenn man mal die Syntax durchschaut.

# %% [markdown]
# **Beispiel:** Wann wurden in welchem Staat letztmals Menschen zum Tode verurteilt?

# %%
df.groupby('state')['year'].max()
# Out:
# state
# Alabama           2017
# Arizona           2017
# Arkansas          2017
# California        2017
# Colorado          2010
# Connecticut       2014
# Delaware          2015
# Federal           2017
# Florida           2017
# Georgia           2014
# Idaho             2017
# Illinois          2010
# Indiana           2014
# Kansas            2016
# Kentucky          2014
# Louisiana         2015
# Maryland          2007
# Mississippi       2015
# Missouri          2017
# Montana           2017
# Nebraska          2017
# Nevada            2017
# New Hampshire     2008
# New Jersey        2004
# New Mexico        2000
# New York          2002
# North Carolina    2016
# Ohio              2017
# Oklahoma          2017
# Oregon            2016
# Pennsylvania      2017
# South Carolina    2014
# South Dakota      2014
# Tennessee         2015
# Texas             2017
# U.S. Military     2013
# Utah              1999
# Virginia          2011
# Washington        2013
# Wyoming           2004
# Name: year, dtype: int64

# %% [markdown]
# Was passiert hier genau?

# %% [markdown]
# - zunächst geben wir pandas einfach mal in einer funktion das oberste Gruppierungslevel durch. In diesem Fall sind wir an einer Auswertung nach Staaten interessiert. Als Output kriegt man vorerst - nichts, ausser einem merkwürdigen Objekt.

# %%
df.groupby('state')

# %% [markdown]
# - Mit diesem Objekt können wir nun weiter arbeiten. Dazu müssen wir allerdings angeben, welche Spalte uns als nächstes interessiert. In diesem Fall ist es: das Jahr eines Todesurteils. Wir erhalten - schon wieder ein Objekt.

# %%
df.groupby('state')['year']

# %% [markdown]
# - Warum? Weil wir pandas noch nicht gesagt haben, welche Metrik es auf die zweite Spalte anwenden soll. Zum Beispiel, den Durchschnitt, die Summe, .... In diesem Fall sind wir am Maximum interessiert. Und voilà, hier kommt unsere Auswertung.

# %%
df.groupby('state')['year'].max()
# Out:
# state
# Alabama           2017
# Arizona           2017
# Arkansas          2017
# California        2017
# Colorado          2010
# Connecticut       2014
# Delaware          2015
# Federal           2017
# Florida           2017
# Georgia           2014
# Idaho             2017
# Illinois          2010
# Indiana           2014
# Kansas            2016
# Kentucky          2014
# Louisiana         2015
# Maryland          2007
# Mississippi       2015
# Missouri          2017
# Montana           2017
# Nebraska          2017
# Nevada            2017
# New Hampshire     2008
# New Jersey        2004
# New Mexico        2000
# New York          2002
# North Carolina    2016
# Ohio              2017
# Oklahoma          2017
# Oregon            2016
# Pennsylvania      2017
# South Carolina    2014
# South Dakota      2014
# Tennessee         2015
# Texas             2017
# U.S. Military     2013
# Utah              1999
# Virginia          2011
# Washington        2013
# Wyoming           2004
# Name: year, dtype: int64

# %% [markdown]
# **Quiz:** Um welchen Datentyp handelt es sich bei diesem Output?

# %%
#Antwort:
type(df.groupby('state')['year'].max())
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Und zum Schluss...

# %% [markdown]
# ... lasst uns das Resultat noch etwas ordnen. Sieht dann viel übersichtlicher aus.
#
# - Wir benutzen dazu die Funktion `sort_values()`

# %%
df.groupby('state')['year'].max().sort_values()
# Out:
# state
# Utah              1999
# New Mexico        2000
# New York          2002
# Wyoming           2004
# New Jersey        2004
# Maryland          2007
# New Hampshire     2008
# Colorado          2010
# Illinois          2010
# Virginia          2011
# U.S. Military     2013
# Washington        2013
# Connecticut       2014
# Georgia           2014
# Indiana           2014
# Kentucky          2014
# South Carolina    2014
# South Dakota      2014
# Tennessee         2015
# Louisiana         2015
# Mississippi       2015
# Delaware          2015
# Kansas            2016
# North Carolina    2016
# Oregon            2016
# Pennsylvania      2017
# Texas             2017
# Oklahoma          2017
# Alabama           2017
# Nevada            2017
# Nebraska          2017
# Missouri          2017
# Idaho             2017
# Florida           2017
# Federal           2017
# California        2017
# Arkansas          2017
# Arizona           2017
# Ohio              2017
# Montana           2017
# Name: year, dtype: int64

# %% [markdown]
# **Quiz:** Wie viele Frauen und wie viele Männer wurden insgesamt zum Tode verurteilt?

# %%
#Antwort
df['def_gender'].value_counts()
# Out:
# def_gender
# M    4816
# F      92
# Name: count, dtype: int64

# %% [markdown]
# **Quiz:** Bei vielen Frauenn und bei wie vielen Männer wurde das Todesurteil vollstreckt?

# %%
#Antwort
df.groupby('def_gender')['Executed'].count()
# Out:
# def_gender
# F      6
# M    631
# Name: Executed, dtype: int64

# %% [markdown]
# ## Plotting Level 1

# %% [markdown]
# Pandas hat eine eingebaute Plot-Funktion, die ziemlich einfach zu bedienen ist. Sie heisst...
#
# - `plot()` (wie überraschend!)

# %% [markdown]
# Probieren wir dies gleich mal an unserer Auswertung der Todesurteile nach Jahr aus, die wir weiter oben gemacht haben:

# %%
df['year'].value_counts()
# Out:
# year
# 1994    344
# 1995    344
# 1996    321
# 1993    308
# 1998    300
# 1991    295
# 1992    290
# 1999    287
# 1997    283
# 2000    230
# 2001    174
# 2002    168
# 2003    153
# 2005    148
# 2004    147
# 2007    144
# 2006    132
# 2008    130
# 2010    127
# 2009    126
# 2012     89
# 2011     87
# 2013     86
# 2014     79
# 2015     56
# 2017     39
# 2016     32
# Name: count, dtype: int64

# %%
df['year'].value_counts().plot()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# `plot()` funktioniert in den meisten Fällen ganz gut. Ausser hier, sieht es etwas scheisse aus:

# %%
df['year'].value_counts().plot()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# Der Grund liegt in diesem Fall darin, dass die Zeitreihe nicht ganz richtig geordnet war. Wir behelfen uns mit `sort_index()`.

# %%
df['year'].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# Wir können auch einen Barchart anzeigen lassen:

# %%
df['year'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# Oder als horizontalen Barchart:

# %%
df['year'].value_counts().sort_index().plot(kind='barh')
# Out:
# <Axes: ylabel='year'>

# %% [markdown]
# Oder auch grösser:

# %%
df['year'].value_counts().sort_index().plot(kind='barh', figsize=(10,7))
# Out:
# <Axes: ylabel='year'>

# %% [markdown]
# Damit sind wir am Ende des dieses Workbooks angelangt. Überlegen Sie sich nochmals kurz selbst: Was waren die wichtigsten Befehle, die wir kennengelernt haben? In welchem Stadium einer Recherche würde man diese Befehle typischerweise benutzen?

# %% [markdown]
# # Fragen, zum selbst bearbeiten

# %% [markdown]
# ### Counties

# %% [markdown]
# **Quiz:** In welchen zehn Bezirken (Counties) wurden am meisten Todesurteile gefällt? Erstellen Sie erst eine Liste und plotten Sie danach das Ergebnis.

# %%
#Antwort Liste
df['county'].value_counts().head(10)
# Out:
# county
# Los Angeles     205
# Harris          179
# Maricopa        121
# Philadelphia    106
# Jefferson       103
# Riverside        95
# Orange           91
# Clark            91
# Duval            72
# Oklahoma         70
# Name: count, dtype: int64

# %%
#Plot
df['county'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='county'>

# %% [markdown]
# ### Frauen

# %% [markdown]
# **Quiz:** In welchen fünf Staaten wurden am meisten Frauen zum Tode verurteilt? Erstellen Sie eine Liste und einen Plot.
#
# Tipp: Um die Liste nach Frauen zu filtern: `df[df['def_gender'] == 'F']`

# %%
#Antwort Liste
df[df['def_gender'] == 'F']['state'].value_counts().head(5)
# Out:
# state
# California        18
# Florida           14
# Texas             11
# Alabama            6
# North Carolina     6
# Name: count, dtype: int64

# %%
#Plot
df[df['def_gender'] == 'F']['state'].value_counts().head(5).plot(kind='bar')
# Out:
# <Axes: xlabel='state'>

# %% [markdown]
# ### Vollstreckungen

# %% [markdown]
# **Quiz:** In welchen acht Staaten wurden am meisten Todesurteile vollstreckt? Liste und Barchart.
#
# Tipp: Selbe Filter-Syntax wie oben bei den Frauen verwenden

# %%
#Antwort Liste
df[df['Executed'] == 'Executed']['state'].value_counts().head(8)
# Out:
# state
# Texas             280
# Oklahoma           64
# Virginia           63
# Missouri           35
# Ohio               28
# North Carolina     28
# Florida            25
# South Carolina     19
# Name: count, dtype: int64

# %%
#Plot
df[df['Executed'] == 'Executed']['state'].value_counts().head(8).plot(kind='bar')
# Out:
# <Axes: xlabel='state'>

# %% [markdown]
# **Quiz:** Wie hat sich die Zahl der Exekutionen Jahr für Jahr entwickelt? Liste und Linechart.

# %%
#Antwort Liste
df[df['Executed'] == 'Executed']['year'].value_counts().sort_index()
# Out:
# year
# 1991    55
# 1992    51
# 1993    66
# 1994    81
# 1995    70
# 1996    44
# 1997    43
# 1998    51
# 1999    43
# 2000    34
# 2001    17
# 2002    32
# 2003    17
# 2004    15
# 2005     1
# 2006     2
# 2007     3
# 2008     3
# 2009     1
# 2010     2
# 2011     2
# 2012     1
# 2013     1
# 2015     2
# Name: count, dtype: int64

# %%
#Plot
df[df['Executed'] == 'Executed']['year'].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='year'>
