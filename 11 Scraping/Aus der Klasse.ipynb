# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # Tabea
# Untersuchung "Shrinkflation". Fokus Schoko-Pralines.
# - Hersteller
# - Produkte-Titel
# - Preis
# - Preis/100g

# %%
url = "https://www.coop.ch/de/lebensmittel/suesses-snacks/schokolade-suessigkeiten/schokoladen-pralinen/c/m_0193"

# %%
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

#Mit Selenium auszulesen

# %%
url = "https://www.migros.ch/de/category/snacks-sussigkeiten/schokolade-sussigkeiten/pralinen"

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
url = "https://www.fressnapf.ch/de/c/hund/hundefutter/trockenfutter/"

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup.find_all(class_='p-price')[0]
# Out:
# <div class="p-price" data-hj-allow="" data-v-1e9c511c="">
#     CHF 29.95
#   </div>

# %%
soup.find_all(class_='pt-content')[0]
# Out:
# <div class="pt-content" data-v-0105e4e1=""><div class="pt-variant-info" data-v-0105e4e1=""><div class="variant variant--quantity_pieces_net_weight" data-v-0105e4e1=""><span data-v-0105e4e1="">
#           3 Verpackungsgrößen
#         </span> <!-- --></div> <!-- --></div> <!-- --> <div class="rating" data-v-0105e4e1="" data-v-161ce394=""><div class="r-stars" data-v-161ce394=""><div class="r-stars-wrapper" data-v-161ce394=""><img alt="Bewertung: 0 Sterne" data-v-161ce394="" src="/_nuxt/img/stars_empty.f240421.svg"/> <div class="r-stars--full" data-v-161ce394="" style="width:0px;"><img alt="Bewertung: 0.0 von 5 Sternen" data-v-161ce394="" src="/_nuxt/img/stars_filled.cfdfe4d.svg"/></div></div></div> <!-- --> <!-- --></div> <div class="pricing pricing--product-teaser" data-v-0105e4e1="" data-v-1e9c511c=""><!-- --> <!-- --> <!-- --> <!-- --> <!-- --> <div class="p-price" data-hj-allow="" data-v-1e9c511c="">
#     CHF 29.95
# ...

# %% [markdown]
# # Jerome
# - [Krankenkasse-Prämien](https://opendata.swiss/de/dataset/health-insurance-premiums)
# - [Kastater, Wem gehört ide Stadt Biel](https://www.map.apps.be.ch/pub/synserver?project=a42pub_basis&userprofile=geo&client=core&language=de)
# - Homegate Wohnungspreis

# %%
list(pd.read_csv('plz_verzeichnis_v2.csv', delimiter=";")['POSTLEITZAHL'])[:5]
# Out:
# [6599, 6600, 6612, 6652, 6655]

# %% [markdown]
# # Stephanie
# - [Tankstellen](https://benzin.tcs.ch/de/station)
# - [Medium](https://benzin.tcs.ch/de/station)

# %%
url = 'https://medium.com/tag/self-improvement'

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find_all('div', {'class':'dc'})
# Out:
# []

# %% [markdown]
# # Jan
# - Arztvergleich https://www.docapp.ch
# - Typ
# - Adresse
# - Sterne
# - Besuche

# %%
url = "https://www.docapp.ch/de/suche?q=Zahnarzt&l=Z%C3%BCrich&s=specialfield"

# %%
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
len(soup.find_all(class_="searchResult_adresse"))
# Out:
# 25

# %%
soup.find_all(class_="searchResult_text")[0]
# Out:
# <div class="searchResult_text pure-u-1 pure-u-md-15-24 pure-u-xl-16-24">
# <h2>
# <a href="/de/zuerich/zahnarzt/dr-med-dent-jan-munzinger/mz8jjz">Dr. med. dent. Jan Munzinger</a>
# </h2>
# <p class="searchResult_title">
#                             Zahnarzt
#                         </p>
# <p class="searchResult_fmh">
# </p>
# <p class="searchResult_adresse">
#                             Weinbergstrasse 62 <i class="dot"></i> 8006 Zürich <i class="dot"></i>
# <span>0.8 km</span>
# </p>
# <p class="searchResult_tag">
# <a class="tooltip" href="/de/glossar/zahnarzt-zahnmedizin" target="_blank" title="&lt;strong&gt;Beschreibung&lt;/strong&gt;&lt;br&gt;Als Zahnmedizin bezeichnet man das medizinische Fachgebiet, das sich mit ... &lt;a href='/de/glossar/zahnarzt-zahnmedizin'  target='_blank'&gt;Link zum Glossar&lt;/a&gt;">ZAHNARZT (ZAHNMEDIZIN)</a>
# ...

# %% [markdown]
# # Daniel
# - Autoscout https://www.autoscout24.ch/de/autos/alle-marken?vehtyp=10
# - Welche Marke wird am meisten gehandelt?

# %%
url = "https://www.autoscout24.ch/de/autos/alle-marken?vehtyp=10"

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><noscript data-next-hide-fouc="true"><style>body{display:block}</style></noscript><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><link href="..." rel="icon" type="image/x-icon"/><title>Auto &amp; MotoScout24</title><meta content="4" name="next-head-count"/><noscript data-n-css=""></noscript>
# ...
