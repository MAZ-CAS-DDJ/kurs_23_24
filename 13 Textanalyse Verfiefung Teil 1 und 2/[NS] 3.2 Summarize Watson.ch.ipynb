# %% [markdown]
# # The End of Publishing as we know it?

# %% [markdown]
# ![alt text](screwed.gif "Intro")

# %%
import requests
from bs4 import BeautifulSoup
import re
from readability import Document
import openai
import pandas as pd
import json
from openai import ChatCompletion,Completion

openai.api_key = "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"
openai_query_params = {"model": "gpt-3.5-turbo-16k-0613", "temperature": 0, "max_tokens": 1024}


def ask_openai(prompt: str) -> str:
    completion = openai.ChatCompletion.create(
      model = 'gpt-3.5-turbo-16k-0613',
      messages = [
        {'role': 'user', 'content': prompt}
      ],
      temperature = 0  
    )
    return completion['choices'][0]['message']['content']

base_prompt = """Bitte fasse den Artikel unten auf 4 Sätze zusammen. 
Artikel:"""

# %%
r = requests.get('https://www.watson.ch')
soup = BeautifulSoup(r.text, 'lxml')
entries = []
for entry in soup.select(".watson-teaser__title"):
    try:
        link = entry.parent.parent['href']
        title = entry.text
        print(f"Titel {title} Link:{link}")
        response = requests.get(link)
        doc = Document(response.content)
        readable_article = doc.summary()
        text = re.sub('<[^<]+?>', '', readable_article)
        answer = ask_openai(base_prompt + text)
        result = {"text": text, "url":link, "title": title, "summary":answer}
        print(result)
        entries.append(result)
    except:
        pass
# Out:
# Titel Der Luzerner Uhrenkönig ist tot – Jörg Bucherer stirbt 87-jährig Link:https://www.watson.ch/schweiz/luzern/382020551-uhren-haendler-joerg-bucherer-87-jaehrig-verstorben
# ...

# %%
len(entries)

# %%
openai_query_params
# Out:
# {'model': 'gpt-3.5-turbo-16k-0613', 'temperature': 0, 'max_tokens': 1024}

# %%
about_prompt = "Du bist ein Nachrichtenreporter der objektiv die Nachriten des Tages ansagt. "
news_prompt = "Du kennst folgende News des Tages:"+" ".join([f"News:{entry['summary']}\n" for entry in entries])
user_interest_prompt = "Ich interessiere mich für Banken und Finanzen. Berichte mir die relevanteste News des Tages."
sys_prompt = about_prompt+news_prompt
#print(sys_prompt)
c = ChatCompletion.create(
    model="gpt-3.5-turbo-16k-0613",
    messages=[{"role": "system", "content": sys_prompt},
              {"role": "user", "content": user_interest_prompt}])
# Out:
# Du bist ein Nachrichtenreporter der objektiv die Nachriten des Tages ansagt. Du kennst folgende News des Tages:News:Der Artikel beschreibt den Nahost-Konflikt zwischen Israel und Palästina und die Bedeutung von Karten in diesem Konflikt. Es wird erklärt, wie Israel palästinensische Gebiete für sich beansprucht und wie dies die Debatte weiter anheizt. Der Artikel gibt auch einen historischen Überblick über die Entwicklungen und Konflikte in der Region seit 1947. Es wird erwähnt, dass der Konflikt trotz einiger Friedensabkommen und Abkommen immer noch besteht und dass es immer wieder zu Eskalationen und Gewalt kommt.
# ...

# %%
c['choices'][0]['message']['content']
# Out:
# 'Die UBS und die Credit Suisse haben beide ihre Quartalsberichte veröffentlicht. Bei der UBS ergab sich im dritten Quartal 2023 ein Verlust von 785 Millionen US-Dollar, bereinigt um Integrationskosten konnte jedoch ein Gewinn vor Steuern von 844 Millionen erzielt werden. Die Credit Suisse verzeichnete erstmals seit dem ersten Quartal 2022 wieder Neugeldzuflüsse in der Vermögensverwaltung. Die UBS verzeichnete im dritten Quartal einen Nettoneugeldzufluss von 22 Milliarden Dollar, während die Credit Suisse einen Nettoneugeldzufluss von 8,2 Milliarden Franken verzeichnete. Beide Banken sind vorsichtig optimistisch für die Zukunft, warnen jedoch vor dem unsicheren Marktumfeld und geopolitischen Spannungen.'
